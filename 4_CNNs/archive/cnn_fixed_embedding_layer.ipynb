# %% [markdown]
# # CNN with a Trainable Embedding Layer

# %%
# %matplotlib inline

import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID";
os.environ["CUDA_VISIBLE_DEVICES"]="0";

# %%
import ktrain
from ktrain import text

import numpy as np
import tensorflow as tf
from gensim.models import Word2Vec
from gensim import utils

# %% [markdown]
# ## Compute custom Word2Vec embeddings
#
# Load the full corpus.

# %%
import pandas as pd
full_corpus = pd.read_csv('../data/ICAAD_FIJI.csv')
full_corpus_text = full_corpus.contents
dummy_labels = full_corpus.sentencing

# %% [markdown]
# Instantiate the preprocessor

# %%
NUM_WORDS = 33000
MAXLEN = 5000
DIMS = 300
NGRAM_RANGE = 1

# %% [markdown]
# Preprocess the full corpus.  Note that we need to pass a dummy vector of lables.  These don't matter.

# %%
preproc = ktrain.text.preprocessor.StandardTextPreprocessor(max_features=NUM_WORDS, maxlen=MAXLEN, class_names=[0,1])

# %%
X, dummy_y = preproc.preprocess_train(full_corpus_text, dummy_labels)
# Out:
# language: en
# Word Counts: 132011
# Nrows: 13384
# 13384 train sequences
# train sequence lengths:
# 	mean : 2218
# 	95percentile : 5989
# 	99percentile : 11259
# x_train shape: (13384,5000)
# y_train shape: (13384, 2)
# Is Multi-Label? False

# %%
X = list(X)

# %% [markdown]
# Convert the tokenized documents back into text in preparation for running through Word2Vec.  This step may not be strictly necessary.

# %%
X_text = [preproc.undo(doc).split(' ') for doc in X]

# %%
def build_model(corpus, dims=DIMS, workers=8):
    WV = Word2Vec(sentences=corpus, size=dims, workers=8)
    vocab = WV.wv.index2word
    vocab_len = len(vocab)
    embeddings = np.array([WV.wv.get_vector(word) for word in vocab])
    text_to_token = {word: i for word, i in zip(vocab, range(vocab_len))}
    token_to_text = {i: word for word, i in zip(vocab, range(vocab_len))}
    model = {'embeddings': embeddings,
             'text_to_token': text_to_token,
             'token_to_text': token_to_text,
             'vocab': vocab,
             'vocab_len': len(vocab)}
    return model

# %%
def embed_word(word, wv_model, dims):
    if word in wv_model['vocab']:
        token = wv_model['text_to_token'][word]
        return wv_model['embeddings'][token]
    else:
        return np.zeros(dims)

# %%
def build_embeddings(preproc, wv_model, dims):
    preproc_vocab = preproc.undo(range(NUM_WORDS)).split(' ')
    Embeddings = [embed_word(word, wv_model, DIMS) for word in preproc_vocab]
    Embeddings = np.stack(Embeddings)
    return(Embeddings)

# %%
wv_model = build_model(X_text, DIMS)
Embeddings = build_embeddings(preproc, wv_model, DIMS)

# %%
Train = pd.read_csv('../data/train.csv')
x_train = Train.cleaned_contents
y_train = Train.Discrimination_Label

Test = pd.read_csv('../data/test.csv')
x_test = Test.cleaned_contents
y_test = Test.Discrimination_Label

# %%
train = preproc.preprocess_test(x_train, y_train)
test = preproc.preprocess_test(x_test, y_test)
# Out:
# 647 test sequences
# test sequence lengths:
# 	mean : 1515
# 	95percentile : 3968
# 	99percentile : 7513
# x_test shape: (647,5000)
# y_test shape: (647, 2)
# 162 test sequences
# test sequence lengths:
# 	mean : 1419
# 	95percentile : 3336
# 	99percentile : 7205
# x_test shape: (162,5000)
# y_test shape: (162, 2)

# %% [markdown]
# ## Build the model

# %%
def _build_cnn(maxlen, max_features, embed_dim, filters, kernels,
               dropout=0.1, density=64,
               loss_func='categorical_crossentropy',
               activation = 'softmax', metrics=['accuracy'],
               verbose=1, optimizer='adam'):
    
    embedding_matrix = np.ones((max_features, 1))
    embedding_matrix[0] = 0

    # set up the model
    inp = tf.keras.layers.Input(shape=(maxlen,))
    x = tf.keras.layers.Embedding(max_features, embed_dim, input_length=maxlen, 
                                  trainable=False)(inp)
    x0 = tf.keras.layers.Conv1D(filters=filters,
                               kernel_size=kernels[0],
                               activation='relu')(x)
    x0 = tf.keras.layers.MaxPool1D(pool_size=maxlen - kernels[0] + 1)(x0)

    x1 = tf.keras.layers.Conv1D(filters=filters,
                                kernel_size=kernels[1],
                                activation='relu')(x)
    x1 = tf.keras.layers.MaxPool1D(pool_size=maxlen - kernels[1] + 1)(x1)
    
    x2 = tf.keras.layers.Conv1D(filters=filters,
                                kernel_size=kernels[2],
                                activation='relu')(x)
    x2 = tf.keras.layers.MaxPool1D(pool_size=maxlen - kernels[2] + 1)(x2)
    
    x3 = tf.keras.layers.Conv1D(filters=filters,
                                kernel_size=kernels[3],
                                activation='relu')(x)
    x3 = tf.keras.layers.MaxPool1D(pool_size=maxlen - kernels[3] + 1)(x3)

    x4 = tf.keras.layers.Conv1D(filters=filters,
                                kernel_size=kernels[4],
                                activation='relu')(x)
    x4 = tf.keras.layers.MaxPool1D(pool_size=maxlen - kernels[4] + 1)(x4)

    x = tf.keras.layers.concatenate([x0, x1, x2, x3, x4])

    x = tf.keras.layers.Dense(density, activation='relu')(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    x = tf.keras.layers.Flatten()(x)
    outputs = tf.keras.layers.Dense(2, activation=activation)(x)
    model = tf.keras.Model(inputs=inp, outputs=outputs)
    model.compile(loss=loss_func,
                  optimizer=optimizer,
                  metrics=metrics)
    return model

# %%
model = _build_cnn(MAXLEN, len(Embeddings), DIMS, filters=64, kernels=[2, 3, 4, 5, 6], dropout=0.4, density=32)
learner = ktrain.get_learner(model, train_data=train, val_data=test)

# %%
learner.model.summary()

# %% [markdown]
# ## Add the pre-trained embeddings

# %%
learner.model.layers[1].set_weights([Embeddings])

# %%
learner.model.weights[0].numpy()[0]

# %%
Embeddings

# %% [markdown]
# ## Define and train the model

# %% [markdown]
# ### Find a good initial learning rate
#
# This is a method that was developed at the Naval Research Laboratory.  It's been promoted by Jeremy Howard.

# %%
learner.lr_find(show_plot=True)

# %% [markdown]
# ### Train

# %%
learner.autofit(10e-4, early_stopping=5)

# %% [markdown]
# ## Examine results

# %%
learner.validate(class_names=preproc.get_classes())

# %% [markdown]
# ## Explain a prediction

# %%
import pandas as pd
X_test = pd.read_csv('../data/test.csv')['cleaned_contents']

# %%
predictor = ktrain.get_predictor(learner.model, preproc=preproc)

# %%
i = 9
print(predictor.predict(x_test[i]), y_test[i])

# %%
predictor.explain(x_test[i])

# %%
learner.evaluate(test)[1,1]

# %%
x_test.shape

# %%
f1_best = 0.1
for width in [32, 64, 128, 256]:
    for filters in [16, 32, 64]:
        for dropout in [0.1, 0.2, 0.3, 0.4]:
            f1s = []
            for _ in range(5):
                model = _build_cnn(MAXLEN, len(Embeddings), DIMS, filters=filters, kernels=[2, 3, 4, 5, 6], dropout=dropout, density=width)
                learner = ktrain.get_learner(model, train_data=train, val_data=test)
                learner.model.layers[1].set_weights([Embeddings])
                print(learner.model.weights[0])
                learner.autofit(10e-4)
                c_matrix = learner.evaluate(test)
                TP = c_matrix[1,1]
                FN = c_matrix[0,1]
                FP = c_matrix[1,0]
                F1 = 2 * TP / (2 * TP + FN + FP)
                f1s.append(F1)
                if F1 > f1_best:
                    print('------------------------------------------------------------------------')
                    print(str(F1) + ' is better than ' + str(f1_best))
                    f1_best = F1
                    print('New f1_best = ' + str(f1_best))
                    tf.keras.models.save_model(model, filepath='./cnn_Ioya2Vec_model')
                    predictor = ktrain.get_predictor(model, preproc)
                    predictor.save('cnn_Ioya2Vec_predictor')
            outstring = str(width) + ',' + str(filters) + ',' + str(dropout) + ',' + str(np.array(f1s).mean()) + '\n'
            print(outstring)
            with open('results_updated.csv', 'a') as f:
                f.write(outstring)
# Out:
# <tf.Variable 'embedding_36/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 5s 7ms/sample - loss: 1.5824 - accuracy: 0.4946 - val_loss: 0.8668 - val_accuracy: 0.5864
# Epoch 2/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.7436 - accuracy: 0.6569 - val_loss: 0.7024 - val_accuracy: 0.6111
# Epoch 3/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.5033 - accuracy: 0.7589 - val_loss: 0.6442 - val_accuracy: 0.6728
# Epoch 4/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.4005 - accuracy: 0.8145 - val_loss: 0.6521 - val_accuracy: 0.6358
# Epoch 5/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.3266 - accuracy: 0.8813
# Epoch 00005: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.3292 - accuracy: 0.8779 - val_loss: 0.6535 - val_accuracy: 0.6420
# Epoch 6/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2503 - accuracy: 0.9243 - val_loss: 0.6539 - val_accuracy: 0.6420
# Epoch 7/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2127 - accuracy: 0.9469
# Epoch 00007: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2156 - accuracy: 0.9444 - val_loss: 0.6546 - val_accuracy: 0.6605
# Epoch 8/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.1829 - accuracy: 0.9444 - val_loss: 0.6401 - val_accuracy: 0.6728
# Epoch 9/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1876 - accuracy: 0.9552 - val_loss: 0.6463 - val_accuracy: 0.6605
# Epoch 10/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1588 - accuracy: 0.9750
# Epoch 00010: Reducing Max LR on Plateau: new max lr will be 0.000125 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1590 - accuracy: 0.9753 - val_loss: 0.6591 - val_accuracy: 0.6728
# Epoch 11/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1595 - accuracy: 0.9706 - val_loss: 0.6453 - val_accuracy: 0.6852
# Epoch 12/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1463 - accuracy: 0.9797
# Epoch 00012: Reducing Max LR on Plateau: new max lr will be 6.25e-05 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1460 - accuracy: 0.9799 - val_loss: 0.6483 - val_accuracy: 0.6790
# Epoch 13/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1531 - accuracy: 0.9656Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.1539 - accuracy: 0.9660 - val_loss: 0.6443 - val_accuracy: 0.6852
# Epoch 00013: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.60      0.57      0.58        65
#            1       0.72      0.74      0.73        97
#
#     accuracy                           0.67       162
#    macro avg       0.66      0.66      0.66       162
# weighted avg       0.67      0.67      0.67       162
#
# ------------------------------------------------------------------------
# 0.7309644670050761 is better than 0.1
# New f1_best = 0.7309644670050761
# <tf.Variable 'embedding_37/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 4s 6ms/sample - loss: 1.4829 - accuracy: 0.5796 - val_loss: 0.8385 - val_accuracy: 0.6420
# Epoch 2/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.9600 - accuracy: 0.6461 - val_loss: 0.7798 - val_accuracy: 0.5864
# Epoch 3/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.5016 - accuracy: 0.7713 - val_loss: 0.6768 - val_accuracy: 0.5802
# Epoch 4/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.4154 - accuracy: 0.8099 - val_loss: 0.7067 - val_accuracy: 0.6543
# Epoch 5/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.3088 - accuracy: 0.8719
# Epoch 00005: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.3128 - accuracy: 0.8686 - val_loss: 0.6773 - val_accuracy: 0.6543
# Epoch 6/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2024 - accuracy: 0.9444 - val_loss: 0.6643 - val_accuracy: 0.6728
# Epoch 7/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1905 - accuracy: 0.9536 - val_loss: 0.6766 - val_accuracy: 0.6605
# Epoch 8/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1509 - accuracy: 0.9703
# Epoch 00008: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1502 - accuracy: 0.9706 - val_loss: 0.6890 - val_accuracy: 0.6605
# Epoch 9/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1375 - accuracy: 0.9722 - val_loss: 0.6784 - val_accuracy: 0.6667
# Epoch 10/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1280 - accuracy: 0.9781
# Epoch 00010: Reducing Max LR on Plateau: new max lr will be 0.000125 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1271 - accuracy: 0.9784 - val_loss: 0.6743 - val_accuracy: 0.6728
# Epoch 11/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1167 - accuracy: 0.9766Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.1166 - accuracy: 0.9768 - val_loss: 0.6810 - val_accuracy: 0.6728
# Epoch 00011: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.59      0.62      0.60        65
#            1       0.73      0.71      0.72        97
#
#     accuracy                           0.67       162
#    macro avg       0.66      0.66      0.66       162
# weighted avg       0.68      0.67      0.67       162
#
# <tf.Variable 'embedding_38/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 4s 6ms/sample - loss: 2.9979 - accuracy: 0.4869 - val_loss: 1.2501 - val_accuracy: 0.4506
# Epoch 2/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 1.2134 - accuracy: 0.6198 - val_loss: 0.7719 - val_accuracy: 0.5926
# Epoch 3/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.8833 - accuracy: 0.6832 - val_loss: 0.6909 - val_accuracy: 0.6481
# Epoch 4/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.7024 - accuracy: 0.6971 - val_loss: 0.6950 - val_accuracy: 0.6543
# Epoch 5/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.4936 - accuracy: 0.7859
# Epoch 00005: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.4975 - accuracy: 0.7852 - val_loss: 0.7108 - val_accuracy: 0.6481
# Epoch 6/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.4163 - accuracy: 0.8130 - val_loss: 0.7287 - val_accuracy: 0.6358
# Epoch 7/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.3712 - accuracy: 0.8362 - val_loss: 0.6718 - val_accuracy: 0.6790
# Epoch 8/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.3049 - accuracy: 0.8810 - val_loss: 0.6721 - val_accuracy: 0.6420
# Epoch 9/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2860 - accuracy: 0.8969
# Epoch 00009: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2871 - accuracy: 0.8964 - val_loss: 0.6959 - val_accuracy: 0.6420
# Epoch 10/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2696 - accuracy: 0.8949 - val_loss: 0.6696 - val_accuracy: 0.6420
# Epoch 11/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2383 - accuracy: 0.9413 - val_loss: 0.6750 - val_accuracy: 0.6605
# Epoch 12/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2056 - accuracy: 0.9500
# Epoch 00012: Reducing Max LR on Plateau: new max lr will be 0.000125 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2060 - accuracy: 0.9505 - val_loss: 0.6841 - val_accuracy: 0.6481
# Epoch 13/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2064 - accuracy: 0.9428 - val_loss: 0.6773 - val_accuracy: 0.6420
# Epoch 14/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1965 - accuracy: 0.9625
# Epoch 00014: Reducing Max LR on Plateau: new max lr will be 6.25e-05 (if not early_stopping).
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.1960 - accuracy: 0.9629 - val_loss: 0.6828 - val_accuracy: 0.6358
# Epoch 15/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1860 - accuracy: 0.9578Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.1856 - accuracy: 0.9583 - val_loss: 0.6819 - val_accuracy: 0.6358
# Epoch 00015: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.57      0.46      0.51        65
#            1       0.68      0.76      0.72        97
#
#     accuracy                           0.64       162
#    macro avg       0.62      0.61      0.61       162
# weighted avg       0.63      0.64      0.63       162
#
# <tf.Variable 'embedding_39/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 4s 6ms/sample - loss: 2.5827 - accuracy: 0.5039 - val_loss: 1.0485 - val_accuracy: 0.5988
# Epoch 2/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 1.3237 - accuracy: 0.6244 - val_loss: 0.7550 - val_accuracy: 0.6543
# Epoch 3/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.7380 - accuracy: 0.7388 - val_loss: 0.7755 - val_accuracy: 0.6235
# Epoch 4/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.4851 - accuracy: 0.7969
# Epoch 00004: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.4854 - accuracy: 0.7975 - val_loss: 0.8910 - val_accuracy: 0.6235
# Epoch 5/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.3545 - accuracy: 0.8423 - val_loss: 0.7452 - val_accuracy: 0.6481
# Epoch 6/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2664 - accuracy: 0.8825 - val_loss: 0.6971 - val_accuracy: 0.6605
# Epoch 7/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2289 - accuracy: 0.9258 - val_loss: 0.6768 - val_accuracy: 0.6852
# Epoch 8/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1814 - accuracy: 0.9521 - val_loss: 0.7072 - val_accuracy: 0.6605
# Epoch 9/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1558 - accuracy: 0.9578
# Epoch 00009: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1548 - accuracy: 0.9583 - val_loss: 0.6969 - val_accuracy: 0.6667
# Epoch 10/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1247 - accuracy: 0.9753 - val_loss: 0.7007 - val_accuracy: 0.6914
# Epoch 11/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1178 - accuracy: 0.9766
# Epoch 00011: Reducing Max LR on Plateau: new max lr will be 0.000125 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1192 - accuracy: 0.9753 - val_loss: 0.6868 - val_accuracy: 0.7037
# Epoch 12/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1183 - accuracy: 0.9719Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.1189 - accuracy: 0.9706 - val_loss: 0.6859 - val_accuracy: 0.6975
# Epoch 00012: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.61      0.58      0.60        65
#            1       0.73      0.75      0.74        97
#
#     accuracy                           0.69       162
#    macro avg       0.67      0.67      0.67       162
# weighted avg       0.68      0.69      0.68       162
#
# ------------------------------------------------------------------------
# 0.7411167512690355 is better than 0.7309644670050761
# New f1_best = 0.7411167512690355
# <tf.Variable 'embedding_40/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 4s 6ms/sample - loss: 0.9874 - accuracy: 0.5317 - val_loss: 0.6532 - val_accuracy: 0.6543
# Epoch 2/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.6760 - accuracy: 0.6430 - val_loss: 0.6228 - val_accuracy: 0.6420
# Epoch 3/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.5017 - accuracy: 0.7512 - val_loss: 0.6293 - val_accuracy: 0.6481
# Epoch 4/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.4026 - accuracy: 0.8284 - val_loss: 0.5908 - val_accuracy: 0.7099
# Epoch 5/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.3561 - accuracy: 0.8578 - val_loss: 0.5771 - val_accuracy: 0.6852
# Epoch 6/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2804 - accuracy: 0.9165 - val_loss: 0.6061 - val_accuracy: 0.7037
# Epoch 7/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2362 - accuracy: 0.9266
# Epoch 00007: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2360 - accuracy: 0.9274 - val_loss: 0.6976 - val_accuracy: 0.6543
# Epoch 8/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2338 - accuracy: 0.9274 - val_loss: 0.6145 - val_accuracy: 0.7099
# Epoch 9/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1728 - accuracy: 0.9641
# Epoch 00009: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1726 - accuracy: 0.9645 - val_loss: 0.5957 - val_accuracy: 0.6728
# Epoch 10/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1491 - accuracy: 0.9766Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.1492 - accuracy: 0.9768 - val_loss: 0.6020 - val_accuracy: 0.7160
# Epoch 00010: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.62      0.57      0.59        65
#            1       0.73      0.76      0.74        97
#
#     accuracy                           0.69       162
#    macro avg       0.67      0.67      0.67       162
# weighted avg       0.68      0.69      0.68       162
#
# ------------------------------------------------------------------------
# 0.7437185929648241 is better than 0.7411167512690355
# New f1_best = 0.7437185929648241
# 32,16,0.1,0.7313519004371838
#
# <tf.Variable 'embedding_41/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 4s 6ms/sample - loss: 1.4279 - accuracy: 0.5410 - val_loss: 0.7813 - val_accuracy: 0.6296
# Epoch 2/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.8550 - accuracy: 0.6136 - val_loss: 0.7380 - val_accuracy: 0.6173
# Epoch 3/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.5914 - accuracy: 0.7017 - val_loss: 0.6802 - val_accuracy: 0.6358
# Epoch 4/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.4426 - accuracy: 0.7867 - val_loss: 0.6536 - val_accuracy: 0.6667
# Epoch 5/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.3581 - accuracy: 0.8640 - val_loss: 0.6814 - val_accuracy: 0.6481
# Epoch 6/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.3117 - accuracy: 0.8717 - val_loss: 0.6463 - val_accuracy: 0.6667
# Epoch 7/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2826 - accuracy: 0.9057 - val_loss: 0.6385 - val_accuracy: 0.6852
# Epoch 8/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2476 - accuracy: 0.9243 - val_loss: 0.6267 - val_accuracy: 0.6728
# Epoch 9/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2077 - accuracy: 0.9505 - val_loss: 0.6531 - val_accuracy: 0.6790
# Epoch 10/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1968 - accuracy: 0.9406
# Epoch 00010: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1994 - accuracy: 0.9382 - val_loss: 0.6835 - val_accuracy: 0.6543
# Epoch 11/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.1795 - accuracy: 0.9583 - val_loss: 0.6528 - val_accuracy: 0.6728
# Epoch 12/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1884 - accuracy: 0.9484
# Epoch 00012: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1894 - accuracy: 0.9490 - val_loss: 0.6358 - val_accuracy: 0.6790
# Epoch 13/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1581 - accuracy: 0.9656Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.1572 - accuracy: 0.9660 - val_loss: 0.6307 - val_accuracy: 0.6728
# Epoch 00013: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.62      0.48      0.54        65
#            1       0.70      0.80      0.75        97
#
#     accuracy                           0.67       162
#    macro avg       0.66      0.64      0.64       162
# weighted avg       0.67      0.67      0.66       162
#
# ------------------------------------------------------------------------
# 0.7464114832535885 is better than 0.7437185929648241
# New f1_best = 0.7464114832535885
# <tf.Variable 'embedding_42/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 4s 6ms/sample - loss: 2.0438 - accuracy: 0.5085 - val_loss: 0.8167 - val_accuracy: 0.5309
# Epoch 2/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.9205 - accuracy: 0.6059 - val_loss: 0.6760 - val_accuracy: 0.6790
# Epoch 3/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.5785 - accuracy: 0.6955 - val_loss: 0.6408 - val_accuracy: 0.6481
# Epoch 4/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.4486 - accuracy: 0.7883 - val_loss: 0.6573 - val_accuracy: 0.6481
# Epoch 5/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.4077 - accuracy: 0.8188
# Epoch 00005: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.4066 - accuracy: 0.8207 - val_loss: 0.6547 - val_accuracy: 0.6173
# Epoch 6/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.3285 - accuracy: 0.8686 - val_loss: 0.6478 - val_accuracy: 0.6605
# Epoch 7/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.3041 - accuracy: 0.9031
# Epoch 00007: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.3050 - accuracy: 0.9042 - val_loss: 0.6847 - val_accuracy: 0.6667
# Epoch 8/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2738 - accuracy: 0.9281Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2727 - accuracy: 0.9289 - val_loss: 0.6958 - val_accuracy: 0.6420
# Epoch 00008: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.56      0.55      0.56        65
#            1       0.70      0.71      0.71        97
#
#     accuracy                           0.65       162
#    macro avg       0.63      0.63      0.63       162
# weighted avg       0.65      0.65      0.65       162
#
# <tf.Variable 'embedding_43/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 4s 6ms/sample - loss: 2.7212 - accuracy: 0.5070 - val_loss: 1.0529 - val_accuracy: 0.6049
# Epoch 2/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 1.0772 - accuracy: 0.6043 - val_loss: 0.6743 - val_accuracy: 0.6173
# Epoch 3/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.5997 - accuracy: 0.6893 - val_loss: 0.6874 - val_accuracy: 0.6543
# Epoch 4/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.4725 - accuracy: 0.7688
# Epoch 00004: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.4720 - accuracy: 0.7697 - val_loss: 0.6804 - val_accuracy: 0.6420
# Epoch 5/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.4143 - accuracy: 0.7898 - val_loss: 0.6814 - val_accuracy: 0.6235
# Epoch 6/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.3388 - accuracy: 0.8453
# Epoch 00006: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.3416 - accuracy: 0.8439 - val_loss: 0.7059 - val_accuracy: 0.6420
# Epoch 7/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2966 - accuracy: 0.8781Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2941 - accuracy: 0.8794 - val_loss: 0.6812 - val_accuracy: 0.6420
# Epoch 00007: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.54      0.29      0.38        65
#            1       0.64      0.84      0.72        97
#
#     accuracy                           0.62       162
#    macro avg       0.59      0.56      0.55       162
# weighted avg       0.60      0.62      0.59       162
#
# <tf.Variable 'embedding_44/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 4s 6ms/sample - loss: 1.7460 - accuracy: 0.5456 - val_loss: 0.6785 - val_accuracy: 0.6358
# Epoch 2/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.8069 - accuracy: 0.6275 - val_loss: 0.6837 - val_accuracy: 0.6049
# Epoch 3/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.5757 - accuracy: 0.7156
# Epoch 00003: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.5739 - accuracy: 0.7172 - val_loss: 0.7211 - val_accuracy: 0.6358
# Epoch 4/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.4840 - accuracy: 0.7620 - val_loss: 0.6457 - val_accuracy: 0.6605
# Epoch 5/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.3835 - accuracy: 0.8393 - val_loss: 0.6648 - val_accuracy: 0.6111
# Epoch 6/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.3381 - accuracy: 0.8609 - val_loss: 0.6404 - val_accuracy: 0.6543
# Epoch 7/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2927 - accuracy: 0.8964 - val_loss: 0.6987 - val_accuracy: 0.6420
# Epoch 8/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2907 - accuracy: 0.9031
# Epoch 00008: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2909 - accuracy: 0.9026 - val_loss: 0.6734 - val_accuracy: 0.6543
# Epoch 9/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2433 - accuracy: 0.9181 - val_loss: 0.6648 - val_accuracy: 0.6543
# Epoch 10/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2209 - accuracy: 0.9344
# Epoch 00010: Reducing Max LR on Plateau: new max lr will be 0.000125 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2207 - accuracy: 0.9335 - val_loss: 0.6631 - val_accuracy: 0.6667
# Epoch 11/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2150 - accuracy: 0.9359Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2141 - accuracy: 0.9366 - val_loss: 0.6684 - val_accuracy: 0.6481
# Epoch 00011: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.58      0.49      0.53        65
#            1       0.69      0.76      0.73        97
#
#     accuracy                           0.65       162
#    macro avg       0.64      0.63      0.63       162
# weighted avg       0.65      0.65      0.65       162
#
# <tf.Variable 'embedding_45/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 4s 6ms/sample - loss: 1.5105 - accuracy: 0.5301 - val_loss: 0.7864 - val_accuracy: 0.5988
# Epoch 2/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.8469 - accuracy: 0.6414 - val_loss: 0.7078 - val_accuracy: 0.5741
# Epoch 3/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.6389 - accuracy: 0.6878 - val_loss: 0.7112 - val_accuracy: 0.5926
# Epoch 4/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.4463 - accuracy: 0.8037 - val_loss: 0.6802 - val_accuracy: 0.5926
# Epoch 5/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.3941 - accuracy: 0.8238 - val_loss: 0.6731 - val_accuracy: 0.5926
# Epoch 6/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.3527 - accuracy: 0.8532 - val_loss: 0.6544 - val_accuracy: 0.6667
# Epoch 7/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2927 - accuracy: 0.8794 - val_loss: 0.6804 - val_accuracy: 0.6296
# Epoch 8/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2477 - accuracy: 0.9125
# Epoch 00008: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2462 - accuracy: 0.9134 - val_loss: 0.7603 - val_accuracy: 0.5679
# Epoch 9/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2347 - accuracy: 0.9165 - val_loss: 0.7164 - val_accuracy: 0.5802
# Epoch 10/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1870 - accuracy: 0.9531
# Epoch 00010: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1876 - accuracy: 0.9536 - val_loss: 0.6879 - val_accuracy: 0.6296
# Epoch 11/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1817 - accuracy: 0.9438Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.1815 - accuracy: 0.9444 - val_loss: 0.6872 - val_accuracy: 0.6173
# Epoch 00011: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.60      0.52      0.56        65
#            1       0.70      0.76      0.73        97
#
#     accuracy                           0.67       162
#    macro avg       0.65      0.64      0.65       162
# weighted avg       0.66      0.67      0.66       162
#
# 32,16,0.2,0.7270963080130691
#
# <tf.Variable 'embedding_46/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 4s 6ms/sample - loss: 1.8165 - accuracy: 0.5070 - val_loss: 0.6962 - val_accuracy: 0.6049
# Epoch 2/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.7964 - accuracy: 0.6352 - val_loss: 0.6362 - val_accuracy: 0.6358
# Epoch 3/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.5848 - accuracy: 0.7002 - val_loss: 0.6179 - val_accuracy: 0.6543
# Epoch 4/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.4783 - accuracy: 0.8022 - val_loss: 0.6163 - val_accuracy: 0.6790
# Epoch 5/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.4222 - accuracy: 0.8223 - val_loss: 0.6307 - val_accuracy: 0.6605
# Epoch 6/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.3930 - accuracy: 0.8422
# Epoch 00006: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.3934 - accuracy: 0.8423 - val_loss: 0.6253 - val_accuracy: 0.6420
# Epoch 7/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.3463 - accuracy: 0.8810 - val_loss: 0.6178 - val_accuracy: 0.6481
# Epoch 8/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.3334 - accuracy: 0.8813
# Epoch 00008: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.3338 - accuracy: 0.8810 - val_loss: 0.6241 - val_accuracy: 0.6296
# Epoch 9/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.3110 - accuracy: 0.9000Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.3118 - accuracy: 0.8995 - val_loss: 0.6179 - val_accuracy: 0.6790
# Epoch 00009: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60        65
#            1       0.73      0.73      0.73        97
#
#     accuracy                           0.68       162
#    macro avg       0.67      0.67      0.67       162
# weighted avg       0.68      0.68      0.68       162
#
# <tf.Variable 'embedding_47/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 4s 6ms/sample - loss: 1.7642 - accuracy: 0.5147 - val_loss: 0.7583 - val_accuracy: 0.5432
# Epoch 2/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.7854 - accuracy: 0.6244 - val_loss: 0.6651 - val_accuracy: 0.6173
# Epoch 3/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.5458 - accuracy: 0.7218 - val_loss: 0.6539 - val_accuracy: 0.6420
# Epoch 4/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.4816 - accuracy: 0.7713 - val_loss: 0.6470 - val_accuracy: 0.5926
# Epoch 5/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.4593 - accuracy: 0.7867 - val_loss: 0.6307 - val_accuracy: 0.6790
# Epoch 6/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.3553 - accuracy: 0.8532 - val_loss: 0.6771 - val_accuracy: 0.6914
# Epoch 7/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.3208 - accuracy: 0.8609
# Epoch 00007: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.3232 - accuracy: 0.8609 - val_loss: 0.6516 - val_accuracy: 0.6914
# Epoch 8/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.3050 - accuracy: 0.9104 - val_loss: 0.6491 - val_accuracy: 0.7037
# Epoch 9/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2696 - accuracy: 0.8906
# Epoch 00009: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2702 - accuracy: 0.8887 - val_loss: 0.6391 - val_accuracy: 0.7160
# Epoch 10/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2685 - accuracy: 0.9073 - val_loss: 0.6304 - val_accuracy: 0.6975
# Epoch 11/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2268 - accuracy: 0.9351 - val_loss: 0.6422 - val_accuracy: 0.7160
# Epoch 12/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2372 - accuracy: 0.9281
# Epoch 00012: Reducing Max LR on Plateau: new max lr will be 0.000125 (if not early_stopping).
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2397 - accuracy: 0.9258 - val_loss: 0.6452 - val_accuracy: 0.6852
# Epoch 13/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2186 - accuracy: 0.9459 - val_loss: 0.6557 - val_accuracy: 0.7284
# Epoch 14/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1904 - accuracy: 0.9531
# Epoch 00014: Reducing Max LR on Plateau: new max lr will be 6.25e-05 (if not early_stopping).
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.1893 - accuracy: 0.9536 - val_loss: 0.6486 - val_accuracy: 0.6914
# Epoch 15/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1890 - accuracy: 0.9563Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.1897 - accuracy: 0.9552 - val_loss: 0.6542 - val_accuracy: 0.7222
# Epoch 00015: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62        65
#            1       0.74      0.75      0.75        97
#
#     accuracy                           0.70       162
#    macro avg       0.68      0.68      0.68       162
# weighted avg       0.70      0.70      0.70       162
#
# ------------------------------------------------------------------------
# 0.7487179487179487 is better than 0.7464114832535885
# New f1_best = 0.7487179487179487
# <tf.Variable 'embedding_48/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 5s 8ms/sample - loss: 1.2581 - accuracy: 0.5054 - val_loss: 0.7134 - val_accuracy: 0.5679
# Epoch 2/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.7333 - accuracy: 0.5935 - val_loss: 0.6957 - val_accuracy: 0.5864
# Epoch 3/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.5459 - accuracy: 0.7172 - val_loss: 0.6762 - val_accuracy: 0.6605
# Epoch 4/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.4915 - accuracy: 0.7604 - val_loss: 0.6752 - val_accuracy: 0.5802
# Epoch 5/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.4348 - accuracy: 0.8053 - val_loss: 0.6632 - val_accuracy: 0.5988
# Epoch 6/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.3874 - accuracy: 0.8470 - val_loss: 0.6692 - val_accuracy: 0.5926
# Epoch 7/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.3274 - accuracy: 0.8918 - val_loss: 0.6431 - val_accuracy: 0.6173
# Epoch 8/1024
# 647/647 [==============================] - 3s 5ms/sample - loss: 0.2814 - accuracy: 0.9042 - val_loss: 0.6430 - val_accuracy: 0.6173
# Epoch 9/1024
# 647/647 [==============================] - 3s 4ms/sample - loss: 0.2861 - accuracy: 0.8980 - val_loss: 0.6561 - val_accuracy: 0.5864
# Epoch 10/1024
# ...
# Epoch 2/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.8533 - accuracy: 0.6260 - val_loss: 0.7735 - val_accuracy: 0.6173
# Epoch 3/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.5707 - accuracy: 0.7249 - val_loss: 0.6665 - val_accuracy: 0.6543
# Epoch 4/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.3966 - accuracy: 0.8253 - val_loss: 0.6769 - val_accuracy: 0.6481
# Epoch 5/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.3248 - accuracy: 0.8734
# Epoch 00005: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.3283 - accuracy: 0.8717 - val_loss: 0.6819 - val_accuracy: 0.6358
# Epoch 6/1024
# 647/647 [==============================] - 6s 10ms/sample - loss: 0.2621 - accuracy: 0.9057 - val_loss: 0.6440 - val_accuracy: 0.6605
# Epoch 7/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.2188 - accuracy: 0.9258 - val_loss: 0.6510 - val_accuracy: 0.6420
# Epoch 8/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1915 - accuracy: 0.9406
# Epoch 00008: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1916 - accuracy: 0.9413 - val_loss: 0.6594 - val_accuracy: 0.6667
# Epoch 9/1024
# 647/647 [==============================] - 6s 10ms/sample - loss: 0.1601 - accuracy: 0.9722 - val_loss: 0.6410 - val_accuracy: 0.6605
# Epoch 10/1024
# 647/647 [==============================] - 6s 10ms/sample - loss: 0.1520 - accuracy: 0.9706 - val_loss: 0.6316 - val_accuracy: 0.6605
# Epoch 11/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1248 - accuracy: 0.9861 - val_loss: 0.6411 - val_accuracy: 0.6728
# Epoch 12/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1259 - accuracy: 0.9812
# Epoch 00012: Reducing Max LR on Plateau: new max lr will be 0.000125 (if not early_stopping).
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1250 - accuracy: 0.9815 - val_loss: 0.6692 - val_accuracy: 0.6605
# Epoch 13/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1168 - accuracy: 0.9768 - val_loss: 0.6561 - val_accuracy: 0.6543
# Epoch 14/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1017 - accuracy: 0.9859
# Epoch 00014: Reducing Max LR on Plateau: new max lr will be 6.25e-05 (if not early_stopping).
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1021 - accuracy: 0.9845 - val_loss: 0.6509 - val_accuracy: 0.6543
# Epoch 15/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1018 - accuracy: 0.9797Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1015 - accuracy: 0.9799 - val_loss: 0.6467 - val_accuracy: 0.6605
# Epoch 00015: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.60      0.48      0.53        65
#            1       0.69      0.78      0.73        97
#
#     accuracy                           0.66       162
#    macro avg       0.64      0.63      0.63       162
# weighted avg       0.65      0.66      0.65       162
# /usr/local/lib/python3.6/dist-packages/ktrain/core.py:41: UserWarning: Could not save original model weights
#   warnings.warn('Could not save original model weights')
# <tf.Variable 'embedding_207/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 7s 11ms/sample - loss: 2.8397 - accuracy: 0.5394 - val_loss: 0.9348 - val_accuracy: 0.6420
# Epoch 2/1024
# 647/647 [==============================] - 6s 10ms/sample - loss: 1.1566 - accuracy: 0.6445 - val_loss: 0.6495 - val_accuracy: 0.6667
# Epoch 3/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.5110 - accuracy: 0.7821 - val_loss: 0.7633 - val_accuracy: 0.6358
# Epoch 4/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.3889 - accuracy: 0.8053 - val_loss: 0.6328 - val_accuracy: 0.6605
# Epoch 5/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.2487 - accuracy: 0.9119 - val_loss: 0.8416 - val_accuracy: 0.6481
# Epoch 6/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2712 - accuracy: 0.8703
# Epoch 00006: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.2720 - accuracy: 0.8702 - val_loss: 0.6776 - val_accuracy: 0.6605
# Epoch 7/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1977 - accuracy: 0.9335 - val_loss: 0.7688 - val_accuracy: 0.6481
# Epoch 8/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1485 - accuracy: 0.9500
# Epoch 00008: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1476 - accuracy: 0.9505 - val_loss: 0.7292 - val_accuracy: 0.6420
# Epoch 9/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1363 - accuracy: 0.9609Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1357 - accuracy: 0.9614 - val_loss: 0.6603 - val_accuracy: 0.6667
# Epoch 00009: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.60      0.45      0.51        65
#            1       0.68      0.80      0.74        97
#
#     accuracy                           0.66       162
#    macro avg       0.64      0.63      0.63       162
# weighted avg       0.65      0.66      0.65       162
# /usr/local/lib/python3.6/dist-packages/ktrain/core.py:41: UserWarning: Could not save original model weights
#   warnings.warn('Could not save original model weights')
# <tf.Variable 'embedding_208/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 7s 11ms/sample - loss: 2.3057 - accuracy: 0.5456 - val_loss: 0.9757 - val_accuracy: 0.6049
# Epoch 2/1024
# 647/647 [==============================] - 6s 10ms/sample - loss: 1.1276 - accuracy: 0.6121 - val_loss: 0.8954 - val_accuracy: 0.6049
# Epoch 3/1024
# 647/647 [==============================] - 6s 10ms/sample - loss: 0.6673 - accuracy: 0.6708 - val_loss: 0.6800 - val_accuracy: 0.6358
# Epoch 4/1024
# 647/647 [==============================] - 6s 10ms/sample - loss: 0.3876 - accuracy: 0.8269 - val_loss: 0.6411 - val_accuracy: 0.6605
# Epoch 5/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.2880 - accuracy: 0.8748 - val_loss: 0.7220 - val_accuracy: 0.6605
# Epoch 6/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.2504 - accuracy: 0.9031
# Epoch 00006: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.2499 - accuracy: 0.9042 - val_loss: 0.6656 - val_accuracy: 0.6667
# Epoch 7/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.2065 - accuracy: 0.9366 - val_loss: 0.6224 - val_accuracy: 0.7160
# Epoch 8/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1630 - accuracy: 0.9536 - val_loss: 0.7261 - val_accuracy: 0.6543
# Epoch 9/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1476 - accuracy: 0.9688
# Epoch 00009: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1489 - accuracy: 0.9675 - val_loss: 0.6582 - val_accuracy: 0.6790
# Epoch 10/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1221 - accuracy: 0.9691 - val_loss: 0.6425 - val_accuracy: 0.6728
# Epoch 11/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1043 - accuracy: 0.9828
# Epoch 00011: Reducing Max LR on Plateau: new max lr will be 0.000125 (if not early_stopping).
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1045 - accuracy: 0.9830 - val_loss: 0.6462 - val_accuracy: 0.7099
# Epoch 12/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1151 - accuracy: 0.9766Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1145 - accuracy: 0.9768 - val_loss: 0.6541 - val_accuracy: 0.6914
# Epoch 00012: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.68      0.55      0.61        65
#            1       0.73      0.82      0.78        97
#
#     accuracy                           0.72       162
#    macro avg       0.71      0.69      0.69       162
# weighted avg       0.71      0.72      0.71       162
# /usr/local/lib/python3.6/dist-packages/ktrain/core.py:41: UserWarning: Could not save original model weights
#   warnings.warn('Could not save original model weights')
# <tf.Variable 'embedding_209/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024
# 647/647 [==============================] - 7s 11ms/sample - loss: 3.1379 - accuracy: 0.5595 - val_loss: 1.9093 - val_accuracy: 0.6235
# Epoch 2/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 1.8295 - accuracy: 0.5626 - val_loss: 0.8726 - val_accuracy: 0.6420
# Epoch 3/1024
# 647/647 [==============================] - 6s 10ms/sample - loss: 0.6690 - accuracy: 0.7264 - val_loss: 0.6364 - val_accuracy: 0.6728
# Epoch 4/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.4223 - accuracy: 0.8130 - val_loss: 0.7053 - val_accuracy: 0.6111
# Epoch 5/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.3171 - accuracy: 0.8797
# Epoch 00005: Reducing Max LR on Plateau: new max lr will be 0.0005 (if not early_stopping).
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.3162 - accuracy: 0.8794 - val_loss: 0.6415 - val_accuracy: 0.6975
# Epoch 6/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.2448 - accuracy: 0.9088 - val_loss: 0.6109 - val_accuracy: 0.6728
# Epoch 7/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1835 - accuracy: 0.9459 - val_loss: 0.6125 - val_accuracy: 0.6790
# Epoch 8/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1536 - accuracy: 0.9547
# Epoch 00008: Reducing Max LR on Plateau: new max lr will be 0.00025 (if not early_stopping).
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1534 - accuracy: 0.9552 - val_loss: 0.6235 - val_accuracy: 0.6605
# Epoch 9/1024
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1436 - accuracy: 0.9691 - val_loss: 0.6148 - val_accuracy: 0.6852
# Epoch 10/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.9812
# Epoch 00010: Reducing Max LR on Plateau: new max lr will be 0.000125 (if not early_stopping).
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1150 - accuracy: 0.9799 - val_loss: 0.6204 - val_accuracy: 0.7099
# Epoch 11/1024
# 640/647 [============================>.] - ETA: 0s - loss: 0.1089 - accuracy: 0.9766Restoring model weights from the end of the best epoch.
# 647/647 [==============================] - 6s 9ms/sample - loss: 0.1096 - accuracy: 0.9768 - val_loss: 0.6131 - val_accuracy: 0.7037
# Epoch 00011: early stopping
# Weights from best epoch have been loaded into model.
#               precision    recall  f1-score   support
#
#            0       0.63      0.45      0.52        65
#            1       0.69      0.82      0.75        97
#
#     accuracy                           0.67       162
#    macro avg       0.66      0.64      0.64       162
# weighted avg       0.67      0.67      0.66       162
# /usr/local/lib/python3.6/dist-packages/ktrain/core.py:41: UserWarning: Could not save original model weights
#   warnings.warn('Could not save original model weights')
# <tf.Variable 'embedding_210/embeddings:0' shape=(32999, 300) dtype=float32, numpy=
# array([[ 5.9036863e-01,  9.0349948e-01,  1.2093734e+00, ...,
#          4.5612368e-01,  1.8838350e-01, -1.9618142e+00],
#        [-5.8652055e-01,  2.9772940e-01,  3.1020391e-01, ...,
#          1.1321809e+00,  8.5766238e-01, -2.0014069e+00],
#        [ 5.9271681e-01,  8.1031388e-01, -8.5649437e-01, ...,
#          1.3010132e+00,  4.4007072e-01, -3.6066253e+00],
#        ...,
#        [ 2.9657234e-02,  2.2038482e-02, -5.6051318e-02, ...,
#          6.9732770e-02, -1.1526353e-01,  2.1006858e-02],
#        [ 8.8998429e-02,  8.6988613e-02, -2.5797749e-02, ...,
#          8.0753088e-02, -7.5066857e-02,  1.6337280e-01],
#        [ 2.5559446e-02,  2.3548608e-03,  6.6786364e-02, ...,
#          9.2198504e-03, -5.5137150e-02,  1.2658484e-01]], dtype=float32)>
# early_stopping automatically enabled at patience=5
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 0.001...
# Train on 647 samples, validate on 162 samples
# Epoch 1/1024

# %%
os.getcwd()

# %%
outstring
