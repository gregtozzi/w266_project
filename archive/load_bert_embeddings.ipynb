# %% [markdown]
# ## Example code to load BERT word embedding files

# %%
import pickle
import pandas as pd

fname = 'data/distilBert_embeddings_stack_512.pkl'

with open(fname, 'rb') as fp:
    df_olap = pickle.load(fp)

# %%
df_olap.head()
# Out:
#    docid  label doc_use                                  input_ids_np_olap  \
# 0  73277      0   train  [101, 5650, 122, 1128, 1132, 4601, 1112, 3226,...
# 1  73277      0   train  [101, 1909, 1149, 1104, 1123, 191, 27547, 1605...
# 2  73277      0   train  [101, 1692, 1209, 1928, 1115, 1175, 1132, 2740...
# 3  73277      0   train  [101, 1127, 1107, 1231, 20993, 1121, 1367, 127...
# 4  73277      0   train  [101, 3176, 1223, 2237, 5942, 122, 123, 1104, ...
#
#                                           embeddings
# 0  [0.25269353, -0.012546801, -0.18077362, -0.207...
# 1  [0.29827455, 0.022689205, -0.22928648, -0.1488...
# 2  [0.4063151, -0.0011410881, -0.22199179, -0.244...
# 3  [0.40596703, 0.08195555, -0.18231179, -0.20820...
# 4  [0.28099203, 0.019883651, -0.23193958, -0.2665...

# %%
len(df_olap['embeddings'][0])
# Out:
# 768

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
df = pd.read_csv('molecular_activity.csv')
properties = list(df.columns.values)
properties.remove('Activity')
X = df[properties]
y = df['Activity']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(4,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
	keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid),
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=1)

test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)

# %%
pd.set_option('display.max_rows', 805)
(df_olap.groupby('docid').count()[['label']]).sort_values(by=['label'], ascending=False)
# Out:
#         label
# docid
# 264885     32
# 80568      23
# 245181     23
# 77986      20
# 268570     18
# 81163      18
# 248863     18
# 251050     18
# 80754      16
# 269044     16
# 79889      14
# 80855      14
# 284361     14
# 251896     14
# 80648      14
# 80049      13
# 74137      13
# 268663     12
# 243592     12
# 79412      12
# 78581      12
# 82905      11
# 285849     11
# 258992     11
# 259194     11
# 70384      11
# 82417      11
# 71570      11
# 75792      10
# 242946     10
# 76230      10
# 243854     10
# 77943      10
# 70042      10
# 82449      10
# 82203      10
# 249010      9
# 78839       9
# 72470       9
# 243881      9
# 245483      9
# 75927       9
# 80046       9
# 253149      9
# 247596      9
# 80130       9
# 241284      8
# 241194      8
# 80820       8
# 251854      8
# 80694       8
# 78902       8
# 70480       8
# 80433       8
# 78648       8
# 79013       8
# 249821      8
# 82859       8
# 75870       8
# 77951       8
# 271680      8
# ...

# %%
# Out:
# 268663

# %%
fname = 'data/distilBert_embeddings_headtail_' + str(chunk_len) + '.pkl'

with open(fname, 'rb') as fp:
    df_headtail = pickle.load(fp)

# %%
df_headtail.head()
# Out:
#    docid                                               text  label  len_txt  \
# 0  73277  sentence 1 you are charged as follows first co...      0     1853
# 1  79776  sentence 1 josefa kotobalavu you were charged ...      1      448
# 2  75870  sentence 1 the director of public prosecution ...      1     2995
# 3  79299  sentence 1 mohommed nabi ud dean you were conv...      1      339
# 4  80603  judgment of the court background 1 the appella...      0     2937
#
#   doc_use                                  input_ids_np_head  \
# 0   train  [101, 5650, 122, 1128, 1132, 4601, 1112, 3226,...
# 1   train  [101, 5650, 122, 179, 6787, 8057, 180, 12355, ...
# 2   train  [101, 5650, 122, 1103, 1900, 1104, 1470, 12369...
# 3   train  [101, 5650, 122, 182, 10559, 4165, 4611, 9468,...
# 4   train  [101, 9228, 1104, 1103, 2175, 3582, 122, 1103,...
#
#                                    input_ids_np_tail  \
# 0  [101, 2456, 178, 1546, 1142, 5650, 1106, 1576,...
# ...

# %%
df_test = df[df['doc_use'] == 'test']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-10ae060d4ff4> in <module>
# ----> 1 df_test = df[df['doc_use'] == 'test']
#
# NameError: name 'df' is not defined
