# %% [markdown]
# # A very fast and loose first attempt with the universal sentence encoder
# #### Load packages

# %%
import pandas as pd
import numpy as np
import nltk
import tensorflow_hub as hub
from sklearn.cluster import MiniBatchKMeans

# %% [markdown]
# #### Load the pre-trained model from Tensor-Hub

# %%
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %% [markdown]
# #### Load our data
#
# In this case, I'm loading all of the text.

# %%
data = pd.read_csv('./data/trackGBV_xls_all.csv')

# %%
data.head()
# Out:
#     docid                                           contents
# 0   73794  Home | Databases | WorldLII | Search | Feedbac...
# 1  238749     Kanoanie v Peter Kum Kee & Sons [2007] KIHC...
# 2  303537     Bade v Regina [2014] SBCA 13; SICOA-CRAC 31...
# 3  299802     Ngirametuker v Oikull Village [2013] PWSC 1...
# 4  240504     Bank of Kiribati v Corbett [2004] KIHC 48; ...

# %%
data.shape
# Out:
# (48983, 2)

# %% [markdown]
# #### Split the documents into sentences using a custom function based on `punkt`

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/gregorytozzi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def split_sent(doc):
    doc_carriage_return = doc.split('\n')
    doc_carriage_return = [line for line in doc_carriage_return if line != '']
    sentences = []
    for line in doc_carriage_return:
        for sent in nltk.tokenize.sent_tokenize(line):
            sentences.append(sent)
    return sentences

# %% [markdown]
# #### Build embeddings from a subset of the documents

# %%
docs = list(data.contents)

# %%
sentences = []
for doc in docs[:1000]:
    for sent in split_sent(doc):
        sentences.append(sent)

# %%
len(sentences)
# Out:
# 153596

# %%
embeddings = embed(sentences[:30000]).numpy()

# %%
embeddings.shape
# Out:
# (30000, 512)

# %% [markdown]
# #### Cluster the embeddings

# %%
clust = MiniBatchKMeans(n_clusters=500, verbose=1)
clust.fit(embeddings)
y_hat = clust.predict(embeddings)
# Out:
# Init 1/3 with method: k-means++
# /Users/gregorytozzi/opt/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:1676: RuntimeWarning: init_size=300 should be larger than k=500. Setting it to 3*k
#   init_size=init_size)
# Inertia for init 1/3: 59.294983
# Init 2/3 with method: k-means++
# /Users/gregorytozzi/opt/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:1676: RuntimeWarning: init_size=300 should be larger than k=500. Setting it to 3*k
#   init_size=init_size)
# Inertia for init 2/3: 63.396748
# Init 3/3 with method: k-means++
# /Users/gregorytozzi/opt/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:1676: RuntimeWarning: init_size=300 should be larger than k=500. Setting it to 3*k
#   init_size=init_size)
# Inertia for init 3/3: 62.964703
# Minibatch iteration 1/30000: mean batch inertia: 0.885546, ewa inertia: 0.885546
# Minibatch iteration 2/30000: mean batch inertia: 0.807968, ewa inertia: 0.885029
# Minibatch iteration 3/30000: mean batch inertia: 0.720702, ewa inertia: 0.883933
# Minibatch iteration 4/30000: mean batch inertia: 0.752522, ewa inertia: 0.883057
# Minibatch iteration 5/30000: mean batch inertia: 0.760959, ewa inertia: 0.882243
# Minibatch iteration 6/30000: mean batch inertia: 0.693615, ewa inertia: 0.880986
# Minibatch iteration 7/30000: mean batch inertia: 0.732939, ewa inertia: 0.879999
# Minibatch iteration 8/30000: mean batch inertia: 0.757549, ewa inertia: 0.879183
# Minibatch iteration 9/30000: mean batch inertia: 0.710965, ewa inertia: 0.878061
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 10/30000: mean batch inertia: 0.690426, ewa inertia: 0.876810
# Minibatch iteration 11/30000: mean batch inertia: 0.723001, ewa inertia: 0.875785
# Minibatch iteration 12/30000: mean batch inertia: 0.751904, ewa inertia: 0.874959
# Minibatch iteration 13/30000: mean batch inertia: 0.744229, ewa inertia: 0.874088
# Minibatch iteration 14/30000: mean batch inertia: 0.657311, ewa inertia: 0.872642
# Minibatch iteration 15/30000: mean batch inertia: 0.737284, ewa inertia: 0.871740
# Minibatch iteration 16/30000: mean batch inertia: 0.660273, ewa inertia: 0.870330
# Minibatch iteration 17/30000: mean batch inertia: 0.730822, ewa inertia: 0.869400
# Minibatch iteration 18/30000: mean batch inertia: 0.664390, ewa inertia: 0.868034
# Minibatch iteration 19/30000: mean batch inertia: 0.773591, ewa inertia: 0.867404
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 20/30000: mean batch inertia: 0.756576, ewa inertia: 0.866665
# Minibatch iteration 21/30000: mean batch inertia: 0.700760, ewa inertia: 0.865559
# Minibatch iteration 22/30000: mean batch inertia: 0.685539, ewa inertia: 0.864359
# Minibatch iteration 23/30000: mean batch inertia: 0.674369, ewa inertia: 0.863093
# Minibatch iteration 24/30000: mean batch inertia: 0.671186, ewa inertia: 0.861813
# Minibatch iteration 25/30000: mean batch inertia: 0.693008, ewa inertia: 0.860688
# Minibatch iteration 26/30000: mean batch inertia: 0.644373, ewa inertia: 0.859246
# Minibatch iteration 27/30000: mean batch inertia: 0.658498, ewa inertia: 0.857908
# Minibatch iteration 28/30000: mean batch inertia: 0.706406, ewa inertia: 0.856898
# Minibatch iteration 29/30000: mean batch inertia: 0.646959, ewa inertia: 0.855498
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 30/30000: mean batch inertia: 0.684720, ewa inertia: 0.854360
# Minibatch iteration 31/30000: mean batch inertia: 0.684705, ewa inertia: 0.853229
# Minibatch iteration 32/30000: mean batch inertia: 0.691071, ewa inertia: 0.852148
# Minibatch iteration 33/30000: mean batch inertia: 0.696720, ewa inertia: 0.851111
# Minibatch iteration 34/30000: mean batch inertia: 0.706234, ewa inertia: 0.850146
# Minibatch iteration 35/30000: mean batch inertia: 0.644990, ewa inertia: 0.848778
# Minibatch iteration 36/30000: mean batch inertia: 0.683803, ewa inertia: 0.847678
# Minibatch iteration 37/30000: mean batch inertia: 0.644086, ewa inertia: 0.846321
# Minibatch iteration 38/30000: mean batch inertia: 0.683540, ewa inertia: 0.845236
# Minibatch iteration 39/30000: mean batch inertia: 0.699182, ewa inertia: 0.844262
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 40/30000: mean batch inertia: 0.669072, ewa inertia: 0.843094
# Minibatch iteration 41/30000: mean batch inertia: 0.643709, ewa inertia: 0.841765
# Minibatch iteration 42/30000: mean batch inertia: 0.653824, ewa inertia: 0.840512
# Minibatch iteration 43/30000: mean batch inertia: 0.660485, ewa inertia: 0.839312
# Minibatch iteration 44/30000: mean batch inertia: 0.649564, ewa inertia: 0.838047
# Minibatch iteration 45/30000: mean batch inertia: 0.648246, ewa inertia: 0.836782
# Minibatch iteration 46/30000: mean batch inertia: 0.695447, ewa inertia: 0.835840
# Minibatch iteration 47/30000: mean batch inertia: 0.653409, ewa inertia: 0.834623
# Minibatch iteration 48/30000: mean batch inertia: 0.690818, ewa inertia: 0.833665
# Minibatch iteration 49/30000: mean batch inertia: 0.664075, ewa inertia: 0.832534
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 50/30000: mean batch inertia: 0.643885, ewa inertia: 0.831277
# Minibatch iteration 51/30000: mean batch inertia: 0.630037, ewa inertia: 0.829935
# Minibatch iteration 52/30000: mean batch inertia: 0.673273, ewa inertia: 0.828891
# Minibatch iteration 53/30000: mean batch inertia: 0.684895, ewa inertia: 0.827931
# Minibatch iteration 54/30000: mean batch inertia: 0.647168, ewa inertia: 0.826726
# Minibatch iteration 55/30000: mean batch inertia: 0.651432, ewa inertia: 0.825557
# Minibatch iteration 56/30000: mean batch inertia: 0.664757, ewa inertia: 0.824485
# Minibatch iteration 57/30000: mean batch inertia: 0.729053, ewa inertia: 0.823849
# Minibatch iteration 58/30000: mean batch inertia: 0.593507, ewa inertia: 0.822313
# Minibatch iteration 59/30000: mean batch inertia: 0.633587, ewa inertia: 0.821055
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 60/30000: mean batch inertia: 0.677264, ewa inertia: 0.820097
# Minibatch iteration 61/30000: mean batch inertia: 0.651727, ewa inertia: 0.818974
# Minibatch iteration 62/30000: mean batch inertia: 0.629782, ewa inertia: 0.817713
# Minibatch iteration 63/30000: mean batch inertia: 0.654086, ewa inertia: 0.816622
# Minibatch iteration 64/30000: mean batch inertia: 0.655246, ewa inertia: 0.815546
# Minibatch iteration 65/30000: mean batch inertia: 0.641772, ewa inertia: 0.814388
# Minibatch iteration 66/30000: mean batch inertia: 0.657506, ewa inertia: 0.813342
# Minibatch iteration 67/30000: mean batch inertia: 0.624638, ewa inertia: 0.812084
# Minibatch iteration 68/30000: mean batch inertia: 0.682254, ewa inertia: 0.811219
# Minibatch iteration 69/30000: mean batch inertia: 0.681017, ewa inertia: 0.810351
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 70/30000: mean batch inertia: 0.634099, ewa inertia: 0.809176
# Minibatch iteration 71/30000: mean batch inertia: 0.702974, ewa inertia: 0.808468
# Minibatch iteration 72/30000: mean batch inertia: 0.645635, ewa inertia: 0.807382
# Minibatch iteration 73/30000: mean batch inertia: 0.657816, ewa inertia: 0.806385
# Minibatch iteration 74/30000: mean batch inertia: 0.708340, ewa inertia: 0.805731
# Minibatch iteration 75/30000: mean batch inertia: 0.596342, ewa inertia: 0.804336
# Minibatch iteration 76/30000: mean batch inertia: 0.651910, ewa inertia: 0.803319
# Minibatch iteration 77/30000: mean batch inertia: 0.668316, ewa inertia: 0.802419
# Minibatch iteration 78/30000: mean batch inertia: 0.630583, ewa inertia: 0.801274
# Minibatch iteration 79/30000: mean batch inertia: 0.677533, ewa inertia: 0.800449
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 80/30000: mean batch inertia: 0.648442, ewa inertia: 0.799436
# Minibatch iteration 81/30000: mean batch inertia: 0.602379, ewa inertia: 0.798122
# Minibatch iteration 82/30000: mean batch inertia: 0.640558, ewa inertia: 0.797072
# Minibatch iteration 83/30000: mean batch inertia: 0.641070, ewa inertia: 0.796032
# Minibatch iteration 84/30000: mean batch inertia: 0.569329, ewa inertia: 0.794520
# Minibatch iteration 85/30000: mean batch inertia: 0.639741, ewa inertia: 0.793488
# Minibatch iteration 86/30000: mean batch inertia: 0.655794, ewa inertia: 0.792570
# Minibatch iteration 87/30000: mean batch inertia: 0.622917, ewa inertia: 0.791440
# Minibatch iteration 88/30000: mean batch inertia: 0.610846, ewa inertia: 0.790236
# Minibatch iteration 89/30000: mean batch inertia: 0.698903, ewa inertia: 0.789627
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 90/30000: mean batch inertia: 0.644734, ewa inertia: 0.788661
# Minibatch iteration 91/30000: mean batch inertia: 0.679715, ewa inertia: 0.787935
# Minibatch iteration 92/30000: mean batch inertia: 0.707187, ewa inertia: 0.787396
# Minibatch iteration 93/30000: mean batch inertia: 0.648248, ewa inertia: 0.786469
# Minibatch iteration 94/30000: mean batch inertia: 0.680827, ewa inertia: 0.785764
# Minibatch iteration 95/30000: mean batch inertia: 0.674085, ewa inertia: 0.785020
# Minibatch iteration 96/30000: mean batch inertia: 0.625946, ewa inertia: 0.783959
# Minibatch iteration 97/30000: mean batch inertia: 0.626086, ewa inertia: 0.782907
# Minibatch iteration 98/30000: mean batch inertia: 0.684586, ewa inertia: 0.782251
# Minibatch iteration 99/30000: mean batch inertia: 0.655498, ewa inertia: 0.781406
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 100/30000: mean batch inertia: 0.624777, ewa inertia: 0.780362
# Minibatch iteration 101/30000: mean batch inertia: 0.680729, ewa inertia: 0.779698
# Minibatch iteration 102/30000: mean batch inertia: 0.622874, ewa inertia: 0.778653
# Minibatch iteration 103/30000: mean batch inertia: 0.639629, ewa inertia: 0.777726
# Minibatch iteration 104/30000: mean batch inertia: 0.614732, ewa inertia: 0.776639
# Minibatch iteration 105/30000: mean batch inertia: 0.630720, ewa inertia: 0.775667
# Minibatch iteration 106/30000: mean batch inertia: 0.695776, ewa inertia: 0.775134
# Minibatch iteration 107/30000: mean batch inertia: 0.614800, ewa inertia: 0.774065
# Minibatch iteration 108/30000: mean batch inertia: 0.642040, ewa inertia: 0.773185
# Minibatch iteration 109/30000: mean batch inertia: 0.664158, ewa inertia: 0.772458
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 110/30000: mean batch inertia: 0.651874, ewa inertia: 0.771654
# Minibatch iteration 111/30000: mean batch inertia: 0.671493, ewa inertia: 0.770987
# Minibatch iteration 112/30000: mean batch inertia: 0.617403, ewa inertia: 0.769963
# Minibatch iteration 113/30000: mean batch inertia: 0.700054, ewa inertia: 0.769497
# Minibatch iteration 114/30000: mean batch inertia: 0.647671, ewa inertia: 0.768684
# Minibatch iteration 115/30000: mean batch inertia: 0.648915, ewa inertia: 0.767886
# Minibatch iteration 116/30000: mean batch inertia: 0.647763, ewa inertia: 0.767085
# Minibatch iteration 117/30000: mean batch inertia: 0.664548, ewa inertia: 0.766402
# Minibatch iteration 118/30000: mean batch inertia: 0.625171, ewa inertia: 0.765460
# Minibatch iteration 119/30000: mean batch inertia: 0.639942, ewa inertia: 0.764623
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 120/30000: mean batch inertia: 0.633658, ewa inertia: 0.763750
# Minibatch iteration 121/30000: mean batch inertia: 0.645122, ewa inertia: 0.762960
# Minibatch iteration 122/30000: mean batch inertia: 0.670489, ewa inertia: 0.762343
# Minibatch iteration 123/30000: mean batch inertia: 0.657987, ewa inertia: 0.761647
# Minibatch iteration 124/30000: mean batch inertia: 0.631271, ewa inertia: 0.760778
# Minibatch iteration 125/30000: mean batch inertia: 0.627089, ewa inertia: 0.759887
# Minibatch iteration 126/30000: mean batch inertia: 0.660627, ewa inertia: 0.759225
# Minibatch iteration 127/30000: mean batch inertia: 0.599520, ewa inertia: 0.758161
# Minibatch iteration 128/30000: mean batch inertia: 0.687646, ewa inertia: 0.757691
# Minibatch iteration 129/30000: mean batch inertia: 0.642126, ewa inertia: 0.756920
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 130/30000: mean batch inertia: 0.652096, ewa inertia: 0.756221
# Minibatch iteration 131/30000: mean batch inertia: 0.631060, ewa inertia: 0.755387
# Minibatch iteration 132/30000: mean batch inertia: 0.699017, ewa inertia: 0.755011
# Minibatch iteration 133/30000: mean batch inertia: 0.660945, ewa inertia: 0.754384
# Minibatch iteration 134/30000: mean batch inertia: 0.644079, ewa inertia: 0.753649
# Minibatch iteration 135/30000: mean batch inertia: 0.644128, ewa inertia: 0.752919
# Minibatch iteration 136/30000: mean batch inertia: 0.632144, ewa inertia: 0.752114
# Minibatch iteration 137/30000: mean batch inertia: 0.649794, ewa inertia: 0.751431
# Minibatch iteration 138/30000: mean batch inertia: 0.579634, ewa inertia: 0.750286
# Minibatch iteration 139/30000: mean batch inertia: 0.617141, ewa inertia: 0.749399
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 140/30000: mean batch inertia: 0.597778, ewa inertia: 0.748388
# Minibatch iteration 141/30000: mean batch inertia: 0.648652, ewa inertia: 0.747723
# Minibatch iteration 142/30000: mean batch inertia: 0.655881, ewa inertia: 0.747111
# Minibatch iteration 143/30000: mean batch inertia: 0.644733, ewa inertia: 0.746428
# Minibatch iteration 144/30000: mean batch inertia: 0.654778, ewa inertia: 0.745817
# Minibatch iteration 145/30000: mean batch inertia: 0.583188, ewa inertia: 0.744733
# Minibatch iteration 146/30000: mean batch inertia: 0.643088, ewa inertia: 0.744055
# Minibatch iteration 147/30000: mean batch inertia: 0.658660, ewa inertia: 0.743486
# Minibatch iteration 148/30000: mean batch inertia: 0.659073, ewa inertia: 0.742923
# Minibatch iteration 149/30000: mean batch inertia: 0.625753, ewa inertia: 0.742142
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 150/30000: mean batch inertia: 0.602607, ewa inertia: 0.741212
# Minibatch iteration 151/30000: mean batch inertia: 0.614107, ewa inertia: 0.740365
# Minibatch iteration 152/30000: mean batch inertia: 0.664529, ewa inertia: 0.739859
# Minibatch iteration 153/30000: mean batch inertia: 0.661836, ewa inertia: 0.739339
# Minibatch iteration 154/30000: mean batch inertia: 0.636350, ewa inertia: 0.738652
# Minibatch iteration 155/30000: mean batch inertia: 0.603089, ewa inertia: 0.737749
# Minibatch iteration 156/30000: mean batch inertia: 0.637010, ewa inertia: 0.737077
# Minibatch iteration 157/30000: mean batch inertia: 0.626507, ewa inertia: 0.736340
# Minibatch iteration 158/30000: mean batch inertia: 0.609205, ewa inertia: 0.735492
# Minibatch iteration 159/30000: mean batch inertia: 0.642371, ewa inertia: 0.734872
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 160/30000: mean batch inertia: 0.657325, ewa inertia: 0.734355
# Minibatch iteration 161/30000: mean batch inertia: 0.618813, ewa inertia: 0.733584
# Minibatch iteration 162/30000: mean batch inertia: 0.610769, ewa inertia: 0.732766
# Minibatch iteration 163/30000: mean batch inertia: 0.643238, ewa inertia: 0.732169
# Minibatch iteration 164/30000: mean batch inertia: 0.671874, ewa inertia: 0.731767
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 165/30000: mean batch inertia: 0.652729, ewa inertia: 0.731240
# Minibatch iteration 166/30000: mean batch inertia: 0.612608, ewa inertia: 0.730449
# Minibatch iteration 167/30000: mean batch inertia: 0.629987, ewa inertia: 0.729779
# Minibatch iteration 168/30000: mean batch inertia: 0.635406, ewa inertia: 0.729150
# Minibatch iteration 169/30000: mean batch inertia: 0.651291, ewa inertia: 0.728631
# Minibatch iteration 170/30000: mean batch inertia: 0.652105, ewa inertia: 0.728121
# Minibatch iteration 171/30000: mean batch inertia: 0.549318, ewa inertia: 0.726929
# Minibatch iteration 172/30000: mean batch inertia: 0.581731, ewa inertia: 0.725961
# Minibatch iteration 173/30000: mean batch inertia: 0.662960, ewa inertia: 0.725541
# Minibatch iteration 174/30000: mean batch inertia: 0.659916, ewa inertia: 0.725104
# Minibatch iteration 175/30000: mean batch inertia: 0.574031, ewa inertia: 0.724097
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 176/30000: mean batch inertia: 0.639447, ewa inertia: 0.723532
# Minibatch iteration 177/30000: mean batch inertia: 0.632229, ewa inertia: 0.722924
# Minibatch iteration 178/30000: mean batch inertia: 0.590008, ewa inertia: 0.722038
# Minibatch iteration 179/30000: mean batch inertia: 0.672100, ewa inertia: 0.721705
# Minibatch iteration 180/30000: mean batch inertia: 0.651722, ewa inertia: 0.721238
# Minibatch iteration 181/30000: mean batch inertia: 0.631014, ewa inertia: 0.720637
# Minibatch iteration 182/30000: mean batch inertia: 0.656726, ewa inertia: 0.720211
# Minibatch iteration 183/30000: mean batch inertia: 0.616206, ewa inertia: 0.719517
# Minibatch iteration 184/30000: mean batch inertia: 0.671282, ewa inertia: 0.719196
# Minibatch iteration 185/30000: mean batch inertia: 0.593056, ewa inertia: 0.718355
# Minibatch iteration 186/30000: mean batch inertia: 0.652545, ewa inertia: 0.717916
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 187/30000: mean batch inertia: 0.647944, ewa inertia: 0.717450
# Minibatch iteration 188/30000: mean batch inertia: 0.651976, ewa inertia: 0.717013
# Minibatch iteration 189/30000: mean batch inertia: 0.661094, ewa inertia: 0.716640
# Minibatch iteration 190/30000: mean batch inertia: 0.654667, ewa inertia: 0.716227
# Minibatch iteration 191/30000: mean batch inertia: 0.623287, ewa inertia: 0.715608
# Minibatch iteration 192/30000: mean batch inertia: 0.599523, ewa inertia: 0.714834
# Minibatch iteration 193/30000: mean batch inertia: 0.619931, ewa inertia: 0.714201
# Minibatch iteration 194/30000: mean batch inertia: 0.634733, ewa inertia: 0.713671
# Minibatch iteration 195/30000: mean batch inertia: 0.665019, ewa inertia: 0.713347
# Minibatch iteration 196/30000: mean batch inertia: 0.604795, ewa inertia: 0.712623
# Minibatch iteration 197/30000: mean batch inertia: 0.657199, ewa inertia: 0.712254
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 198/30000: mean batch inertia: 0.611338, ewa inertia: 0.711581
# Minibatch iteration 199/30000: mean batch inertia: 0.663805, ewa inertia: 0.711263
# Minibatch iteration 200/30000: mean batch inertia: 0.643023, ewa inertia: 0.710808
# Minibatch iteration 201/30000: mean batch inertia: 0.542232, ewa inertia: 0.709684
# Minibatch iteration 202/30000: mean batch inertia: 0.594464, ewa inertia: 0.708916
# Minibatch iteration 203/30000: mean batch inertia: 0.615513, ewa inertia: 0.708293
# Minibatch iteration 204/30000: mean batch inertia: 0.618438, ewa inertia: 0.707694
# Minibatch iteration 205/30000: mean batch inertia: 0.613083, ewa inertia: 0.707063
# Minibatch iteration 206/30000: mean batch inertia: 0.604424, ewa inertia: 0.706379
# Minibatch iteration 207/30000: mean batch inertia: 0.630258, ewa inertia: 0.705872
# Minibatch iteration 208/30000: mean batch inertia: 0.665808, ewa inertia: 0.705605
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 209/30000: mean batch inertia: 0.647986, ewa inertia: 0.705220
# Minibatch iteration 210/30000: mean batch inertia: 0.658534, ewa inertia: 0.704909
# Minibatch iteration 211/30000: mean batch inertia: 0.644956, ewa inertia: 0.704510
# Minibatch iteration 212/30000: mean batch inertia: 0.613345, ewa inertia: 0.703902
# Minibatch iteration 213/30000: mean batch inertia: 0.611648, ewa inertia: 0.703287
# Minibatch iteration 214/30000: mean batch inertia: 0.606957, ewa inertia: 0.702645
# Minibatch iteration 215/30000: mean batch inertia: 0.645227, ewa inertia: 0.702262
# Minibatch iteration 216/30000: mean batch inertia: 0.688816, ewa inertia: 0.702172
# Minibatch iteration 217/30000: mean batch inertia: 0.632561, ewa inertia: 0.701708
# Minibatch iteration 218/30000: mean batch inertia: 0.571806, ewa inertia: 0.700842
# Minibatch iteration 219/30000: mean batch inertia: 0.640833, ewa inertia: 0.700442
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 220/30000: mean batch inertia: 0.605305, ewa inertia: 0.699808
# Minibatch iteration 221/30000: mean batch inertia: 0.625588, ewa inertia: 0.699313
# Minibatch iteration 222/30000: mean batch inertia: 0.624298, ewa inertia: 0.698813
# Minibatch iteration 223/30000: mean batch inertia: 0.642178, ewa inertia: 0.698435
# Minibatch iteration 224/30000: mean batch inertia: 0.669259, ewa inertia: 0.698241
# Minibatch iteration 225/30000: mean batch inertia: 0.570032, ewa inertia: 0.697386
# Minibatch iteration 226/30000: mean batch inertia: 0.662181, ewa inertia: 0.697152
# Minibatch iteration 227/30000: mean batch inertia: 0.645698, ewa inertia: 0.696809
# Minibatch iteration 228/30000: mean batch inertia: 0.621099, ewa inertia: 0.696304
# Minibatch iteration 229/30000: mean batch inertia: 0.625930, ewa inertia: 0.695835
# Minibatch iteration 230/30000: mean batch inertia: 0.579816, ewa inertia: 0.695061
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 231/30000: mean batch inertia: 0.646315, ewa inertia: 0.694736
# Minibatch iteration 232/30000: mean batch inertia: 0.650505, ewa inertia: 0.694441
# Minibatch iteration 233/30000: mean batch inertia: 0.637772, ewa inertia: 0.694064
# Minibatch iteration 234/30000: mean batch inertia: 0.619239, ewa inertia: 0.693565
# Minibatch iteration 235/30000: mean batch inertia: 0.604329, ewa inertia: 0.692970
# Minibatch iteration 236/30000: mean batch inertia: 0.661371, ewa inertia: 0.692759
# Minibatch iteration 237/30000: mean batch inertia: 0.663773, ewa inertia: 0.692566
# Minibatch iteration 238/30000: mean batch inertia: 0.645964, ewa inertia: 0.692255
# Minibatch iteration 239/30000: mean batch inertia: 0.607820, ewa inertia: 0.691693
# Minibatch iteration 240/30000: mean batch inertia: 0.568793, ewa inertia: 0.690873
# Minibatch iteration 241/30000: mean batch inertia: 0.624401, ewa inertia: 0.690430
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 242/30000: mean batch inertia: 0.675062, ewa inertia: 0.690328
# Minibatch iteration 243/30000: mean batch inertia: 0.595667, ewa inertia: 0.689697
# Minibatch iteration 244/30000: mean batch inertia: 0.640205, ewa inertia: 0.689367
# Minibatch iteration 245/30000: mean batch inertia: 0.602370, ewa inertia: 0.688787
# Minibatch iteration 246/30000: mean batch inertia: 0.629781, ewa inertia: 0.688393
# Minibatch iteration 247/30000: mean batch inertia: 0.605339, ewa inertia: 0.687840
# Minibatch iteration 248/30000: mean batch inertia: 0.649332, ewa inertia: 0.687583
# Minibatch iteration 249/30000: mean batch inertia: 0.593108, ewa inertia: 0.686953
# Minibatch iteration 250/30000: mean batch inertia: 0.598199, ewa inertia: 0.686361
# Minibatch iteration 251/30000: mean batch inertia: 0.625997, ewa inertia: 0.685959
# Minibatch iteration 252/30000: mean batch inertia: 0.628010, ewa inertia: 0.685573
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 253/30000: mean batch inertia: 0.668296, ewa inertia: 0.685458
# Minibatch iteration 254/30000: mean batch inertia: 0.585290, ewa inertia: 0.684790
# Minibatch iteration 255/30000: mean batch inertia: 0.640533, ewa inertia: 0.684495
# Minibatch iteration 256/30000: mean batch inertia: 0.636749, ewa inertia: 0.684176
# Minibatch iteration 257/30000: mean batch inertia: 0.648115, ewa inertia: 0.683936
# Minibatch iteration 258/30000: mean batch inertia: 0.616700, ewa inertia: 0.683488
# Minibatch iteration 259/30000: mean batch inertia: 0.621833, ewa inertia: 0.683077
# Minibatch iteration 260/30000: mean batch inertia: 0.616521, ewa inertia: 0.682633
# Minibatch iteration 261/30000: mean batch inertia: 0.653498, ewa inertia: 0.682439
# Minibatch iteration 262/30000: mean batch inertia: 0.667795, ewa inertia: 0.682341
# Minibatch iteration 263/30000: mean batch inertia: 0.635211, ewa inertia: 0.682027
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 264/30000: mean batch inertia: 0.609373, ewa inertia: 0.681543
# Minibatch iteration 265/30000: mean batch inertia: 0.623503, ewa inertia: 0.681156
# Minibatch iteration 266/30000: mean batch inertia: 0.627611, ewa inertia: 0.680799
# Minibatch iteration 267/30000: mean batch inertia: 0.630781, ewa inertia: 0.680465
# Minibatch iteration 268/30000: mean batch inertia: 0.655823, ewa inertia: 0.680301
# Minibatch iteration 269/30000: mean batch inertia: 0.560885, ewa inertia: 0.679505
# Minibatch iteration 270/30000: mean batch inertia: 0.610427, ewa inertia: 0.679045
# Minibatch iteration 271/30000: mean batch inertia: 0.583926, ewa inertia: 0.678410
# Minibatch iteration 272/30000: mean batch inertia: 0.665448, ewa inertia: 0.678324
# Minibatch iteration 273/30000: mean batch inertia: 0.621872, ewa inertia: 0.677948
# Minibatch iteration 274/30000: mean batch inertia: 0.592949, ewa inertia: 0.677381
# Minibatch iteration 275/30000: mean batch inertia: 0.635092, ewa inertia: 0.677099
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 276/30000: mean batch inertia: 0.606237, ewa inertia: 0.676627
# Minibatch iteration 277/30000: mean batch inertia: 0.607923, ewa inertia: 0.676169
# Minibatch iteration 278/30000: mean batch inertia: 0.653925, ewa inertia: 0.676020
# Minibatch iteration 279/30000: mean batch inertia: 0.677167, ewa inertia: 0.676028
# Minibatch iteration 280/30000: mean batch inertia: 0.644524, ewa inertia: 0.675818
# Minibatch iteration 281/30000: mean batch inertia: 0.590930, ewa inertia: 0.675252
# Minibatch iteration 282/30000: mean batch inertia: 0.662024, ewa inertia: 0.675164
# Minibatch iteration 283/30000: mean batch inertia: 0.619989, ewa inertia: 0.674796
# Minibatch iteration 284/30000: mean batch inertia: 0.607077, ewa inertia: 0.674345
# Minibatch iteration 285/30000: mean batch inertia: 0.538620, ewa inertia: 0.673440
# Minibatch iteration 286/30000: mean batch inertia: 0.672835, ewa inertia: 0.673436
# Minibatch iteration 287/30000: mean batch inertia: 0.597073, ewa inertia: 0.672927
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 288/30000: mean batch inertia: 0.664660, ewa inertia: 0.672872
# Minibatch iteration 289/30000: mean batch inertia: 0.616600, ewa inertia: 0.672497
# Minibatch iteration 290/30000: mean batch inertia: 0.632158, ewa inertia: 0.672228
# Minibatch iteration 291/30000: mean batch inertia: 0.613872, ewa inertia: 0.671839
# Minibatch iteration 292/30000: mean batch inertia: 0.632624, ewa inertia: 0.671577
# Minibatch iteration 293/30000: mean batch inertia: 0.566744, ewa inertia: 0.670878
# Minibatch iteration 294/30000: mean batch inertia: 0.618666, ewa inertia: 0.670530
# Minibatch iteration 295/30000: mean batch inertia: 0.602471, ewa inertia: 0.670077
# Minibatch iteration 296/30000: mean batch inertia: 0.645113, ewa inertia: 0.669910
# Minibatch iteration 297/30000: mean batch inertia: 0.649062, ewa inertia: 0.669771
# Minibatch iteration 298/30000: mean batch inertia: 0.648003, ewa inertia: 0.669626
# Minibatch iteration 299/30000: mean batch inertia: 0.597564, ewa inertia: 0.669146
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 300/30000: mean batch inertia: 0.647779, ewa inertia: 0.669003
# Minibatch iteration 301/30000: mean batch inertia: 0.576481, ewa inertia: 0.668386
# Minibatch iteration 302/30000: mean batch inertia: 0.632621, ewa inertia: 0.668148
# Minibatch iteration 303/30000: mean batch inertia: 0.646242, ewa inertia: 0.668002
# Minibatch iteration 304/30000: mean batch inertia: 0.604568, ewa inertia: 0.667579
# Minibatch iteration 305/30000: mean batch inertia: 0.618302, ewa inertia: 0.667251
# Minibatch iteration 306/30000: mean batch inertia: 0.607482, ewa inertia: 0.666852
# Minibatch iteration 307/30000: mean batch inertia: 0.574568, ewa inertia: 0.666237
# Minibatch iteration 308/30000: mean batch inertia: 0.564934, ewa inertia: 0.665562
# Minibatch iteration 309/30000: mean batch inertia: 0.588761, ewa inertia: 0.665050
# Minibatch iteration 310/30000: mean batch inertia: 0.635628, ewa inertia: 0.664853
# Minibatch iteration 311/30000: mean batch inertia: 0.604723, ewa inertia: 0.664453
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 312/30000: mean batch inertia: 0.632750, ewa inertia: 0.664241
# Minibatch iteration 313/30000: mean batch inertia: 0.587806, ewa inertia: 0.663732
# Minibatch iteration 314/30000: mean batch inertia: 0.605536, ewa inertia: 0.663344
# Minibatch iteration 315/30000: mean batch inertia: 0.524008, ewa inertia: 0.662415
# Minibatch iteration 316/30000: mean batch inertia: 0.596677, ewa inertia: 0.661977
# Minibatch iteration 317/30000: mean batch inertia: 0.654299, ewa inertia: 0.661925
# Minibatch iteration 318/30000: mean batch inertia: 0.620665, ewa inertia: 0.661650
# Minibatch iteration 319/30000: mean batch inertia: 0.635932, ewa inertia: 0.661479
# Minibatch iteration 320/30000: mean batch inertia: 0.621105, ewa inertia: 0.661210
# Minibatch iteration 321/30000: mean batch inertia: 0.648196, ewa inertia: 0.661123
# Minibatch iteration 322/30000: mean batch inertia: 0.642345, ewa inertia: 0.660998
# Minibatch iteration 323/30000: mean batch inertia: 0.643415, ewa inertia: 0.660881
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 324/30000: mean batch inertia: 0.639582, ewa inertia: 0.660739
# Minibatch iteration 325/30000: mean batch inertia: 0.559733, ewa inertia: 0.660065
# Minibatch iteration 326/30000: mean batch inertia: 0.620838, ewa inertia: 0.659804
# Minibatch iteration 327/30000: mean batch inertia: 0.654099, ewa inertia: 0.659766
# Minibatch iteration 328/30000: mean batch inertia: 0.617609, ewa inertia: 0.659485
# Minibatch iteration 329/30000: mean batch inertia: 0.597139, ewa inertia: 0.659069
# Minibatch iteration 330/30000: mean batch inertia: 0.576545, ewa inertia: 0.658519
# Minibatch iteration 331/30000: mean batch inertia: 0.694534, ewa inertia: 0.658759
# Minibatch iteration 332/30000: mean batch inertia: 0.589928, ewa inertia: 0.658300
# Minibatch iteration 333/30000: mean batch inertia: 0.645811, ewa inertia: 0.658217
# Minibatch iteration 334/30000: mean batch inertia: 0.590969, ewa inertia: 0.657769
# Minibatch iteration 335/30000: mean batch inertia: 0.627377, ewa inertia: 0.657566
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 336/30000: mean batch inertia: 0.613110, ewa inertia: 0.657270
# Minibatch iteration 337/30000: mean batch inertia: 0.614085, ewa inertia: 0.656982
# Minibatch iteration 338/30000: mean batch inertia: 0.627094, ewa inertia: 0.656783
# Minibatch iteration 339/30000: mean batch inertia: 0.613666, ewa inertia: 0.656495
# Minibatch iteration 340/30000: mean batch inertia: 0.573214, ewa inertia: 0.655940
# Minibatch iteration 341/30000: mean batch inertia: 0.642592, ewa inertia: 0.655851
# Minibatch iteration 342/30000: mean batch inertia: 0.636149, ewa inertia: 0.655720
# Minibatch iteration 343/30000: mean batch inertia: 0.600581, ewa inertia: 0.655352
# Minibatch iteration 344/30000: mean batch inertia: 0.626600, ewa inertia: 0.655160
# Minibatch iteration 345/30000: mean batch inertia: 0.562853, ewa inertia: 0.654545
# Minibatch iteration 346/30000: mean batch inertia: 0.569781, ewa inertia: 0.653980
# Minibatch iteration 347/30000: mean batch inertia: 0.645288, ewa inertia: 0.653922
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 348/30000: mean batch inertia: 0.588675, ewa inertia: 0.653487
# Minibatch iteration 349/30000: mean batch inertia: 0.614909, ewa inertia: 0.653230
# Minibatch iteration 350/30000: mean batch inertia: 0.584349, ewa inertia: 0.652771
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 351/30000: mean batch inertia: 0.629958, ewa inertia: 0.652619
# Minibatch iteration 352/30000: mean batch inertia: 0.623361, ewa inertia: 0.652424
# Minibatch iteration 353/30000: mean batch inertia: 0.587124, ewa inertia: 0.651988
# Minibatch iteration 354/30000: mean batch inertia: 0.591823, ewa inertia: 0.651587
# Minibatch iteration 355/30000: mean batch inertia: 0.571171, ewa inertia: 0.651051
# Minibatch iteration 356/30000: mean batch inertia: 0.631624, ewa inertia: 0.650922
# Minibatch iteration 357/30000: mean batch inertia: 0.582431, ewa inertia: 0.650465
# Minibatch iteration 358/30000: mean batch inertia: 0.606979, ewa inertia: 0.650175
# Minibatch iteration 359/30000: mean batch inertia: 0.622593, ewa inertia: 0.649991
# Minibatch iteration 360/30000: mean batch inertia: 0.644223, ewa inertia: 0.649953
# Minibatch iteration 361/30000: mean batch inertia: 0.633583, ewa inertia: 0.649844
# Minibatch iteration 362/30000: mean batch inertia: 0.556189, ewa inertia: 0.649219
# Minibatch iteration 363/30000: mean batch inertia: 0.574151, ewa inertia: 0.648719
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 364/30000: mean batch inertia: 0.627296, ewa inertia: 0.648576
# Minibatch iteration 365/30000: mean batch inertia: 0.649037, ewa inertia: 0.648579
# Minibatch iteration 366/30000: mean batch inertia: 0.587678, ewa inertia: 0.648173
# Minibatch iteration 367/30000: mean batch inertia: 0.669940, ewa inertia: 0.648318
# Minibatch iteration 368/30000: mean batch inertia: 0.610014, ewa inertia: 0.648063
# Minibatch iteration 369/30000: mean batch inertia: 0.636829, ewa inertia: 0.647988
# Minibatch iteration 370/30000: mean batch inertia: 0.659073, ewa inertia: 0.648062
# Minibatch iteration 371/30000: mean batch inertia: 0.619206, ewa inertia: 0.647869
# Minibatch iteration 372/30000: mean batch inertia: 0.621245, ewa inertia: 0.647692
# Minibatch iteration 373/30000: mean batch inertia: 0.578976, ewa inertia: 0.647234
# Minibatch iteration 374/30000: mean batch inertia: 0.650551, ewa inertia: 0.647256
# Minibatch iteration 375/30000: mean batch inertia: 0.603908, ewa inertia: 0.646967
# Minibatch iteration 376/30000: mean batch inertia: 0.543457, ewa inertia: 0.646277
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 377/30000: mean batch inertia: 0.558056, ewa inertia: 0.645689
# Minibatch iteration 378/30000: mean batch inertia: 0.578992, ewa inertia: 0.645244
# Minibatch iteration 379/30000: mean batch inertia: 0.588692, ewa inertia: 0.644867
# Minibatch iteration 380/30000: mean batch inertia: 0.657080, ewa inertia: 0.644949
# Minibatch iteration 381/30000: mean batch inertia: 0.652025, ewa inertia: 0.644996
# Minibatch iteration 382/30000: mean batch inertia: 0.628164, ewa inertia: 0.644884
# Minibatch iteration 383/30000: mean batch inertia: 0.672216, ewa inertia: 0.645066
# Minibatch iteration 384/30000: mean batch inertia: 0.592572, ewa inertia: 0.644716
# Minibatch iteration 385/30000: mean batch inertia: 0.664965, ewa inertia: 0.644851
# Minibatch iteration 386/30000: mean batch inertia: 0.629158, ewa inertia: 0.644746
# Minibatch iteration 387/30000: mean batch inertia: 0.657651, ewa inertia: 0.644832
# Minibatch iteration 388/30000: mean batch inertia: 0.630396, ewa inertia: 0.644736
# Minibatch iteration 389/30000: mean batch inertia: 0.598141, ewa inertia: 0.644425
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 390/30000: mean batch inertia: 0.627637, ewa inertia: 0.644313
# Minibatch iteration 391/30000: mean batch inertia: 0.643167, ewa inertia: 0.644306
# Minibatch iteration 392/30000: mean batch inertia: 0.612486, ewa inertia: 0.644094
# Minibatch iteration 393/30000: mean batch inertia: 0.596776, ewa inertia: 0.643778
# Minibatch iteration 394/30000: mean batch inertia: 0.625534, ewa inertia: 0.643657
# Minibatch iteration 395/30000: mean batch inertia: 0.641512, ewa inertia: 0.643642
# Minibatch iteration 396/30000: mean batch inertia: 0.625397, ewa inertia: 0.643521
# Minibatch iteration 397/30000: mean batch inertia: 0.616745, ewa inertia: 0.643342
# Minibatch iteration 398/30000: mean batch inertia: 0.541761, ewa inertia: 0.642665
# Minibatch iteration 399/30000: mean batch inertia: 0.590770, ewa inertia: 0.642319
# Minibatch iteration 400/30000: mean batch inertia: 0.632019, ewa inertia: 0.642250
# Minibatch iteration 401/30000: mean batch inertia: 0.633094, ewa inertia: 0.642189
# Minibatch iteration 402/30000: mean batch inertia: 0.664677, ewa inertia: 0.642339
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 403/30000: mean batch inertia: 0.673640, ewa inertia: 0.642548
# Minibatch iteration 404/30000: mean batch inertia: 0.625855, ewa inertia: 0.642437
# Minibatch iteration 405/30000: mean batch inertia: 0.622004, ewa inertia: 0.642300
# Minibatch iteration 406/30000: mean batch inertia: 0.561608, ewa inertia: 0.641763
# Minibatch iteration 407/30000: mean batch inertia: 0.629117, ewa inertia: 0.641678
# Minibatch iteration 408/30000: mean batch inertia: 0.601590, ewa inertia: 0.641411
# Minibatch iteration 409/30000: mean batch inertia: 0.626420, ewa inertia: 0.641311
# Minibatch iteration 410/30000: mean batch inertia: 0.558772, ewa inertia: 0.640761
# Minibatch iteration 411/30000: mean batch inertia: 0.637443, ewa inertia: 0.640739
# Minibatch iteration 412/30000: mean batch inertia: 0.669097, ewa inertia: 0.640928
# Minibatch iteration 413/30000: mean batch inertia: 0.635700, ewa inertia: 0.640893
# Minibatch iteration 414/30000: mean batch inertia: 0.660021, ewa inertia: 0.641020
# Minibatch iteration 415/30000: mean batch inertia: 0.671564, ewa inertia: 0.641224
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 416/30000: mean batch inertia: 0.610874, ewa inertia: 0.641022
# Minibatch iteration 417/30000: mean batch inertia: 0.597353, ewa inertia: 0.640731
# Minibatch iteration 418/30000: mean batch inertia: 0.622400, ewa inertia: 0.640608
# Minibatch iteration 419/30000: mean batch inertia: 0.622395, ewa inertia: 0.640487
# Minibatch iteration 420/30000: mean batch inertia: 0.622710, ewa inertia: 0.640368
# Minibatch iteration 421/30000: mean batch inertia: 0.557889, ewa inertia: 0.639819
# Minibatch iteration 422/30000: mean batch inertia: 0.604551, ewa inertia: 0.639583
# Minibatch iteration 423/30000: mean batch inertia: 0.588175, ewa inertia: 0.639241
# Minibatch iteration 424/30000: mean batch inertia: 0.595606, ewa inertia: 0.638950
# Minibatch iteration 425/30000: mean batch inertia: 0.589373, ewa inertia: 0.638619
# Minibatch iteration 426/30000: mean batch inertia: 0.559690, ewa inertia: 0.638093
# Minibatch iteration 427/30000: mean batch inertia: 0.545711, ewa inertia: 0.637477
# Minibatch iteration 428/30000: mean batch inertia: 0.615368, ewa inertia: 0.637330
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 429/30000: mean batch inertia: 0.657224, ewa inertia: 0.637463
# Minibatch iteration 430/30000: mean batch inertia: 0.608613, ewa inertia: 0.637270
# Minibatch iteration 431/30000: mean batch inertia: 0.596198, ewa inertia: 0.636996
# Minibatch iteration 432/30000: mean batch inertia: 0.650819, ewa inertia: 0.637089
# Minibatch iteration 433/30000: mean batch inertia: 0.630450, ewa inertia: 0.637044
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 434/30000: mean batch inertia: 0.643899, ewa inertia: 0.637090
# Minibatch iteration 435/30000: mean batch inertia: 0.611278, ewa inertia: 0.636918
# Minibatch iteration 436/30000: mean batch inertia: 0.589708, ewa inertia: 0.636603
# Minibatch iteration 437/30000: mean batch inertia: 0.609182, ewa inertia: 0.636420
# Minibatch iteration 438/30000: mean batch inertia: 0.591005, ewa inertia: 0.636118
# Minibatch iteration 439/30000: mean batch inertia: 0.566855, ewa inertia: 0.635656
# Minibatch iteration 440/30000: mean batch inertia: 0.608349, ewa inertia: 0.635474
# Minibatch iteration 441/30000: mean batch inertia: 0.594437, ewa inertia: 0.635200
# Minibatch iteration 442/30000: mean batch inertia: 0.588744, ewa inertia: 0.634891
# Minibatch iteration 443/30000: mean batch inertia: 0.584388, ewa inertia: 0.634554
# Minibatch iteration 444/30000: mean batch inertia: 0.589615, ewa inertia: 0.634254
# Minibatch iteration 445/30000: mean batch inertia: 0.586237, ewa inertia: 0.633934
# Minibatch iteration 446/30000: mean batch inertia: 0.600306, ewa inertia: 0.633710
# Minibatch iteration 447/30000: mean batch inertia: 0.635822, ewa inertia: 0.633724
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 448/30000: mean batch inertia: 0.633347, ewa inertia: 0.633722
# Minibatch iteration 449/30000: mean batch inertia: 0.664076, ewa inertia: 0.633924
# Minibatch iteration 450/30000: mean batch inertia: 0.568822, ewa inertia: 0.633490
# Minibatch iteration 451/30000: mean batch inertia: 0.548737, ewa inertia: 0.632925
# Minibatch iteration 452/30000: mean batch inertia: 0.628581, ewa inertia: 0.632896
# Minibatch iteration 453/30000: mean batch inertia: 0.631630, ewa inertia: 0.632888
# Minibatch iteration 454/30000: mean batch inertia: 0.641211, ewa inertia: 0.632943
# Minibatch iteration 455/30000: mean batch inertia: 0.568841, ewa inertia: 0.632516
# Minibatch iteration 456/30000: mean batch inertia: 0.617820, ewa inertia: 0.632418
# Minibatch iteration 457/30000: mean batch inertia: 0.597516, ewa inertia: 0.632185
# Minibatch iteration 458/30000: mean batch inertia: 0.594777, ewa inertia: 0.631936
# Minibatch iteration 459/30000: mean batch inertia: 0.558760, ewa inertia: 0.631448
# Minibatch iteration 460/30000: mean batch inertia: 0.564809, ewa inertia: 0.631004
# Minibatch iteration 461/30000: mean batch inertia: 0.641416, ewa inertia: 0.631073
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 462/30000: mean batch inertia: 0.608639, ewa inertia: 0.630924
# Minibatch iteration 463/30000: mean batch inertia: 0.636897, ewa inertia: 0.630963
# Minibatch iteration 464/30000: mean batch inertia: 0.599720, ewa inertia: 0.630755
# Minibatch iteration 465/30000: mean batch inertia: 0.613612, ewa inertia: 0.630641
# Minibatch iteration 466/30000: mean batch inertia: 0.572035, ewa inertia: 0.630250
# Minibatch iteration 467/30000: mean batch inertia: 0.620529, ewa inertia: 0.630185
# Minibatch iteration 468/30000: mean batch inertia: 0.613664, ewa inertia: 0.630075
# Minibatch iteration 469/30000: mean batch inertia: 0.583433, ewa inertia: 0.629764
# Minibatch iteration 470/30000: mean batch inertia: 0.609308, ewa inertia: 0.629628
# Minibatch iteration 471/30000: mean batch inertia: 0.620477, ewa inertia: 0.629567
# Minibatch iteration 472/30000: mean batch inertia: 0.637770, ewa inertia: 0.629622
# Minibatch iteration 473/30000: mean batch inertia: 0.640680, ewa inertia: 0.629695
# Minibatch iteration 474/30000: mean batch inertia: 0.619129, ewa inertia: 0.629625
# Minibatch iteration 475/30000: mean batch inertia: 0.609532, ewa inertia: 0.629491
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 476/30000: mean batch inertia: 0.642831, ewa inertia: 0.629580
# Minibatch iteration 477/30000: mean batch inertia: 0.578052, ewa inertia: 0.629236
# Minibatch iteration 478/30000: mean batch inertia: 0.625334, ewa inertia: 0.629210
# Minibatch iteration 479/30000: mean batch inertia: 0.617109, ewa inertia: 0.629130
# Minibatch iteration 480/30000: mean batch inertia: 0.584423, ewa inertia: 0.628832
# Minibatch iteration 481/30000: mean batch inertia: 0.567834, ewa inertia: 0.628425
# Minibatch iteration 482/30000: mean batch inertia: 0.614239, ewa inertia: 0.628330
# Minibatch iteration 483/30000: mean batch inertia: 0.576645, ewa inertia: 0.627986
# Minibatch iteration 484/30000: mean batch inertia: 0.554308, ewa inertia: 0.627495
# Minibatch iteration 485/30000: mean batch inertia: 0.644957, ewa inertia: 0.627611
# Minibatch iteration 486/30000: mean batch inertia: 0.570931, ewa inertia: 0.627233
# Minibatch iteration 487/30000: mean batch inertia: 0.598875, ewa inertia: 0.627044
# Minibatch iteration 488/30000: mean batch inertia: 0.633038, ewa inertia: 0.627084
# Minibatch iteration 489/30000: mean batch inertia: 0.640043, ewa inertia: 0.627170
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 490/30000: mean batch inertia: 0.574953, ewa inertia: 0.626822
# Minibatch iteration 491/30000: mean batch inertia: 0.591552, ewa inertia: 0.626587
# Minibatch iteration 492/30000: mean batch inertia: 0.601017, ewa inertia: 0.626417
# Minibatch iteration 493/30000: mean batch inertia: 0.641574, ewa inertia: 0.626518
# Minibatch iteration 494/30000: mean batch inertia: 0.634413, ewa inertia: 0.626570
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 495/30000: mean batch inertia: 0.592174, ewa inertia: 0.626341
# Minibatch iteration 496/30000: mean batch inertia: 0.627795, ewa inertia: 0.626351
# Minibatch iteration 497/30000: mean batch inertia: 0.598934, ewa inertia: 0.626168
# Minibatch iteration 498/30000: mean batch inertia: 0.594154, ewa inertia: 0.625955
# Minibatch iteration 499/30000: mean batch inertia: 0.608624, ewa inertia: 0.625839
# Minibatch iteration 500/30000: mean batch inertia: 0.578128, ewa inertia: 0.625521
# Minibatch iteration 501/30000: mean batch inertia: 0.599893, ewa inertia: 0.625350
# Minibatch iteration 502/30000: mean batch inertia: 0.607693, ewa inertia: 0.625233
# Minibatch iteration 503/30000: mean batch inertia: 0.574960, ewa inertia: 0.624897
# Minibatch iteration 504/30000: mean batch inertia: 0.613360, ewa inertia: 0.624820
# Minibatch iteration 505/30000: mean batch inertia: 0.619846, ewa inertia: 0.624787
# Minibatch iteration 506/30000: mean batch inertia: 0.687341, ewa inertia: 0.625204
# Minibatch iteration 507/30000: mean batch inertia: 0.601037, ewa inertia: 0.625043
# Minibatch iteration 508/30000: mean batch inertia: 0.653258, ewa inertia: 0.625231
# Minibatch iteration 509/30000: mean batch inertia: 0.574386, ewa inertia: 0.624892
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 510/30000: mean batch inertia: 0.633618, ewa inertia: 0.624950
# Minibatch iteration 511/30000: mean batch inertia: 0.643770, ewa inertia: 0.625076
# Minibatch iteration 512/30000: mean batch inertia: 0.653475, ewa inertia: 0.625265
# Minibatch iteration 513/30000: mean batch inertia: 0.670790, ewa inertia: 0.625569
# Minibatch iteration 514/30000: mean batch inertia: 0.618902, ewa inertia: 0.625524
# Minibatch iteration 515/30000: mean batch inertia: 0.561950, ewa inertia: 0.625101
# Converged (lack of improvement in inertia) at iteration 515/30000
# Computing label assignment and total inertia
# Computing label assignment and total inertia

# %% [markdown]
# #### Examine some results

# %%
index = 8
sentence_index = np.where(y_hat==index)[0]
for i in sentence_index:
    print('-----------------------------------------------------------------')
    print(sentences[i])
    print('\n')
# Out:
# -----------------------------------------------------------------
# Counsel for Appellant: Pro Se
#
#
# -----------------------------------------------------------------
# Counsel for Appellee: Oldiais Ngirakelau
#
#
# -----------------------------------------------------------------
# Counsel for the 1st Respondent: E. Veretawatini: Veretawatini Esq.
#
#
# -----------------------------------------------------------------
# Counsel: Appellants in Person
#
#
# -----------------------------------------------------------------
# Counsel: Appellants in Person
#
#
# -----------------------------------------------------------------
# Counsel: Appellant in person
#
#
# -----------------------------------------------------------------
# Counsel: S. Maharaj for the Appellant
#
#
# -----------------------------------------------------------------
# Counsel: Appellant in Person
#
#
# -----------------------------------------------------------------
# Counsel for Appellant No.
#
#
# -----------------------------------------------------------------
# Counselor both of Lalovaea.
#
#
# -----------------------------------------------------------------
# Counsel: R Papali’i for applicants
#
#
# -----------------------------------------------------------------
# Counsel: Birimaka Tekanene for appellant
#
#
# -----------------------------------------------------------------
# COUNSEL : Applicant in Person
#
#
# -----------------------------------------------------------------
# Counsel for the Appellant: E. Molbaleh
#
#
# -----------------------------------------------------------------
# Counsel: Appellant in Person

# %%
index = 33
sentence_index = np.where(y_hat==index)[0]
for i in sentence_index:
    print('-----------------------------------------------------------------')
    print(sentences[i])
    print('\n')
# Out:
# -----------------------------------------------------------------
# For the following reasons, the decision of the Land Court is AFFIRMED.
#
#
# -----------------------------------------------------------------
# He gave two principal reasons for his decision:
#
#
# -----------------------------------------------------------------
# The learned trial Magistrate gave the following principal reasons for his decision:-
#
#
# -----------------------------------------------------------------
# The court's reasons follow.
#
#
# -----------------------------------------------------------------
# VERDICT AND REASONS
#
#
# -----------------------------------------------------------------
# [4] These are my reasons.
#
#
# -----------------------------------------------------------------
# I now give my reasons.
#
#
# -----------------------------------------------------------------
# REASONS FOR JUDGMENT OF THE COURT
#
#
# -----------------------------------------------------------------
#  REASONS FOR DECISION
#
#
# -----------------------------------------------------------------
# Reasonable cause of action.
#
#
# -----------------------------------------------------------------
# I have reached that conclusion for three reasons.
#
#
# -----------------------------------------------------------------
# Reason for the failure
#
#
# -----------------------------------------------------------------
# The reasons given included:
#
#
# -----------------------------------------------------------------
# Reasons
#
#
# -----------------------------------------------------------------
# The reason for this delay became obvious later.
#
#
# -----------------------------------------------------------------
# You are required to give merely your opinion but not the reasons for your opinion.
#
#
# -----------------------------------------------------------------
# You will be asked individually for your opinion and are not required to give reasons for your opinion.
#
#
# -----------------------------------------------------------------
# The PSC gave detailed reasons for its decision.
#
#
# -----------------------------------------------------------------
# For these reasons, I grant the application.
#
#
# -----------------------------------------------------------------
# The grounds of the application were that-
#
#
# -----------------------------------------------------------------
# The reasons are contained in the Decision of the Court issued on 4th August.
#
#
# -----------------------------------------------------------------
#  (3) The Provincial Land Court gave reasons for its decision in a nine-page written judgment.
#
#
# -----------------------------------------------------------------
#  (3) failed to give reasons for its decision (para 17(d)).
#
#
# -----------------------------------------------------------------
# ... failed to give reasons for the said decision.
#
#
# -----------------------------------------------------------------
# The reasons follow.
#
#
# -----------------------------------------------------------------
# 5 The reasons for this decision now follow.
#
#
# -----------------------------------------------------------------
# The reason is plain enough.
#
#
# -----------------------------------------------------------------
# In his judgment, reasons for his decision have to be given.
#
#
# -----------------------------------------------------------------
# • CAUSE OF ACTION:
#
#
# -----------------------------------------------------------------
# REASONS FOR VERDICT
#
#
# -----------------------------------------------------------------
# These are my reasons for that verdict.

# %%
index = 34
sentence_index = np.where(y_hat==index)[0]
for i in sentence_index:
    print('-----------------------------------------------------------------')
    print(sentences[i])
    print('\n')
# Out:
# -----------------------------------------------------------------
# The courts are not intended by s. 10(1) to be independent of the law but independent within it.
#
#
# -----------------------------------------------------------------
# accepted self-serving testimonies and irrelevant documents presented by Appellee."
#
#
# -----------------------------------------------------------------
# One customary law was proven while the other was not.
#
#
# -----------------------------------------------------------------
# The Land Court's decision was not clearly erroneous and must be AFFIRMED.
#
#
# -----------------------------------------------------------------
# It is not capable of raising the material facts."
#
#
# -----------------------------------------------------------------
# Whether or not termination lawful
#
#
# -----------------------------------------------------------------
# In my view, the assessors' decision was not perverse.
#
#
# -----------------------------------------------------------------
# However, on count no.
#
#
# -----------------------------------------------------------------
# I also have no hesitation in rejecting the accused's denial on count no.
#
#
# -----------------------------------------------------------------
# • No steps have been taken by the defendant.
#
#
# -----------------------------------------------------------------
# There are no mitigating circumstances.
#
#
# -----------------------------------------------------------------
# Nor should Affidavits be bound together in a book.
#
#
# -----------------------------------------------------------------
# Mr Kurisaqila accepts that his material does not so deal.
#
#
# -----------------------------------------------------------------
# The movant bears the burden of showing a lack of triable issues of fact.
#
#
# -----------------------------------------------------------------
# The movant bears the burden of showing a lack of triable issues of fact.
#
#
# -----------------------------------------------------------------
# Skilling therefore offers Dungawin no support.
#
#
# -----------------------------------------------------------------
# It was filed too late.
#
#
# -----------------------------------------------------------------
# Dungawin did not file a response to this motion.
#
#
# -----------------------------------------------------------------
# Only Kalolaine was called to give evidence.
#
#
# -----------------------------------------------------------------
# They did not talk with any other boys.
#
#
# -----------------------------------------------------------------
#  (3) without consent
#
#
# -----------------------------------------------------------------
# was both irrational and unreasonable.
#
#
# -----------------------------------------------------------------
# It was not disputed.
#
#
# -----------------------------------------------------------------
# It was not disputed.
#
#
# -----------------------------------------------------------------
# The other Appellants decided to remain silent.
#
#
# -----------------------------------------------------------------
# The 3rd Appellant was unemployed.
#
#
# -----------------------------------------------------------------
# I do not consider that he was prejudiced by such waiver.
#
#
# -----------------------------------------------------------------
# His caution interview was not tendered.
#
#
# -----------------------------------------------------------------
# The two Appellants were present.
#
#
# -----------------------------------------------------------------
# There was no evidence of planning.
#
#
# -----------------------------------------------------------------
# There was no evidence of mens rea.
#
#
# -----------------------------------------------------------------
# I dismiss the claim.
#
#
# -----------------------------------------------------------------
# The hearing did not proceed so the matter was rescheduled for 25 September 2006.
#
#
# -----------------------------------------------------------------
# The Defendant apparently did not speak English.
#
#
# -----------------------------------------------------------------
# The engineering workshop was run from the Defendant’s land.
#
#
# -----------------------------------------------------------------
# The deposit should be returned if it has not already been done.
#
#
# -----------------------------------------------------------------
# I make no allowance for the interlocutory attendances.
#
#
# -----------------------------------------------------------------
# Mr. Leung did not object.
#
#
# -----------------------------------------------------------------
# The frankness of the Plaintiff’s answers, it must be said, did not impress me.
#
#
# -----------------------------------------------------------------
# There is no admission made in the record of interview.
#
#
# -----------------------------------------------------------------
# The Court and the defence do not carry that burden and onus.
#
#
# -----------------------------------------------------------------
# The application was granted.
#
#
# -----------------------------------------------------------------
# • The applicable tests are not in issue on this appeal, merely their application.
#
#
# -----------------------------------------------------------------
# The passage, with the omission of the reference to Wenlock v Moloney, bears repeating:
#
#
# -----------------------------------------------------------------
# It is not a final order within which the rights of parties have been determined.
#
#
# -----------------------------------------------------------------
# No such leave has been sought or granted.
#
#
# -----------------------------------------------------------------
# • You have no prior convictions.
#
#
# -----------------------------------------------------------------
# Miss Iteraera, prosecuting, did not oppose a fine.
#
#
# -----------------------------------------------------------------
#  No appearances for or by the Respondent and Co-Respondent
#
#
# -----------------------------------------------------------------
# The respondent and co-respondent were not present.
#
#
# -----------------------------------------------------------------
# And for the respondent, there is nothing left to be concerned with.
#
#
# -----------------------------------------------------------------
# The failure implies that the allegations are correct.
#
#
# -----------------------------------------------------------------
# This provision states and I quote: “65 A Unauthorized possession of ammunition
#
#
# -----------------------------------------------------------------
# The matter was not properly investigated.
#
#
# -----------------------------------------------------------------
# d. Mr. Naickar and Ashika were never alone in production office that day.
#
#
# -----------------------------------------------------------------
# f. Mr. Naickar and Ashika were never alone.
#
#
# -----------------------------------------------------------------
# However, he denied both charges as untrue.
#
#
# -----------------------------------------------------------------
# It appears that PW1 did not show any distress about the incidents.
#
#
# -----------------------------------------------------------------
# This where PW1 lacking credibility.
#
#
# -----------------------------------------------------------------
# PW2 under cross examination stated that the case was not properly investigated.
#
#
# -----------------------------------------------------------------
# Their evidence was not shaken in the course of cross examination.
#
#
# -----------------------------------------------------------------
# This was a one off failure with no consequences flowing.
#
#
# -----------------------------------------------------------------
# Luckily, the defendant did not force penetration.
#
#
# -----------------------------------------------------------------
#  [2] I decline the application.
#
#
# -----------------------------------------------------------------
#  (ii) Failure to consider case guidelines.
#
#
# -----------------------------------------------------------------
# "Held - Injunction refused.
#
#
# -----------------------------------------------------------------
# • Mr. Noal has no previous convictions.
#
#
# -----------------------------------------------------------------
# The offence was not planned; there was no use of a weapon to frighten X.
#
#
# -----------------------------------------------------------------
# Mr. Noal was not in a position of trust towards her.
#
#
# -----------------------------------------------------------------
# There were no lights.
#
#
# -----------------------------------------------------------------
# Her sister-in-law did not know about this and was not a party to the scheme.
#
#
# -----------------------------------------------------------------
#  (d) The use to which the money was put is questionable.
#
#
# -----------------------------------------------------------------
# It has not been pleaded.
#
#
# -----------------------------------------------------------------
# It was not pleaded and there was no warning of such a claim.
#
#
# -----------------------------------------------------------------
# Miss Tonga had agreed to stand by her submission and not call any evidence.
#
#
# -----------------------------------------------------------------
#  ➢ lack of prior conviction,
#
#
# -----------------------------------------------------------------
# Consequential loss which was not too remote was recoverable in an action for false imprisonment.
#
#
# -----------------------------------------------------------------
# Urgency has not been one of the hallmarks of this piece of litigation.
#
#
# -----------------------------------------------------------------
# Constable Sonasi could not recall that particular part of the incident.
#
#
# -----------------------------------------------------------------
# A wholly voluntary submission is insufficient.
#
#
# -----------------------------------------------------------------
# Aggravated damages should not be claimed as a discrete figure.
#
#
# -----------------------------------------------------------------
# I am not satisfied that this head of claim has been made out.
#
#
# -----------------------------------------------------------------
# But in equity that is not necessary so.
#
#
# -----------------------------------------------------------------
# It cannot evade this duty.
#
#
# -----------------------------------------------------------------
# Unfortunately National Housing Corporation has not been called to give evidence.
#
#
# -----------------------------------------------------------------
# On this point I agree with their Lordships that “remuneration” does not include severance payment.
#
#
# -----------------------------------------------------------------
# So I conclude there is no such risk.
#
#
# -----------------------------------------------------------------
# •  As later discovered, you were never released as ordered.
#
#
# -----------------------------------------------------------------
# The Court's order is quite clear and that has not been complied with.
#
#
# -----------------------------------------------------------------
# The Court had not made any such determination.
#
#
# -----------------------------------------------------------------
# It lacks bona fides.
#
#
# -----------------------------------------------------------------
# It was no use dilly-dallying and not taking the required steps within the time frame.
#
#
# -----------------------------------------------------------------
# 197 of 1973 FCA at p.2) counsel being away was not regarded as an excuse.
#
#
# -----------------------------------------------------------------
# 7 There was nothing in any of the previous documentation quantifying the claimants' alleged loss.
#
#
# -----------------------------------------------------------------
# Neither was the draft default judgment, subsequently granted by the Acting Registrar.
#
#
# -----------------------------------------------------------------
# I enter a non conviction.
#
#
# -----------------------------------------------------------------
# They did not operate beyond the boundaries they know of.
#
#
# -----------------------------------------------------------------
# There was no evidence of the Chiefs who heard the dispute.
#
#
# -----------------------------------------------------------------
# The fact that there was no reference to the Local Court was expected.
#
#
# -----------------------------------------------------------------
# Therefore, the first hurdle has not been proved.
#
#
# -----------------------------------------------------------------
# It was not a continues intrusion so as to require injunctive orders.
#
#
# -----------------------------------------------------------------
# Simply there would be no trial accorded him.
#
#
# -----------------------------------------------------------------
# There is no merit in his case.
#
#
# -----------------------------------------------------------------
# • Warrant of arrest not revoked.
#
#
# -----------------------------------------------------------------
# The mother was very angry.
#
#
# -----------------------------------------------------------------
# The accused made no reply.
#
#
# -----------------------------------------------------------------
# The first is the irregularity of the default judgment.
#
#
# -----------------------------------------------------------------
# No Reasonable Cause of Action
#
#
# -----------------------------------------------------------------
# • I find that the Plaintiff's claim lacks merit and doom to fail.
#
#
# -----------------------------------------------------------------
# The lady did not like this but was subjugated by the authority of your pastoral office.
#
#
# -----------------------------------------------------------------
# There are no exceptional circumstances warranting some other treatment.
#
#
# -----------------------------------------------------------------
# There is no suggestion of fraud here.
#
#
# -----------------------------------------------------------------
# Once rights are established by law they should not be disturbed.
#
#
# -----------------------------------------------------------------
# The defendants have no right to possession.
#
#
# -----------------------------------------------------------------
# The application is not opposed and leave is granted accordingly.
#
#
# -----------------------------------------------------------------
# The finding of illegality
#
#
# -----------------------------------------------------------------
# [35] The legal basis for the connection is not in issue.
#
#
# -----------------------------------------------------------------
# It would have made no profits.
#
#
# -----------------------------------------------------------------
# It would have had no business reputation to injure.
#
#
# -----------------------------------------------------------------
# (d) the judgment was obtained by fraud; or
#
#
# -----------------------------------------------------------------
# LAS 822 at Sisibia No.
#
#
# -----------------------------------------------------------------
# I will therefore treat the apology as neutral.
#
#
# -----------------------------------------------------------------
# Needless to say the plaintiff's ownership of Lot 24 (i.e.
#
#
# -----------------------------------------------------------------
# No cause has been shown on this ground.
#
#
# -----------------------------------------------------------------
# I am not unsympathetic with the plaintiffs.
#
#
# -----------------------------------------------------------------
# Answer: I did not instruct
#
#
# -----------------------------------------------------------------
# Question: You did not instruct?
#
#
# -----------------------------------------------------------------
# (i) The reason for the failure to file within time.
#
#
# -----------------------------------------------------------------
# Not surprisingly the Respondents in their affidavit in opposition have not exhibited such a letter.
#
#
# -----------------------------------------------------------------
# They are not modifiable by consent of the parties.
#
#
# -----------------------------------------------------------------
# (2) Nothing is said of what became of the Memorandum and the Ruling.
#
#
# -----------------------------------------------------------------
# The lateness was only 11 days in Avery v No.
#
#
# -----------------------------------------------------------------
# There is no evidence of any justification for dismissal on grounds of redundancy.
#
#
# -----------------------------------------------------------------
# Accordingly I publish these Reasons but do not at this stage make any order.
#
#
# -----------------------------------------------------------------
# [4] I have not yet given.
#
#
# -----------------------------------------------------------------
# The Respondent's version of the Appellant's banking procedures has not been challenged by any credible evidence to the contrary.
#
#
# -----------------------------------------------------------------
# Even the Appellant accepts that the audit is still in progress".
#
#
# -----------------------------------------------------------------
# The judge then gave some examples of these which I need not mention.
#
#
# -----------------------------------------------------------------
# Therefore, I do not find any merits in the first ground.
#
#
# -----------------------------------------------------------------
# • In conclusion, I do not find any merit in this Notice of Motion.
#
#
# -----------------------------------------------------------------
# I therefore refuse it and dismiss it accordingly.
#
#
# -----------------------------------------------------------------
# This too, was of no assistance to the Applicant's case.
#
#
# -----------------------------------------------------------------
# 2 of the claim clearly states:
#
#
# -----------------------------------------------------------------
# I disagree with the submission which blithely ignores the liability of the firm.
#
#
# -----------------------------------------------------------------
# [24] The matter does not end there.
#
#
# -----------------------------------------------------------------
# The Learned Magistrate failed to do so.
#
#
# -----------------------------------------------------------------
# Was the decision of the PSC unreasonable?
#
#
# -----------------------------------------------------------------
# 1 WAS THE DECISION OF THE PSC UNREASONABLE?
#
#
# -----------------------------------------------------------------
# The PSC did not fail to consider the seriousness of the matter.
#
#
# -----------------------------------------------------------------
# - that the PSC’s decision was absurd and unreasonable.
#
#
# -----------------------------------------------------------------
# It must be remembered that the PSC is not a court.
#
#
# -----------------------------------------------------------------
# Failure to consider internal reports
#
#
# -----------------------------------------------------------------
# I reject the submission that the PSC failed to consider this matter adequately.
#
#
# -----------------------------------------------------------------
# Was the PSC’s decision absurd?
#
#
# -----------------------------------------------------------------
# So the penalty was not just a caution.
#
#
# -----------------------------------------------------------------
# I dismiss the ground of review of unreasonableness.
#
#
# -----------------------------------------------------------------
# I do not place any weight on this document.
#
#
# -----------------------------------------------------------------
# Secondly Mr Short has no qualifications in accident investigation and was not qualified as an independent expert.
#
#
# -----------------------------------------------------------------
# •  Mr Wynyard did not inspect either vehicle.
#
#
# -----------------------------------------------------------------
# They were of poor quality and of uncertain age and origin.
#
#
# -----------------------------------------------------------------
# For instance, Mr Ioaba would not be able to run.
#
#
# -----------------------------------------------------------------
# Mr Ioaba had no time to avoid the collision.
#
#
# -----------------------------------------------------------------
# •  Other items of special damages were not agreed between Counsel.
#
#
# -----------------------------------------------------------------
# The calculation of general damages is never precise.
#
#
# -----------------------------------------------------------------
# The Accident Compensation (ACC) awards are of no assistance in this case.
#
#
# -----------------------------------------------------------------
# I considered escaping shows a definite decision to be absent voluntary.
#
#
# -----------------------------------------------------------------
# None of this will be suspended.
#
#
# -----------------------------------------------------------------
# Apparently the motion, after debate, was lost.
#
#
# -----------------------------------------------------------------
# No particulars of the breaches were given.
#
#
# -----------------------------------------------------------------
# In my view this evidence does not assist the Appellant.]
#
#
# -----------------------------------------------------------------
# (b) The Magistrate was biased and the proceedings were unfair;
#
#
# -----------------------------------------------------------------
# Those proceedings do not provide for oral evidence to be heard.
#
#
# -----------------------------------------------------------------
# There is no evidence to proof this therefore points 11 and 12 also dismissed.
#
#
# -----------------------------------------------------------------
# The respondent said that this matter is not concerning Haresimono house but Aipurano.
#
#
# -----------------------------------------------------------------
# I do not intend to restate them.
#
#
# -----------------------------------------------------------------
# I do not intend to restate that here.
#
#
# -----------------------------------------------------------------
# The windscreens were not tinted.
#
#
# -----------------------------------------------------------------
# The offender has no prior convictions.
#
#
# -----------------------------------------------------------------
# The pre-sentence report does not warrant suspension.
#
#
# -----------------------------------------------------------------
# Your opinion need not be unanimous.
#
#
# -----------------------------------------------------------------
# RULING ON "NO CASE" SUBMISSION
#
#
# -----------------------------------------------------------------
# This description does not fit Velina, Esmie, nor Diana.
#
#
# -----------------------------------------------------------------
# The application was opposed.
#
#
# -----------------------------------------------------------------
# The PSAB did not appear given that it’s attendance had been earlier excused.
#
#
# -----------------------------------------------------------------
# The leave sought to withdraw was granted.
#
#
# -----------------------------------------------------------------
# Accordingly I dismiss the motion.
#
#
# -----------------------------------------------------------------
# This rule does not apply where the prisoner would be called as a witness.
#
#
# -----------------------------------------------------------------
# I am unable to agree with the Deacon.
#
#
# -----------------------------------------------------------------
# We have not upheld that ground.
#
#
# -----------------------------------------------------------------
# The appellant did not stop.
#
#
# -----------------------------------------------------------------
# • The appellant did not give or call evidence.
#
#
# -----------------------------------------------------------------
# • The assessors were unpersuaded.
#
#
# -----------------------------------------------------------------
# We say nothing as to what we would have decided in relation to them.
#
#
# -----------------------------------------------------------------
# The context was that the prima facie elements for murder were not contested.
#
#
# -----------------------------------------------------------------
# 35 of 2006) which the Plaintiffs failed to attend.
#
#
# -----------------------------------------------------------------
# Mr Tai did not give evidence.
#
#
# -----------------------------------------------------------------
# The First Defendants' key did not open the lock.
#
#
# -----------------------------------------------------------------
# It was not seized.
#
#
# -----------------------------------------------------------------
# No other goods were removed by or on behalf of the First Defendants.
#
#
# -----------------------------------------------------------------
# Furthermore, there was no breach of the Distress for Rent Act.
#
#
# -----------------------------------------------------------------
# The sum of K5,000.00 was paid.
#
#
# -----------------------------------------------------------------
# There was no reply.
#
#
# -----------------------------------------------------------------
# Nothing was done.
#
#
# -----------------------------------------------------------------
# It was excluded from evidence because of its unreliability.
#
#
# -----------------------------------------------------------------
# • Both appellants were not happy with the above decision.
#
#
# -----------------------------------------------------------------
# This was a waste of scarce resources.
#
#
# -----------------------------------------------------------------
# So, in a sense, Appellant No.
#
#
# -----------------------------------------------------------------
# The decision was communicated to the Acting Secretary, DPM.
#
#
# -----------------------------------------------------------------
# The PSC concedes that the summonsing procedure was not followed.
#
#
# -----------------------------------------------------------------
# As a result, a "hearing" was not conducted: Allan Pinggha v PSC (2005) N2850.
#
#
# -----------------------------------------------------------------
# The parties have not agreed to any issues arising out of these grounds for my determination.
#
#
# -----------------------------------------------------------------
# It also appears the Secretary, DPM and Mr. Gelu were also not summonsed.
#
#
# -----------------------------------------------------------------
# In my view, this is not in compliance with s.18(3)(c)(iii).
#
#
# -----------------------------------------------------------------
# Therefore the decision is not binding on him.
#
#
# -----------------------------------------------------------------
# There is no claim for specific performance of the contract.
#
#
# -----------------------------------------------------------------
# There is in fact nothing claimed apart from damages.
#
#
# -----------------------------------------------------------------
# This list of aggravating and mitigating features are by no means exhaustive.
#
#
# -----------------------------------------------------------------
# Furthermore none of the jewellery was recovered.
#
#
# -----------------------------------------------------------------
# On the other hand, the Plaintiff/Respondent argues to the contrary.
#
#
# -----------------------------------------------------------------
# However, they did not file and serve their defence within the required period.
#
#
# -----------------------------------------------------------------
# The consolidation aspect of the application was not sufficiently well motivated and I find it is not merited.
#
#
# -----------------------------------------------------------------
# The appeal raises various matters including the absence of corroboration in the case.
#
#
# -----------------------------------------------------------------
# It was not touched upon in the evidence or the submissions for the respondents.
#
#
# -----------------------------------------------------------------
# Nor has the National Provident Fund been cited as a party to these proceedings.
#
#
# -----------------------------------------------------------------
# No further submissions are therefore required from counsel.
#
#
# -----------------------------------------------------------------
# Imeleta did not pay her arrears.
#
#
# -----------------------------------------------------------------
# These were the only documents they signed.
#
#
# -----------------------------------------------------------------
# They signed no other document.
#
#
# -----------------------------------------------------------------
# So he was not clear and unhappy.
#
#
# -----------------------------------------------------------------
# And that part of Harry’s evidence was not destabilised under cross-examination.
#
#
# -----------------------------------------------------------------
# The caveat must therefore be removed.
#
#
# -----------------------------------------------------------------
# Imeleta failed to do so.
#
#
# -----------------------------------------------------------------
# At the times of those registrations, there was no caveat on the land.
#
#
# -----------------------------------------------------------------
# There was also no caveat on the land at that time.
#
#
# -----------------------------------------------------------------
# The respondents caveat should therefore be removed.
#
#
# -----------------------------------------------------------------
# behalf of Plaintiff/Applicant : Not filed – except for few case authorities.
#
#
# -----------------------------------------------------------------
# Only Daisy had been required to give evidence on oath.
#
#
# -----------------------------------------------------------------
# There are no aggravating features.
#
#
# -----------------------------------------------------------------
# As a result payment of the allowance had been discontinued.
#
#
# -----------------------------------------------------------------
# No Appearance for or by the Second Respondent.
#
#
# -----------------------------------------------------------------
# Attendances: Claimants no appearance (Nigel Morrison)
#
#
# -----------------------------------------------------------------
# Mr Morrison was not able to be contacted.
#
#
# -----------------------------------------------------------------
# The offer is that all parties walk away.
#
#
# -----------------------------------------------------------------
# • No previous convictions;
#
#
# -----------------------------------------------------------------
# You did not provide this Court with any such evidence.
#
#
# -----------------------------------------------------------------
# There would have been no such costs if you did not escape.
#
#
# -----------------------------------------------------------------
# However there are also no indication of the Defendant's approval as stated.
#
#
# -----------------------------------------------------------------
# No written agreement was proved and or admitted.
#
#
# -----------------------------------------------------------------
#  In 1995 the Ombudsman Act No.
#
#
# -----------------------------------------------------------------
# A report has been published and on the pleadings the recommendation have not been acted upon.
#
#
# -----------------------------------------------------------------
# • The frivolous Statement of Claim ought not to be entertained and struck off in its entirety.
#
#
# -----------------------------------------------------------------
# Those judgments appear to have had no impact.
#
#
# -----------------------------------------------------------------
# [67] The very nature of the substantive matter:
#
#
# -----------------------------------------------------------------
# For such appearances no retainer is paid.
#
#
# -----------------------------------------------------------------
# In fact when Mr Narayan appeared no retainer was paid.
#
#
# -----------------------------------------------------------------
# The defendant was not present on this first sitting date.
#
#
# -----------------------------------------------------------------
# Only VT 1.035.000 was received.
#
#
# -----------------------------------------------------------------
# The shortfall is VT 141.000.
#
#
# -----------------------------------------------------------------
# That submission is untenable and is rejected.
#
#
# -----------------------------------------------------------------
# Trial date has been not been set in this case.
#
#
# -----------------------------------------------------------------
#  No appearance for the Defendants
#
#
# -----------------------------------------------------------------
# § 46.1502 ("A national shall not be excluded from jury service in this territory on account of race, color .
#
#
# -----------------------------------------------------------------
# [3] The disputed order conclusively determined venue.
#
#
# -----------------------------------------------------------------
# Held: Application for stay refused.
#
#
# -----------------------------------------------------------------
# The Respondent commenced action OS No.
#
#
# -----------------------------------------------------------------
# The balance of convenience did not warrant a grant of stay order.
#
#
# -----------------------------------------------------------------
#  η The nature of the judgement sought to be stayed.
#
#
# -----------------------------------------------------------------
# The defendants failed to lead any evidence to counter PE 3.
#
#
# -----------------------------------------------------------------
# (i) The Directors had no powers to decide on the allotment of shares.
#
#
# -----------------------------------------------------------------
# (iii) No consideration was paid for the allotted shares.
#
#
# -----------------------------------------------------------------
# Nothing on the subject had been heard before.
#
#
# -----------------------------------------------------------------
# I find this allegation not true.
#
#
# -----------------------------------------------------------------
# I therefore find this allegation not sustained.
#
#
# -----------------------------------------------------------------
# (c) No consideration was paid for the allotted shares.
#
#
# -----------------------------------------------------------------
# Accordingly I reject this allegation also.
#
#
# -----------------------------------------------------------------
# And there it is not to be found.
#
#
# -----------------------------------------------------------------
# 247 does not lead to invalidation of the allotment.
#
#
# -----------------------------------------------------------------
# That is not disputed by her counsel.
#
#
# -----------------------------------------------------------------
# • During the trial the Appellant was not represented.
#
#
# -----------------------------------------------------------------
# We are far from persuaded about that.
#
#
# -----------------------------------------------------------------
# The Respondent’s role is merely an advisory one.
#
#
# -----------------------------------------------------------------
# 173633 being Lot 10 on deposited plan No.
#
#
# -----------------------------------------------------------------
# [5] However, that did not happen.
#
#
# -----------------------------------------------------------------
#  Application for Discharge Without Conviction:
#
#
# -----------------------------------------------------------------
# Accordingly, a discharge without conviction is declined.
#
#
# -----------------------------------------------------------------
# The Court made no order for interest.
#
#
# -----------------------------------------------------------------
# Objections against assessments.
#
#
# -----------------------------------------------------------------
# The first ground of review was dismissed.
#
#
# -----------------------------------------------------------------
# There was no denial of natural justice.
#
#
# -----------------------------------------------------------------
# The allegation of failure to give reasons was entirely meritless.
#
#
# -----------------------------------------------------------------
# The third ground of review was dismissed.
#
#
# -----------------------------------------------------------------
# The appeals did not progress for 18 years.
#
#
# -----------------------------------------------------------------
# No particulars were provided in the statement in support of this ground of review.
#
#
# -----------------------------------------------------------------
# The principle of adverse possession was not wrongly considered.
#
#
# -----------------------------------------------------------------
# However the judgment and the order cannot be read in isolation.
#
#
# -----------------------------------------------------------------
# It did not vary the Local Land Court order.
#
#
# -----------------------------------------------------------------
# Therefore no error of law has been established.
#
#
# -----------------------------------------------------------------
#  (2) FAILURE TO CONDUCT A PROPER HEARING
#
#
# -----------------------------------------------------------------
# The inference arises that there was no such request.
#
#
# -----------------------------------------------------------------
#  (3) FAILURE TO GIVE REASONS
#
#
# -----------------------------------------------------------------
# No particulars were provided in the statement in support of this ground of review.
#
#
# -----------------------------------------------------------------
# Mr Token submitted that his Worship failed to give reasons in three respects:
#
#
# -----------------------------------------------------------------
# The argument is made in a vacuum and must be dismissed.
#
#
# -----------------------------------------------------------------
# The allegation of failure to give reasons is entirely meritless.
#
#
# -----------------------------------------------------------------
# The Claimants are saying that the transfer in 1971 could not have taken place.
#
#
# -----------------------------------------------------------------
# It was not an occasion that was conducted secretly.
#
#
# -----------------------------------------------------------------
# That did not happen as the Commission did not require Mael Apisai to be interviewed.
#
#
# -----------------------------------------------------------------
# BF612 was done by the Respondent's Agents.
#
#
# -----------------------------------------------------------------
# Injunctions against financial institutions are very rarely granted.
#
#
# -----------------------------------------------------------------
# Neither Defendants appeared.
#
#
# -----------------------------------------------------------------
# • Assessment of damages is discontinued and set aside;
#
#
# -----------------------------------------------------------------
# Defense counsel was not cooperative.
#
#
# -----------------------------------------------------------------
# The Antecedent Report presented recorded no previous convictions.
#
#
# -----------------------------------------------------------------
# These are factors not in favour of the prisoner;
#
#
# -----------------------------------------------------------------
# Prisoner expressed remorse and no compensation paid.
#
#
# -----------------------------------------------------------------
# The strike out is refused.
#
#
# -----------------------------------------------------------------
# They had been granted letters of administration de bonis non No.
#
#
# -----------------------------------------------------------------
# But no ruling was ever put before me.
#
#
# -----------------------------------------------------------------
# I have not been paid this share.
#
#
# -----------------------------------------------------------------
# (e) I have not been paid this share
#
#
# -----------------------------------------------------------------
# Nothing turns on this.
#
#
# -----------------------------------------------------------------
# "...the Appellants were not invited to the family meeting because they were not descendants of Eipera.
#
#
# -----------------------------------------------------------------
# Eidian) was not the recorded owner of Amwange."
#
#
# -----------------------------------------------------------------
# 8336 was never to be registered is answered by Mr. Waqavonovono.
#
#
# -----------------------------------------------------------------
# Likewise this was not disclosed to Scott J.
#
#
# -----------------------------------------------------------------
# There was no mistake about it.
#
#
# -----------------------------------------------------------------
# Such agreement has no useful purpose.
#
#
# -----------------------------------------------------------------
# There was no such map identified to me or shown clearly to the Court.
#
#
# -----------------------------------------------------------------
# No reasons were recorded for the withdrawal.
#
#
# -----------------------------------------------------------------
# The Magistrate's Court did not find any merit in that line of reasoning.
#
#
# -----------------------------------------------------------------
# This is not the purpose of s.220 of CPC.
#
#
# -----------------------------------------------------------------
# I refused the first leg of the application.
#
#
# -----------------------------------------------------------------
# The Second Respondent was moving around in Jiwaka Province only in the nights.
#
#
# -----------------------------------------------------------------
# It takes no position on the application.
#
#
# -----------------------------------------------------------------
# There are no remaining letters of yours to reply to.
#
#
# -----------------------------------------------------------------
# • Only minimal force was used
#
#
# -----------------------------------------------------------------
# • There was no pre-planning
#
#
# -----------------------------------------------------------------
# The respondents refused to recognize the ministerial decision.
#
#
# -----------------------------------------------------------------
# The question of standing does not arise.
#
#
# -----------------------------------------------------------------
# Therefore the Minister acted on a flawed decision.
#
#
# -----------------------------------------------------------------
# The application has no merit and it should be dismissed.
#
#
# -----------------------------------------------------------------
# I am not satisfied an arguable case has been demonstrated.
#
#
# -----------------------------------------------------------------
# The application must therefore fail.
#
#
# -----------------------------------------------------------------
#  (1) The application is refused.
#
#
# -----------------------------------------------------------------
# (a) You have obviously heard no evidence from them.
#
#
# -----------------------------------------------------------------
# These alterations were initiated but they are not his initials.
#
#
# -----------------------------------------------------------------
# The signature on them is not his.
#
#
# -----------------------------------------------------------------
# In any event you are not to speculate.
#
#
# -----------------------------------------------------------------
# [61] The fourth, fifth and sixth accused did not give evidence.
#
#
# -----------------------------------------------------------------
# It does nothing to establish his or her guilt.
#
#
# -----------------------------------------------------------------
# The defendant did not complete the transaction.
#
#
# -----------------------------------------------------------------
# The discretionary beneficiaries did not want the property sold.
#
#
# -----------------------------------------------------------------
# The children are not party to these proceedings nor did they interplead
#
#
# -----------------------------------------------------------------
# They had no notice of any contractual mistake or equitable interest in a trust.
#
#
# -----------------------------------------------------------------
# In that case the entire court transcripts were not located and unavailable.
#
#
# -----------------------------------------------------------------
# The application is opposed.
#
#
# -----------------------------------------------------------------
# Prior to this, three SOCs were filed which I need not go into.
#
#
# -----------------------------------------------------------------
# • Mediation was attempted but was unsuccessful.
#
#
# -----------------------------------------------------------------
# (b)Defendant knows the representation is false;
#
#
# -----------------------------------------------------------------
# The total amount claimed became $1,336,022.00.
#
#
# -----------------------------------------------------------------
# There were also no originals to confirm who had prepared those invoices.
#
#
# -----------------------------------------------------------------
# It was, however, withheld.
#
#
# -----------------------------------------------------------------
# Lloyd’s was accordingly not liable to the Names under the tort of deceit.
#
#
# -----------------------------------------------------------------
# The firm had gained nothing from the frauds.
#
#
# -----------------------------------------------------------------
#  Issue 1:Whether MF committed the tort of deceit:
#
#
# -----------------------------------------------------------------
# • MF made a false representation to SBL;
#
#
# -----------------------------------------------------------------
# • MF knew the representation was false;
#
#
# -----------------------------------------------------------------
# •  In consequence, suffered loss.
#
#
# -----------------------------------------------------------------
# Whether MF made a false representation to SBL;
#
#
# -----------------------------------------------------------------
# However I do not find that this explains the substantial excess.
#
#
# -----------------------------------------------------------------
# The credit was substantial during the period of the claim.
#
#
# -----------------------------------------------------------------
#  No Appearance for the Defendants – Defendants absent
#
#
# -----------------------------------------------------------------
# 293269 with the words “Cancelled by Re-Entry No.
#
#
# -----------------------------------------------------------------
# 11003 and about the consequences on their failure to adhere to the notice.
#
#
# -----------------------------------------------------------------
# The Respondent did not pay.
#
#
# -----------------------------------------------------------------
# However by Legal Notice No.
#
#
# -----------------------------------------------------------------
# There is no evidence of a refusal.
#
#
# -----------------------------------------------------------------
# Leave was granted.
#
#
# -----------------------------------------------------------------
# Patient was advised and discharged home.”
#
#
# -----------------------------------------------------------------
# Defendant was served with Order and did not comply."
#
#
# -----------------------------------------------------------------
# The Union contends that the action by the Company is unfair, unjust and wrong.
#
#
# -----------------------------------------------------------------
# There is no mention or reference to the other workers.
#
#
# -----------------------------------------------------------------
# One does not necessarily arise as a result of the other.
#
#
# -----------------------------------------------------------------
# The total proceeds of the sale were US$27,270.00.
#
#
# -----------------------------------------------------------------
# This was not an unreasonable stance taken by the Defendant.
#
#
# -----------------------------------------------------------------
# The correct amount had not been agreed between the parties and thus this case.
#
#
# -----------------------------------------------------------------
# •  Had been mistaken on the facts, or
#
#
# -----------------------------------------------------------------
# The first appellant did not accede to that request and stayed put.

# %%
index = 54
sentence_index = np.where(y_hat==index)[0]
for i in sentence_index:
    print('-----------------------------------------------------------------')
    print(sentences[i])
    print('\n')
# Out:
# -----------------------------------------------------------------
# The competing affidavit material demonstrates the existence of strongly contested issues of fact.
#
#
# -----------------------------------------------------------------
# I am of the view that the overall balance of convenience requires that a stay be granted.
#
#
# -----------------------------------------------------------------
# We review the Land Court's factual findings for clear error and its conclusions of law de novo.
#
#
# -----------------------------------------------------------------
# is warranted only if the findings so lack evidentiary support in the record that no reasonable trier of fact could have reached the same conclusion."
#
#
# -----------------------------------------------------------------
# [5] As a general matter, "[t]he Tochi Daicho is presumed to be accurate, and a party seeking to rebut it must present clear and convincing evidence."
#
#
# -----------------------------------------------------------------
# The expression of opinion by the lawyer that there is good prospect of success can only amount to a legal opinion.
#
#
# -----------------------------------------------------------------
# The affidavits filed on behalf of PEIL in my view, do disclose material facts which show a good defence on the merits.
#
#
# -----------------------------------------------------------------
# (4) When the judge does not agree with the majority opinion of the assessors, the judge shall give reasons for differing with the majority opinion, which shall be –
#
#
# -----------------------------------------------------------------
# "...In our opinion learned counsel for the appellants is confusing the functions of the assessors with those of a Jury in a trial.
#
#
# -----------------------------------------------------------------
# For instance evidence will have to be readily available of non-attendance or of absconding from trial if section 18(1) (a) is to be relied upon as a ground of objection to bail.
#
#
# -----------------------------------------------------------------
#  A court will deny a summary judgment motion unless, viewing the facts presented and inferences made in the light most favorable to the nonmoving parties, it finds that there is no genuine issue of material fact and the that moving party is entitled to judgment as a matter of law.
#
#
# -----------------------------------------------------------------
#  A court will deny a summary judgment motion unless, viewing the facts presented and inferences made in the light most favorable to the nonmoving parties, it finds that there is no genuine issue of material fact and the that moving party is entitled to judgment as a matter of law.
#
#
# -----------------------------------------------------------------
# Suffice it to say that having considered the various affidavits and annexures I am satisfied that the plaintiff company's claim raises potentially serious and complex factual and legal issues that ought to be further investigated at a full trial.
#
#
# -----------------------------------------------------------------
# "A fact is said to be proved when, after considering the matters before it, the court either believes it to exist or considers its existence so probable that a prudent man ought, under the circumstances of the particular case, to act upon the supposition that it exists.
#
#
# -----------------------------------------------------------------
# On the other hand court should consider what actually happened and not what adduced by witnesses- as legal maxim "In traditionibus scruptorum non quod dictum est sed qudogestum est inspicitur" have to be noted.
#
#
# -----------------------------------------------------------------
# However, in most, if not all, cases, that ultimate inference must be drawn from some intermediate factual conclusion, whether identified expressly or not.
#
#
# -----------------------------------------------------------------
# More than one intermediate fact may be identifiable; indeed the number will depend to some extent upon how minutely the elements of the crime in question are dissected, bearing in mind that the ultimate burden which lies upon the prosecution is the proof of those elements.
#
#
# -----------------------------------------------------------------
# On the other hand, it may sometimes be necessary or desirable to identify those intermediate facts which constitute indispensable links in a chain of reasoning towards an inference of guilt.
#
#
# -----------------------------------------------------------------
# If it is appropriate to identify an intermediate fact as indispensable it may well be appropriate to tell the jury that that fact must be found beyond reasonable doubt before the ultimate inference can be drawn.
#
#
# -----------------------------------------------------------------
# In all the circumstances I consider that the combination of all these errors of law must lead to a quashing of the conviction.
#
#
# -----------------------------------------------------------------
# On the material before me, I find no evidence of any likelihood of complainant's reputation being injured or other people are likely to be induced to shun, avoid, ridicule or despise him, nor is there evidence to show such words tend to lower complainant in the estimation of right thinking members of the society.
#
#
# -----------------------------------------------------------------
# And thirdly, we think, that the employer at this stage at which he formed that belief on those grounds had carried out as much investigation into the matter as was reasonable in all these circumstances of the case”.
#
#
# -----------------------------------------------------------------
# In my view, the power of the Court under s. 63 can only be used in circumstances where there are inconsistencies and insufficiency in the evidence.
#
#
# -----------------------------------------------------------------
# Following that ruling, Mr Kefu for the Attorney-General, having no doubt taken the sensible step of checking its effect on other pending cases, realised he was likely to find himself in a similar position in each of the present cases.
#
#
# -----------------------------------------------------------------
# Before the case is listed for hearing, either side should have an opportunity to add further evidence if, in the discretion of the court, there would be no injustice.
#
#
# -----------------------------------------------------------------
# However, the procedures are intended in all cases to ensure that the real issue in controversy is brought before the court for determination.
#
#
# -----------------------------------------------------------------
# The unanimous opinion is completely tenable on the basis of evidence considered in accordance with the legal directions that have been made.
#
#
# -----------------------------------------------------------------
# I have considered and evaluated the evidence, applying legal principles contained in my summing-up to the assessors.
#
#
# -----------------------------------------------------------------
# 9.66 The court must not give summary judgment if it is satisfied that there is a real dispute between the parties about a material fact.
#
#
# -----------------------------------------------------------------
# The first is that the trial court erred in finding that there was a reasonable cause of action in law and fact.
#
#
# -----------------------------------------------------------------
# Those issues are trial issues, not issues that can be determined at a preliminary stage such as this.
#
#
# -----------------------------------------------------------------
# • We agree with the learned trial judge in his application of the relevant test and his conclusion that the matters raised are matters for trial.
#
#
# -----------------------------------------------------------------
# There may be merit in that approach, but I think the time has come for the courts to look for real risks rather than assumed risks as grounds for depriving an accused person of his right to bail.
#
#
# -----------------------------------------------------------------
# • In the light if these facts and the delay in bringing this case to trial, I am satisfied that this is a case where bail should be granted.
#
#
# -----------------------------------------------------------------
# If I were to rule that as a general principle litigants can stay in a country whilst litigating a substantial mischief could well be created."
#
#
# -----------------------------------------------------------------
# While I would not go quite so far as to exclude Judicial Review altogether (for example, the proviso particular to Section 11(2)(g) raises some doubts) I agree that immigration cases are indeed in a category of their own.
#
#
# -----------------------------------------------------------------
# In my ruling on no case to answer I indicated that it is not for this court to decide whether each element of the charges has been proved beyond reasonable doubt and that is the course that I will adapt at the end of the trial if I find a case to answer.
#
#
# -----------------------------------------------------------------
# That there arose the perception of bias is understandable.
#
#
# -----------------------------------------------------------------
# It is clear from the Canterbury case that in considering the correct test, the relevant Tribunal, in this case the Chief Justice, must have regard to the circumstances of the case.
#
#
# -----------------------------------------------------------------
# In this case, it is difficult to see that Mr Morley had any duty to Mr Tupangaia and there must be a serious question as to whether a finding based on negligence could be upheld.
#
#
# -----------------------------------------------------------------
# That may leave it in doubt as to whether the Respondent or the hearing of the petitioner's bound to fail.
#
#
# -----------------------------------------------------------------
# • In that case the Court of Appeal stated that “it will only be in the most exceptional cases that suspensions could ever be contemplated in a case of sexual abuse”.
#
#
# -----------------------------------------------------------------
# I had to be satisfied that there was reasonable evidence available, on the face of the file, of all of the elements of the charge.
#
#
# -----------------------------------------------------------------
# That case is useful as it sets out the different factors that have to be weighed in the balance when determining the length of the term of imprisonment.
#
#
# -----------------------------------------------------------------
# There is no evidence in the present case in my view which would justify an element of aggravation being introduced into the award.
#
#
# -----------------------------------------------------------------
# But: am more Inclined to think that- that argument must be balanced with the public interest In good administration as well as the interest of the complainant.
#
#
# -----------------------------------------------------------------
# •  Posala identified the factors that must be taken into account in considering the question of whether there is just cause for continued detention as follow:[6]
#
#
# -----------------------------------------------------------------
# I anticipate however that the totality principle, degree of culpability / criminality would be relevant considerations at sentence.
#
#
# -----------------------------------------------------------------
# In a bail hearing as required under s.105 CPA, evidence must be produced to substantiate there is such risk.
#
#
# -----------------------------------------------------------------
# "But any statement of the matters which would justify granting leave to appeal must be subject to one important qualification which applies to all cases.
#
#
# -----------------------------------------------------------------
# 51/95) is also relevant and I adopt the same view to the facts and circumstances of this case:
#
#
# -----------------------------------------------------------------
# "The discretion of the court being, as I conceive it, a perfectly free one, the only question is whether, upon the facts of this particular case, that discretion should be exercised."
#
#
# -----------------------------------------------------------------
# The fact that the SBD$129,000 was paid will of course be relevant to the issue of what, if any, further amounts may be due to the claimants.
#
#
# -----------------------------------------------------------------
# For an application based on no reasonable cause of action, the Court can only look at the facts in the pleadings and particulars; no evidence is admissible at this stage[4].
#
#
# -----------------------------------------------------------------
# It should be done only where the statement of claim and the asserted facts do not raise an arguable case fit to be decided at trial.
#
#
# -----------------------------------------------------------------
# However, my perception is differed in that the Chiefs decision delivered before 1986 are valid and often considered by this Court as evidence of proof as to ownership of customary land.
#
#
# -----------------------------------------------------------------
# I also bear in mind that the unsworn evidence of the young girl must be considered with extra care and certainly should not be relied on without some confirmation by other sworn testimony.
#
#
# -----------------------------------------------------------------
# 'Only in plain and obvious cases that recourse should be had to the summary process under O.
#
#
# -----------------------------------------------------------------
# Apart from truly exceptional cases the approach to such applications  is to assume that the factual basis on which the allegations contained in the pleadings are raised will be provided if a  legal issue can be raised on the facts as pleaded then the Court will not strike out a  pleading and will certainly not do so on a  contention that the facts cannot be proved unless the situation is so strong that judicial notice can be taken of the falsity of a  factual contention...'
#
#
# -----------------------------------------------------------------
# • An opinion of the court that a case appears weak and such that it is unlikely to succeed is not alone; sufficient to warrant summary termination...even a weak case is entitled to the time of a court.
#
#
# -----------------------------------------------------------------
# Experience teaches that the concentration of attention, elaborated evidence and argument and extended time for reflection will sometimes turn an apparently unpromising cause into a successful judgment,
#
#
# -----------------------------------------------------------------
# • Summary relief of the kind provided for by O26 r 18, for absence of a reasonable cause of action, is not a substitute for proceeding by way of demurrer... if there is a serious legal question to be determined, it should ordinarily be determined at a trial for the proof of facts may sometimes assist the judicial mind to understand and apply the law that is invoked and to do so in circumstances more conducive to deciding a real case involving actual litigation rather than one determined on imagined or assumed facts,
#
#
# -----------------------------------------------------------------
#  The Courts view and many decisions on this matter is clear: As long as the statement of claim or the particulars (Davey v. Bentinct: (1893) 1 QB 185) disclose some cause of action, or raise some question fit to be decided by a Judge or a jury, the mere fact that the case is weak, and not likely to succeed is no ground for striking it out.
#
#
# -----------------------------------------------------------------
# The sum involved is obviously not the only factor to be considered, but it may in many cases provide a useful guide.
#
#
# -----------------------------------------------------------------
# The facts as they have been established are very troubling for the following reasons which in the Court's view aggravate your offending: -
#
#
# -----------------------------------------------------------------
# Assuming (which I hesitate to do) that the minute is a full report of the proceedings there may have been procedural errors.
#
#
# -----------------------------------------------------------------
# It may or may not be a full and accurate report of proceedings.
#
#
# -----------------------------------------------------------------
# From my experience of court minutes I am unwilling to base a decision on the form or content of a minute unless the minute is confirmed by other evidence.
#
#
# -----------------------------------------------------------------
# For two reasons: the first I have mentioned, the difficulty of finding out facts: the second, certainty of title, the principle of certainty.
#
#
# -----------------------------------------------------------------
# The value judgment required by such a test was recognized as likely to give rise to uncertainty and, potentially, to injustice.
#
#
# -----------------------------------------------------------------
# The minority preferred a test that would bar any claim tainted by a sufficiently close factual connection with the illegal purpose.
#
#
# -----------------------------------------------------------------
# He contended that facts could emerge at trial that could materially affect the question of illegality and its relationship to the claim.
#
#
# -----------------------------------------------------------------
# There may be other explanations for that including a preference in earlier times for a test that involved a significant subjective component.
#
#
# -----------------------------------------------------------------
# But there is no reason why, in a proper case, the issue cannot be determined in advance of trial as long as any necessary factual findings can be made on the basis of uncontested or incontrovertible evidence.
#
#
# -----------------------------------------------------------------
# [36] Moapa submits that the issue of whether there is a sufficient relationship between the illegality and the claim is also a matter for trial.
#
#
# -----------------------------------------------------------------
# “To fall within the general principle the dispute must be bona filed in both a subjective and an objective sense.
#
#
# -----------------------------------------------------------------
# The court needs to consider the affidavit evidence and careful analysis of them is needed to consider whether the dispute is made in good faith.
#
#
# -----------------------------------------------------------------
# To fall within the general principle the dispute must be bona filed in both a subjective and an objective sense.
#
#
# -----------------------------------------------------------------
# (a) Discussion held in this regard with Mr. Vkatora to clarify matters, must be properly minuted and the Board updated accordingly.
#
#
# -----------------------------------------------------------------
# This in the analysis of the evidence would not pass the test of spontaneity, and considering the circumstances surrounding the events has to be considered with a pinch of salt.
#
#
# -----------------------------------------------------------------
# Both judgments set out what is standard law on setting aside applications and their conclusions are unremarkable, indeed inevitable.
#
#
# -----------------------------------------------------------------
# [38] Even with the service issue, the reasoning of both judges is sufficiently sound to make it highly unlikely that the threshold criteria of section 7(3) would be met.
#
#
# -----------------------------------------------------------------
# Undoubtedly there will be prejudice overall to the Respondents' interests if the discretion is excercised in the petitioner's favour.
#
#
# -----------------------------------------------------------------
# Again, I say I find much force in the learned judge's reasoning.
#
#
# -----------------------------------------------------------------
# However he said this, and it is worthy of re-iteration, "Mere assertion of belief that the Defendant might dissipate his assets, unsupported by solid ground justifying that belief, is insufficient.
#
#
# -----------------------------------------------------------------
# This is a question of exercising my discretion and such questions always trouble Judges when the facts of a given case are, as I regard those in this case, fairly evenly balanced.
#
#
# -----------------------------------------------------------------
# Moreover, it is my view that the percentage of the purity will only be considered in order to determine the appropriate sentence, if the Applicant is found guilty to this offence.
#
#
# -----------------------------------------------------------------
# "The court must not give judgment against a defendant under this rule if it is satisfied that there is a dispute between the parties about a substantial question of fact or a difficult question of law".
#
#
# -----------------------------------------------------------------
# Ground 9-That the judgment of the Learned Magistrate in all the circumstances of the case was unfair and/or unjust and/or biased and against the interest of Justice.
#
#
# -----------------------------------------------------------------
# In the present case want of jurisdictionwas not raised in the Magistrates' Court at all and I have some doubt as to whether it could properly be raised on appeal.'
#
#
# -----------------------------------------------------------------
# The very first question he must ask should be that whether he has jurisdiction to try the case.
#
#
# -----------------------------------------------------------------
# "Every judge in every trial, be it criminal or civil, has an overriding duty to ensure the trial is fair.
#
#
# -----------------------------------------------------------------
# (1) The test to apply for the purposes of determining whether an administrative decision has been made unreasonably is to ask whether the decision is so unreasonable or absurd, having regard to all the circumstances, that no reasonable decision-maker would have made the decision.
#
#
# -----------------------------------------------------------------
# First, it is mandatory for the PSC to consider "all the facts relative to the matter", which must include the matters (A), (B) and (C).
#
#
# -----------------------------------------------------------------
# My assessment of the decision is that it is a carefully considered one.
#
#
# -----------------------------------------------------------------
# The Court can take into account the evidence it has heard including that of the medical experts as to what treatment will be needed in the future.
#
#
# -----------------------------------------------------------------
# I bear in mind that the award of general damages should be commensurate with reasonable expectations in the Cook Islands.
#
#
# -----------------------------------------------------------------
# Returning to consider sentence and after considering all submissions of counsels, I agree that this case is not a worse type.
#
#
# -----------------------------------------------------------------
# "A submission that there is no case to answer may properly be made and upheld (a) when there has been no evidence to prove an essential element of the alleged offence; (b) when the evidence ..... is so manifestly unreliable that no reasonable tribunal could safely convict upon it".
#
#
# -----------------------------------------------------------------
# [24] Before again examining the grounds of appeal, the evidence and arguments advanced by Mr Pohiva it is perhaps worth making two fundamental points:
#
#
# -----------------------------------------------------------------
#  (1) The basis of the courts’ intervention is not a possible perception of impropriety: it is the protection of confidential information.
#
#
# -----------------------------------------------------------------
# What he did and says are matters of evidence to be tested at the appropriate time at trial.
#
#
# -----------------------------------------------------------------
# I fail to see how this can be the subject of any restraining orders either on the basis of disclosure of confidential information or on the basis of a real risk that confidential information will be disclosed.
#
#
# -----------------------------------------------------------------
# If such connections could or may cause doubt, it's better to raise such objection in the beginning, the Court note it was a suspicion and does not weight in support so the Court also dismissed point 13.
#
#
# -----------------------------------------------------------------
# If the quality is good the court can safely assess the evidence even when there is no other evidence to support it.
#
#
# -----------------------------------------------------------------
# They are their arguments, which you may properly take into account when you evaluate the evidence, but the extent to which you do so is entirely a matter for you.
#
#
# -----------------------------------------------------------------
# • If you heard, or read, or otherwise learned anything about this case outside of this courtroom, you must exclude that information or opinions from your consideration.
#
#
# -----------------------------------------------------------------
# You must have regard only to the testimony, agreed facts and the exhibits put before you in this courtroom during the course of this trial.
#
#
# -----------------------------------------------------------------
# You then should consider whether the evidence presented by the witness is probable or improbable considering the circumstances of the case.
#
#
# -----------------------------------------------------------------
# You must approach the case dispassionately, putting aside any view as to what you might or might not have expected to hear, and make your judgment strictly on the evidence that you have heard from the witnesses and the exhibits during the course the hearing.
#
#
# -----------------------------------------------------------------
# If you accept them as reliable and truthful, then you can consider whether you accept then as proven facts.
#
#
# -----------------------------------------------------------------
# All the evidence must be considered and assessed together at the end of trial by the Judge as the Judge of fact.
#
#
# -----------------------------------------------------------------
# However, at this stage, because a submission of no case is made, the Court must be satisfied, as a matter of law, that on the evidence, a reasonable court could convict on such evidence.
#
#
# -----------------------------------------------------------------
# [9] It is also my view that an order for indemnity costs is not warranted in the circumstances of this case having taken into account the factors I am required to consider in the exercise of my discretion.
#
#
# -----------------------------------------------------------------
# • Although the full wording of s 16 must consulted, the elements critical to a case like the present one might be conveniently summarised (chronologically and seen from the accused’s perspective) as follows:
#
#
# -----------------------------------------------------------------
# • Without entering into any discussion of the details, we consider that there was sufficient evidence to go to the assessors on the distinct topic of defence of another.
#
#
# -----------------------------------------------------------------
# • When speaking of the elements of a justification defence it is difficult to avoid falling into the trap of reversing the onus of proof.
#
#
# -----------------------------------------------------------------
# There was a conflict in the evidence as to what was said, what happened and where on the premises certain events took place.
#
#
# -----------------------------------------------------------------
# On an analysis of the materials before it the Court finds that the overall balance of convenience and the status quo would be against granting of stay.
#
#
# -----------------------------------------------------------------
# Even if (which may be debatable) the onus under this provision rests on the Crown, there is nothing in the evidence here that was capable of fairly raising it at the trial.
#
#
# -----------------------------------------------------------------
# “It is not part of the court’s function at this stage of the litigation to try to resolve conflicts of evidence on affidavit as to facts on which the claims of either party may ultimately depend nor to decide difficult questions of law which call for detailed argument and mature considerations.
#
#
# -----------------------------------------------------------------
# Without relying on any specific case on point but only by reference to s. 155(4) of the Constitution and some cases on it, such as Avia Aihi v. The State (No.
#
#
# -----------------------------------------------------------------
# In the case then before me, I found that, the defendants made a deliberate decision to appeal to the Supreme Court, which I found was correct both from a procedural and jurisdictional view point.
#
#
# -----------------------------------------------------------------
# What matters is whether the Court has the necessary jurisdiction to deal with the matter and do justice.
#
#
# -----------------------------------------------------------------
# I have applied my mind to whether their joinder is necessary to ensure that all matters in dispute in the proceedings can be effectively and completely adjudicated upon.
#
#
# -----------------------------------------------------------------
# • As to whether their joinder is necessary to ensure that all matters in dispute in the proceedings can be effectively and completely adjudicated upon, the answer seems to be that, it is possible that the judicial review proceedings they have instituted may delay the disposal of the substantive matter in this case.
#
#
# -----------------------------------------------------------------
# • In my mind it would be unjust and unreasonable to exclude them simply because they have brought review proceedings challenging the legitimacy of the Board and its Chairman.
#
#
# -----------------------------------------------------------------
# I am satisfied that without their participation all matters in dispute in these proceedings cannot be effectively and completely adjudicated upon.
#
#
# -----------------------------------------------------------------
# "As a general rule, the judgment should commence with a description of the charge, followed by the relevant events and the material evidence set out in correct sequence in narrative form, the identifying number of each pertinent witness being incorporated at the appropriate places, after which the Magistrate should state what witnesses he believes and whose evidence he accepts or rejects, and should proceed to make his findings of fact, apply the appropriate law to those facts, and give his reasoned decision: bearing in mind throughout the provisions of Section 154(1) of the Criminal Procedure Code.
#
#
# -----------------------------------------------------------------
# If these considerations are kept in view, not only will it make the task of an appellate court easier, it might well lead to fewer decisions being upset."
#
#
# -----------------------------------------------------------------
# The assessment of the credibility of witnesses by their demeanour alone is wrong if it can be avoided; All the evidence should be weighed before deciding what to accept and what to reject."
#
#
# -----------------------------------------------------------------
# Undoubtedly this was a serious omission on the trial magistrate's part and amounted in my view to an incurable non-direction.
#
#
# -----------------------------------------------------------------
# Since delivering those conclusions, I have done further research on the issues that troubled me and I am now in a position to deliver my final judgment on those issues.
#
#
# -----------------------------------------------------------------
# However it is my respectful view that both phrases are capable of implying the same thing in terms of the imputation of knowledge on the part of Tabukai.
#
#
# -----------------------------------------------------------------
# Those case authorities however can be distinguished either on their facts or on the issue of law being considered by the Court.
#
#
# -----------------------------------------------------------------
# Each case must be considered on its own facts and the same applies in this case.
#
#
# -----------------------------------------------------------------
# The issue in this case is whether prosecution had established on the evidence that Tabukai had the necessary knowledge that he knew that his actions would probably cause the death of or really serious injury to the deceased.
#
#
# -----------------------------------------------------------------
# That issue has to be considered on the facts that are before this court and not on the facts of other cases.
#
#
# -----------------------------------------------------------------
# "In determining whether the decisions of a particular body were subject to judicial review, the Court was not confined to considering the source of that body’s policies and duties but could also look to their nature.
#
#
# -----------------------------------------------------------------
# However whether there is unlikely to be any substantial dispute of fact is not the only matter that determines by which mode proceedings should be commenced.
#
#
# -----------------------------------------------------------------
# I have not, of course, discussed the case with Justice Weir and I am relying entirely on counsel's advice that this was the view expressed by Justice Weir at the settlement conference.
#
#
# -----------------------------------------------------------------
# "It is sufficient, in my opinion, to enliven the discretion to award such (indemnity) costs that, for whatever reason, a party persists in what should on proper consideration be seen to be a hopeless case.
#
#
# -----------------------------------------------------------------
# In those circumstances, he must also have appreciated that his claim would have the result of drawing Kramer Ausenco in to the proceeding in some way.
#
#
# -----------------------------------------------------------------
# However, it is still important that he has an opportunity to consider the above interim conclusions and present any submissions that he might have in response within 14 days.
#
#
# -----------------------------------------------------------------
# Therefore, I hold that this is not a fit and proper case to exercise the discretion not to record a conviction.
#
#
# -----------------------------------------------------------------
# If it can do so a court will assess what it believes to be reasonable compensation in the circumstances.
#
#
# -----------------------------------------------------------------
# It was obliged, in this Court’s view, to make a determination of the appropriate compensation if there was sufficient evidence upon which it could do so.
#
#
# -----------------------------------------------------------------
# This court is satisfied that while it would have been desirable to have had other evidence there was sufficient evidence to come to the figure of $40,000.
#
#
# -----------------------------------------------------------------
# I consider it is appropriate to add considerations of what is the status of the reasons for the escapee's lawful custody at the first place.
#
#
# -----------------------------------------------------------------
# (2) Unless the Court otherwise directs, an affidavit for the purposes of this rule may contain statements of information or belief with the sources and grounds thereof.
#
#
# -----------------------------------------------------------------
# As a matter of urgency we are now considering the issues because it is clear that the matters outstanding in respect of these matters require to be brought to a conclusion and the delay to our next session in April 2002 needed to be avoided.
#
#
# -----------------------------------------------------------------
#  It is necessary before becoming lost in the procedural intricacies of this matter to have regard to the factual circumstances in which this litigation has its basis.
#
#
# -----------------------------------------------------------------
#  There can be no doubt that the issues which are raised are in a number of aspects of critical importance to this Republic and its future.
#
#
# -----------------------------------------------------------------
# There is an urgent need for hearing on the handful of basic issues which arise and will determine the cases.
#
#
# -----------------------------------------------------------------
# That is a matter for the Supreme Court, but to ensure that all matters are properly before the Court, it would appear sensible.
#
#
# -----------------------------------------------------------------
#  Any issues which require further consideration by the Court will best be dealt with after trial and determination when the facts have been established, if there is an appeal by any party.
#
#
# -----------------------------------------------------------------
#  (1) Against this factual background, it is necessary to turn to the applicable law and the judicial thinking in relation to the principles governing “striking-out”.
#
#
# -----------------------------------------------------------------
# Apart from truly exceptional cases the approach to such applications is to assume that the factual basis on which the allegations contained in the pleadings are raised will be proved.
#
#
# -----------------------------------------------------------------
# If a legal issue can be raised on the facts as pleaded then the courts will not strike out a pleading and will certainly not do so on a contention that the facts cannot be proved unless the situation is so strong that judicial notice can be taken of the falsity of a factual contention.
#
#
# -----------------------------------------------------------------
# Experience teaches that the concentration of attention, elaborated evidence and arguments and extended time for reflection will sometimes turn an apparently unpromising cause into a successful judgment.
#
#
# -----------------------------------------------------------------
# If there is a serious legal question to be determined, it should ordinarily be determined at a trial for the proof of facts may sometimes assist the judicial mind to understand and apply the law that is invoked and to do in circumstances more conducive to deciding a real case involving actual litigants rather than one determined on imagined or assumed facts.
#
#
# -----------------------------------------------------------------
# • “The first object of pleadings is to define and clarify with position the issues and questions which are in dispute between the parties and for determination by the Court.
#
#
# -----------------------------------------------------------------
# • “The first object of pleadings is to define and clarify with position the issues and questions which are in dispute between the parties and for determination by the Court.
#
#
# -----------------------------------------------------------------
# It will not attempt to resolve genuinely disputed issues of fact and therefore will generally limit evidence to that which is undisputed.
#
#
# -----------------------------------------------------------------
# The second Defendant cannot, in my Judgment, expect the Court to assess the requirements of Justice with its eyes in blinkers; It must look at all the circumstances.
#
#
# -----------------------------------------------------------------
# "When one has sensitive information in a firm or in any other group of people, there is the element of seepage of that information through casual chatter and discussion, the letting slip of some information which is not thought to be relevant but may make the link in a chain of causation or reasoning."
#
#
# -----------------------------------------------------------------
# I am of the view that this is not an issue which can be dealt by way of striking agreements with opposing counsel, as an afterthought.
#
#
# -----------------------------------------------------------------
# 11) For the reasons provided in the foregoing paragraphs I believe there to be an arguable appeal with a reasonable prospect of success.
#
#
# -----------------------------------------------------------------
# "We think it is plain from the terms of the judgment to which we have already referred that the Full Court was stating that error of law in the order does not in itself constitute substantial injustice, but that it is the result flowing from the erroneous order that is the important matter in determining whether substantial injustice will result."'
#
#
# -----------------------------------------------------------------
# I am satisfied that the greater interests of justice will be served if an opportunity to appeal out of time is granted in this case in order that the issues might be properly thrashed out.
#
#
# -----------------------------------------------------------------
# This is a difficult appeal in that the facts on which a decision must be based go back to the 1940's.
#
#
# -----------------------------------------------------------------
# [5] To be immediately appealable under the collateral order doctrine, the pretrial order must: 1) conclusively determine the disputed question; 2) resolve an important issue that is collateral to the merits of the case; and 3) be effectively unreviewable on appeal from a final judgment in the case.
#
#
# -----------------------------------------------------------------
# Several months later, Majhor renewed his motion, arguing that considerable media coverage of the case had poisoned the local jury pool and that, because of perceived jury bias, he desires to be tried elsewhere in one of the fifty states.
#
#
# -----------------------------------------------------------------
# In addition to the alleged media-inspired bias, Majhor argued below that Samoan cultural values remained anomalous to jury trials, and that Samoan juries are presumptively unable, because of longstanding cultural perspectives on justice generally and race[1] in particular, to impartially consider the evidence in his case.
#
#
# -----------------------------------------------------------------
# In short, Majhor believes that an all or largely Samoan jury will readily disregard the evidence before it and summarily convict him simply because he is non-Samoan and/or an "outsider.
#
#
# -----------------------------------------------------------------
# To be immediately appealable under Cohen, the pretrial order must: 1) conclusively determine the disputed question; 2) resolve an important issue that is collateral to the merits of the case; and 3) be effectively unreviewable on appeal from a final judgment in the case.
#
#
# -----------------------------------------------------------------
# A pretrial decision is effectively unreviewable if it "involve[s] an important right which would be lost, probably irreparably, if review had to await final judgment."
#
#
# -----------------------------------------------------------------
# Stated differently, the disputed order is effectively unreviewable if it concerns "an asserted right the legal and practical value of which would be destroyed if not vindicated before trial."
#
#
# -----------------------------------------------------------------
# On the contrary, we find that his right to an impartial jury would not, as a legal and practical matter, be irreparably lost or destroyed if not vindicated before trial.
#
#
# -----------------------------------------------------------------
# debate grounds, the right to an impartial jury does not involve the right to not be tried; rather, it merely involves the right not to be convicted under certain circumstances.
#
#
# -----------------------------------------------------------------
# While he correctly identifies the three Cohen factors, Majhor fails to explain how the Trial Court's order would be "effectively unreviewable" after judgment.
#
#
# -----------------------------------------------------------------
# Indeed, his only argument seems to be the presumptive claim that his trial would take on a "Kafka-like quality" if he was required to defend in a venue where possible juror bias exists.
#
#
# -----------------------------------------------------------------
# [4] In fact, Majhor's argument that he cannot impanel a fair and impartial jury cannot even be adequately addressed until after voir dire is conducted and the jury seated.
#
#
# -----------------------------------------------------------------
# Only then, once a record is created, can an appellate panel meaningfully review claimed juror bias.
#
#
# -----------------------------------------------------------------
# “In proceedings where evidence of identification is relevant, the Court should be mindful of all the inherent dangers, the need for caution before convicting in reliance on the correctness of identification, the possibility that a mistaken witness could be a convincing one and that any number of such witnesses could all be mistaken; the Court should examine closely all the circumstances in which the identification by each witness came to be made bearing in mind that recognition may be more reliable than identification of a stranger, but that even where the witness is purporting to recognize someone he knows mistakes can be made.
#
#
# -----------------------------------------------------------------
# When the quality of the identification evidence is good the matter should proceed to a verdict, when the quality of identification evidence is poor, unless there is other evidence which goes to support the correctness of the identification, an acquittal should be entered.”
#
#
# -----------------------------------------------------------------
# He seemed lost with questions that were straight forward and at many instances the prosecution had to press him to change his story.
#
#
# -----------------------------------------------------------------
# The stipulation by the Court of the kinds of factors and circumstances it may consider taking into account cannot be exhaustive.
#
#
# -----------------------------------------------------------------
# We think what is important to articulate are the factors and circumstances that may be relevant or appropriate in differing cases from time to time.
#
#
# -----------------------------------------------------------------
# The Learned Judge erred in law and in fact in failing to take into account all relevant matters to the case and all evidence adduced during the hearing of the assessment of damages.
#
#
# -----------------------------------------------------------------
# In my view, the grounds of appeal raise important questions on the assessment of damages, in cases where lessors renege on promises made to prospective lessees.
#
#
# -----------------------------------------------------------------
# That would be enough to conclude the matter unless the law holds otherwise, so I turn now to my understanding of the relevant law.
#
#
# -----------------------------------------------------------------
# And perhaps will also give evidence on the issue of delay and reasons for it.
#
#
# -----------------------------------------------------------------
# I do not know the experience of my fellow Judges but for my part, I would strongly discourage this practice by the prosecution of bringing part of it first and the rest of it later.
#
#
# -----------------------------------------------------------------
# If there is no agreement, then there has to be a trial on the facts to determine a proper basis for sentence.
#
#
# -----------------------------------------------------------------
# • From those observations made by the trial judge, it is apparent that he had in his mind the need to exercise caution in convicting on uncorroborated evidence of a young child.
#
#
# -----------------------------------------------------------------
# He went further to comment on the reasons why he determined that the evidence could be relied upon to support a conviction.
#
#
# -----------------------------------------------------------------
# ...
#
#
# -----------------------------------------------------------------
# He may choose to explain why it seems to him that there is a strong prima facie case or a weak prima facie case.
#
#
# -----------------------------------------------------------------
# If they do so and find that it is a strong prima facie prosecution case, it has never been the situation that a Judge or Magistrate has to recuse himself in respect of hearing the substantive criminal trial on account of apparent bias.
#
#
# -----------------------------------------------------------------
# The "apparent bias" test stresses that the observer has to be an "informed observer".
#
#
# -----------------------------------------------------------------
# Findings of fact on bail applications are necessarily prima facie findings of a tentative nature on limited material.
#
#
# -----------------------------------------------------------------
# In the appeal, the High Court of Australia found, a fair minded observer might entertain apprehension of bias, by reasons of the prejudgment of the issues or the credibility of a witness.
#
#
# -----------------------------------------------------------------
#  “In a case such as the present where there is no allegation of actual bias, the question whether a judge who is confident of his own ability to determine the case before him fairly and impartiality on the evidence should refrain from sitting because of a suggestion that the views which he has expressed in his judgment in some previous case may result in an appearance of pre-judgment can be a difficult one involving matters “of degree and particular circumstances may stoke difference minds in different ways” ( per Atkin J in Shaw).
#
#
# -----------------------------------------------------------------
# If a Judge at first instance considers that there is any real possibility that his participation in a case might lead to a reasonable apprehension of pre-judgment or bias, he should, of course, refrain from sitting”.
#
#
# -----------------------------------------------------------------
# • In view of these reasons, if I continue to hear these three proceedings, I certainly have to determine the credibility and reliability of the same witnesses and their evidence on the same issues which I have already determined in HAC 56 of 2014.
#
#
# -----------------------------------------------------------------
# Hence, it is apparent, that an informed reasonable fair minded person undoubtedly apprehends that there is a real likelihood or reasonable likelihood of pre-judgment of the witnesses and their evidence by the Judge.
#
#
# -----------------------------------------------------------------
# Therefore, I am of the view that there is a logical connection between the circumstances and the feared deviation of impartial and fair hearing.
#
#
# -----------------------------------------------------------------
# • Accordingly, it is my considered opinion that this case is a rare, but a fitting instance for me to recuse myself of hearing on the ground of apparent bias by reasons of pre-judgment.
#
#
# -----------------------------------------------------------------
# However I considered that the better course would be to stand back for some 48 hours to enable me to review the considerable amount of evidence before the Court and counsels' submissions to avoid the possibility of coming to a hasty decision although at the end of argument I had formed certain tentative conclusions.
#
#
# -----------------------------------------------------------------
# As a result of my giving as full a consideration as possible to the matter I find myself confirmed in the tentative views I had formed.
#
#
# -----------------------------------------------------------------
# Those he has implicated may be on notice that may occur so that they can attend and have the opportunity to hear that evidence and respond if they wish.
#
#
# -----------------------------------------------------------------
# To the extent that such conduct, if proved, may be relevant to how his appeal against sentence is dealt with, the Court of Appeal may make findings about it when dealing with the appeal.
#
#
# -----------------------------------------------------------------
# Frankly speaking, this Court lacks jurisdiction to determine the issue, suffice to say, but facts deposed are directly pinch on the issue of evidence, which ought to be considered in deciding the points of law.
#
#
# -----------------------------------------------------------------
# I am not satisfied the material evidence intended to reflect by the Chiefs determination could be believed.
#
#
# -----------------------------------------------------------------
# In my respectable view, it is subject to critical scrutiny and full of controversy.
#
#
# -----------------------------------------------------------------
# What are questions of law as opposed to question of mixed fact and law are not always easy to determine from the decided cases.
#
#
# -----------------------------------------------------------------
# The proper criteria that should be applied in determining this question is; whether it is in the best interest of a fair trial and the proper administration of justice that the case ought to be tried in the High Court.
#
#
# -----------------------------------------------------------------
# Whether a matter goes to the question of fair trial and the proper administration of justice is to be determined on the facts of each individual case.
#
#
# -----------------------------------------------------------------
# The question which arises for our consideration is whether the fact that a person who is unrepresented in a trial before a magistrate is a matter which comes within the principles we have enunciated.
#
#
# -----------------------------------------------------------------
# On the facts and circumstances of this case, it is accepted that there are some degree of provocation.
#
#
# -----------------------------------------------------------------
# “On this model the court makes no judgment of its own as to the relative weight to be attached to this or that factor taken into account in the decision-making process; it is concerned only to see that everything relevant and nothing irrelevant has been considered, and that a rational mind has been brought to bear by the [decision maker] in reaching the decision” (at page 14).
#
#
# -----------------------------------------------------------------
# • Let me now run through some of the cases that this court has dealt with in order to gauze the attitude of the court and to assist me in determining what an appropriate sentence for you should be.
#
#
# -----------------------------------------------------------------
# My consideration and determination of the matters argued are embodied in my reasons for decision.
#
#
# -----------------------------------------------------------------
# (iii) That there are clear arguable issues warranting leave to review the decision.
#
#
# -----------------------------------------------------------------
# Notwithstanding those findings, the majority found that grave injustice would occur if the decision was not reviewed in the circumstances of the case.
#
#
# -----------------------------------------------------------------
# In that case, the Court emphasized that the paramount consideration was whether there were cogent and convincing reasons that demonstrate substantial miscarriage of justice such that in the interest of justice, leave ought to be granted.
#
#
# -----------------------------------------------------------------
# In considering matters under any of those criteria, the Court is not determining the merits of those points.
#
#
# -----------------------------------------------------------------
# The Court should determine whether those points raise an arguable case for review based on a quick perusal of the material placed before it.
#
#
# -----------------------------------------------------------------
# That does mean to say that the Court should avoid determining points that clearly lack merit.
#
#
# -----------------------------------------------------------------
# He appeared before me several times at the directions hearing and exhibited ignorance tendencies which could be misleading.
#
#
# -----------------------------------------------------------------
# Exceptional circumstances showing manifestation of substantial injustice; or serious legal or factual issues that raise important and an arguable case for a full review of the decision
#
#
# -----------------------------------------------------------------
# Upon considering the arguments of counsel supporting their respective cases and the material placed before me, I consider the main point in contention to be whether the trial judge was correct with his interpretation and application of s 133 of the Land Act.
#
#
# -----------------------------------------------------------------
# Equally, if in the course of my review of the evidence I appear to express any views concerning facts, or emphasise a particular aspect of the evidence, do not adopt those views unless you agree with them and if I do not mention something which you think is important you should have regard to it and give it such weight as you think fit.
#
#
# -----------------------------------------------------------------
# You are entitled to draw inferences; that is to come to common sense conclusions based on the evidence which you accept, but you must not speculate about what evidence there may have been or allow yourselves to be drawn into speculation.
#
#
# -----------------------------------------------------------------
# You, individually and collectively, represent a pool of common sense and experience of human affairs in our community which qualifies you to be judges of the facts in the trial.
#
#
# -----------------------------------------------------------------
# You are expected and indeed required to use that common sense and experience in your deliberations and in deciding upon any proposition put to you and in evaluating the evidence in this trial.
#
#
# -----------------------------------------------------------------
# [13] However in looking at the information you must consider the case against and for each defendant separately; just as you must consider each count separately.
#
#
# -----------------------------------------------------------------
# [18] You may think it is only in a very rare case that a Court would receive direct evidence of a criminal conspiracy (e.g.
#
#
# -----------------------------------------------------------------
# Finally you should be careful to distinguish between arriving at conclusions based on reliable circumstantial evidence, and mere speculation.
#
#
# -----------------------------------------------------------------
# The things that a person being interviewed, says, is evidence for you to consider in your wider deliberations however I repeat the directions I gave you during the trial.
#
#
# -----------------------------------------------------------------
# Although there may be plenty of other evidence against the person who you think is blank, you can't use the interview.
#
#
# -----------------------------------------------------------------
# However he did choose to give evidence and you must take what he has said into account when considering the issues of fact which you have to determine.
#
#
# -----------------------------------------------------------------
# And there are times when nothing is interesting anymore because of the difficulties that my family is experiencing.
#
#
# -----------------------------------------------------------------
# [27] When looking at your own family situation and taking that into account for sentencing purposes there is, of course, another issue to reflect upon and that is this.
#
#
# -----------------------------------------------------------------
# You are not charged with those consequences, of course, but it is certainly a sobering thought to reflect upon when looking at the inevitable tragic impact the case is going to have on your own little family.
#
#
# -----------------------------------------------------------------
# In my view, however, little weight can be placed on that submission as a mitigating factor.
#
#
# -----------------------------------------------------------------
# •  Both parties where given each opportunities on cross examination to make representation on the issues of whether the CPE is wrong to grant timber rights on that particular land on the following questions:
#
#
# -----------------------------------------------------------------
# It is important reason for decision by the lower court must be available and matching up to the actual evidence adduce before it.
#
#
# -----------------------------------------------------------------
# 15 From those cases the Appellant must show that there are reasons to suspect that there is something wrong in connection with the hearing of the case which will assist formulate an argument that the conviction was unsafe or unsatisfactory.
#
#
# -----------------------------------------------------------------
# In this case, a transcript unreadable, a material requirement for the Court to properly determine the issue of facts upon which a conviction and sentence was based.
#
#
# -----------------------------------------------------------------
# 19 The factual situation of this case may be slightly different from Faramoa’s case, but the fact is that on equal basis, non of the Magistrates’ records of transcripts will ever assist this Court determine the issues on the appeal.
#
#
# -----------------------------------------------------------------
# I also find the Appellant has shown, should transcripts are available, the evidence will be the main focus of argument.
#
#
# -----------------------------------------------------------------
# So taking into account all the factors and circumstances in the present case including the precedents and bearing in mind that each case necessarily turns on its own particular facts I consider that the appropriate sentence in the present case is a custodial sentence.
#
#
# -----------------------------------------------------------------
# Therefore the probative value of such evidence will be outweighed by its prejudicial effect and will be too dangerous for the Court to admit.
#
#
# -----------------------------------------------------------------
# To prevent a false statement being fraudulent, there must, I think, always be an honest belief in its truth.”
#
#
# -----------------------------------------------------------------
# That, as we have seen, is not the case, but the concept of authority can unconsciously influence the inquiry in an unhelpful way.
#
#
# -----------------------------------------------------------------
# The case has often been understood to be an authority on apparent or ostensible agency, as Mr Templeton submitted it should be regarded, and indeed there are passages in the speeches which might support that view.
#
#
# -----------------------------------------------------------------
# • In assessing whether MF has committed the tort of deceit, I must be satisfied on the balance of probabilities that;
#
#
# -----------------------------------------------------------------
# • Out of the line of authorities that govern the subject in hand, I propose to set out hereunder few important citations, which I consider to be the guidance.
#
#
# -----------------------------------------------------------------
# What is required is that some tangible evidence establishing a right or supporting an arguable case for such right, must be adduced.”
#
#
# -----------------------------------------------------------------
# "If different conclusions are possible as to the ordinary meaning of the word "business" then it is necessary to decide which is the correct conclusion and that becomes a question of fact.
#
#
# -----------------------------------------------------------------
# I heard in evidence the reasons for the dispute over the correct amount of money but such reasons are not relevant to the question of liability to pay the correct amount.
