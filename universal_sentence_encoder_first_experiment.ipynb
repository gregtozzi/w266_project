# %% [markdown]
# # A very fast and loose first attempt with the universal sentence encoder
# #### Load packages

# %%
import pandas as pd
import numpy as np
import nltk
import tensorflow_hub as hub
from sklearn.cluster import MiniBatchKMeans

# %% [markdown]
# #### Load the pre-trained model from Tensor-Hub

# %%
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %% [markdown]
# #### Load our data
#
# In this case, I'm loading all of the text.

# %%
data = pd.read_csv('./data/cleaned_text.csv')

# %%
data.head()
# Out:
#     docid                                           contents  j_idx  s_idx  \
# 0   80380  Home | Databases | WorldLII | Search | Feedbac...    NaN  592.0
# 1   78839  Home | Databases | WorldLII | Search | Feedbac...  601.0    NaN
# 2  248796     State v Lagivere - Sentence [2017] FJHC 386...    NaN  874.0
# 3  257586     State v Goundar - Sentence [2018] FJHC 438;...    NaN  875.0
# 4   80121  Home | Databases | WorldLII | Search | Feedbac...    NaN  645.0
#
#    r_idx  d_idx  o_idx  type_idx  \
# 0    NaN    NaN    NaN       592
# 1    NaN    NaN    NaN       601
# 2    NaN    NaN    NaN       874
# 3    NaN    NaN    NaN       875
# 4    NaN    NaN    NaN       645
#
#                                     cleaned_contents
# 0  SENTENCE\n[Child Rape]\n\n[1] On the 11th Octo...
# 1  JUDGMENT\n\nOn the 12th of August 2004, the Ap...
# 2  SENTENCE\n \n  \n• Inoke Lagivere, you stand c...
# 3  SENTENCE\n \n \n (The name of the complainant ...
# 4  SENTENCE\nBackground\n[1] On the 17th July 201...

# %%
data.shape
# Out:
# (809, 9)

# %% [markdown]
# #### Split the documents into sentences using a custom function based on `punkt`

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/chris/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def split_sent(doc):
    doc_carriage_return = doc.split('\n')
    doc_carriage_return = [line for line in doc_carriage_return if line != '']
    sentences = []
    for line in doc_carriage_return:
        for sent in nltk.tokenize.sent_tokenize(line):
            sentences.append(sent)
    return sentences

# %% [markdown]
# #### Build embeddings from a subset of the documents

# %%
docs = list(data.cleaned_contents)

# %%
sentences = []
for doc in docs[:1000]:
    for sent in split_sent(doc):
        sentences.append(sent)

# %%
len(sentences)
# Out:
# 80692

# %%
embeddings = embed(sentences[:30000]).numpy()

# %%
embeddings.shape
# Out:
# (30000, 512)

# %% [markdown]
# #### Cluster the embeddings

# %%
clust = MiniBatchKMeans(n_clusters=500, verbose=1)
clust.fit(embeddings)
y_hat = clust.predict(embeddings)
# Out:
# Init 1/3 with method: k-means++
# /Users/chris/anaconda3/envs/w266/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:1576: RuntimeWarning: init_size=300 should be larger than k=500. Setting it to 3*k
#   init_size=init_size)
# Inertia for init 1/3: 52.849937
# Init 2/3 with method: k-means++
# /Users/chris/anaconda3/envs/w266/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:1576: RuntimeWarning: init_size=300 should be larger than k=500. Setting it to 3*k
#   init_size=init_size)
# Inertia for init 2/3: 54.443264
# Init 3/3 with method: k-means++
# /Users/chris/anaconda3/envs/w266/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:1576: RuntimeWarning: init_size=300 should be larger than k=500. Setting it to 3*k
#   init_size=init_size)
# Inertia for init 3/3: 51.134789
# Minibatch iteration 1/30000: mean batch inertia: 0.704741, ewa inertia: 0.704741
# Minibatch iteration 2/30000: mean batch inertia: 0.654610, ewa inertia: 0.704407
# Minibatch iteration 3/30000: mean batch inertia: 0.594080, ewa inertia: 0.703672
# Minibatch iteration 4/30000: mean batch inertia: 0.745141, ewa inertia: 0.703948
# Minibatch iteration 5/30000: mean batch inertia: 0.620763, ewa inertia: 0.703393
# Minibatch iteration 6/30000: mean batch inertia: 0.644112, ewa inertia: 0.702998
# Minibatch iteration 7/30000: mean batch inertia: 0.654428, ewa inertia: 0.702674
# Minibatch iteration 8/30000: mean batch inertia: 0.616427, ewa inertia: 0.702099
# Minibatch iteration 9/30000: mean batch inertia: 0.550556, ewa inertia: 0.701089
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 10/30000: mean batch inertia: 0.533098, ewa inertia: 0.699969
# Minibatch iteration 11/30000: mean batch inertia: 0.608938, ewa inertia: 0.699362
# Minibatch iteration 12/30000: mean batch inertia: 0.612491, ewa inertia: 0.698783
# Minibatch iteration 13/30000: mean batch inertia: 0.580143, ewa inertia: 0.697992
# Minibatch iteration 14/30000: mean batch inertia: 0.639397, ewa inertia: 0.697602
# Minibatch iteration 15/30000: mean batch inertia: 0.596272, ewa inertia: 0.696926
# Minibatch iteration 16/30000: mean batch inertia: 0.590908, ewa inertia: 0.696220
# Minibatch iteration 17/30000: mean batch inertia: 0.589225, ewa inertia: 0.695506
# Minibatch iteration 18/30000: mean batch inertia: 0.554715, ewa inertia: 0.694568
# Minibatch iteration 19/30000: mean batch inertia: 0.588739, ewa inertia: 0.693862
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 20/30000: mean batch inertia: 0.511629, ewa inertia: 0.692647
# Minibatch iteration 21/30000: mean batch inertia: 0.516575, ewa inertia: 0.691474
# Minibatch iteration 22/30000: mean batch inertia: 0.576714, ewa inertia: 0.690709
# Minibatch iteration 23/30000: mean batch inertia: 0.621923, ewa inertia: 0.690250
# Minibatch iteration 24/30000: mean batch inertia: 0.519525, ewa inertia: 0.689112
# Minibatch iteration 25/30000: mean batch inertia: 0.563887, ewa inertia: 0.688277
# Minibatch iteration 26/30000: mean batch inertia: 0.537509, ewa inertia: 0.687272
# Minibatch iteration 27/30000: mean batch inertia: 0.578411, ewa inertia: 0.686546
# Minibatch iteration 28/30000: mean batch inertia: 0.595509, ewa inertia: 0.685939
# Minibatch iteration 29/30000: mean batch inertia: 0.519791, ewa inertia: 0.684832
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 30/30000: mean batch inertia: 0.529350, ewa inertia: 0.683795
# Minibatch iteration 31/30000: mean batch inertia: 0.577333, ewa inertia: 0.683085
# Minibatch iteration 32/30000: mean batch inertia: 0.559961, ewa inertia: 0.682265
# Minibatch iteration 33/30000: mean batch inertia: 0.588394, ewa inertia: 0.681639
# Minibatch iteration 34/30000: mean batch inertia: 0.587023, ewa inertia: 0.681008
# Minibatch iteration 35/30000: mean batch inertia: 0.506903, ewa inertia: 0.679847
# Minibatch iteration 36/30000: mean batch inertia: 0.563497, ewa inertia: 0.679072
# Minibatch iteration 37/30000: mean batch inertia: 0.620905, ewa inertia: 0.678684
# Minibatch iteration 38/30000: mean batch inertia: 0.595029, ewa inertia: 0.678126
# Minibatch iteration 39/30000: mean batch inertia: 0.604065, ewa inertia: 0.677633
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 40/30000: mean batch inertia: 0.545920, ewa inertia: 0.676755
# Minibatch iteration 41/30000: mean batch inertia: 0.584319, ewa inertia: 0.676138
# Minibatch iteration 42/30000: mean batch inertia: 0.607768, ewa inertia: 0.675683
# Minibatch iteration 43/30000: mean batch inertia: 0.549471, ewa inertia: 0.674841
# Minibatch iteration 44/30000: mean batch inertia: 0.567611, ewa inertia: 0.674126
# Minibatch iteration 45/30000: mean batch inertia: 0.602096, ewa inertia: 0.673646
# Minibatch iteration 46/30000: mean batch inertia: 0.504056, ewa inertia: 0.672516
# Minibatch iteration 47/30000: mean batch inertia: 0.566283, ewa inertia: 0.671807
# Minibatch iteration 48/30000: mean batch inertia: 0.559679, ewa inertia: 0.671060
# Minibatch iteration 49/30000: mean batch inertia: 0.581121, ewa inertia: 0.670460
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 50/30000: mean batch inertia: 0.546095, ewa inertia: 0.669631
# Minibatch iteration 51/30000: mean batch inertia: 0.568099, ewa inertia: 0.668954
# Minibatch iteration 52/30000: mean batch inertia: 0.626134, ewa inertia: 0.668669
# Minibatch iteration 53/30000: mean batch inertia: 0.515599, ewa inertia: 0.667649
# Minibatch iteration 54/30000: mean batch inertia: 0.572858, ewa inertia: 0.667017
# Minibatch iteration 55/30000: mean batch inertia: 0.549363, ewa inertia: 0.666232
# Minibatch iteration 56/30000: mean batch inertia: 0.572628, ewa inertia: 0.665608
# Minibatch iteration 57/30000: mean batch inertia: 0.598771, ewa inertia: 0.665163
# Minibatch iteration 58/30000: mean batch inertia: 0.568029, ewa inertia: 0.664515
# Minibatch iteration 59/30000: mean batch inertia: 0.494876, ewa inertia: 0.663384
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 60/30000: mean batch inertia: 0.511434, ewa inertia: 0.662371
# Minibatch iteration 61/30000: mean batch inertia: 0.536033, ewa inertia: 0.661529
# Minibatch iteration 62/30000: mean batch inertia: 0.497214, ewa inertia: 0.660434
# Minibatch iteration 63/30000: mean batch inertia: 0.510843, ewa inertia: 0.659436
# Minibatch iteration 64/30000: mean batch inertia: 0.517572, ewa inertia: 0.658491
# Minibatch iteration 65/30000: mean batch inertia: 0.571018, ewa inertia: 0.657908
# Minibatch iteration 66/30000: mean batch inertia: 0.568576, ewa inertia: 0.657312
# Minibatch iteration 67/30000: mean batch inertia: 0.575791, ewa inertia: 0.656769
# Minibatch iteration 68/30000: mean batch inertia: 0.559463, ewa inertia: 0.656120
# Minibatch iteration 69/30000: mean batch inertia: 0.551326, ewa inertia: 0.655421
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 70/30000: mean batch inertia: 0.543639, ewa inertia: 0.654676
# Minibatch iteration 71/30000: mean batch inertia: 0.561447, ewa inertia: 0.654055
# Minibatch iteration 72/30000: mean batch inertia: 0.571121, ewa inertia: 0.653502
# Minibatch iteration 73/30000: mean batch inertia: 0.537515, ewa inertia: 0.652729
# Minibatch iteration 74/30000: mean batch inertia: 0.529040, ewa inertia: 0.651904
# Minibatch iteration 75/30000: mean batch inertia: 0.558007, ewa inertia: 0.651278
# Minibatch iteration 76/30000: mean batch inertia: 0.542844, ewa inertia: 0.650555
# Minibatch iteration 77/30000: mean batch inertia: 0.551963, ewa inertia: 0.649898
# Minibatch iteration 78/30000: mean batch inertia: 0.530045, ewa inertia: 0.649099
# Minibatch iteration 79/30000: mean batch inertia: 0.573313, ewa inertia: 0.648594
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 80/30000: mean batch inertia: 0.514631, ewa inertia: 0.647701
# Minibatch iteration 81/30000: mean batch inertia: 0.533527, ewa inertia: 0.646939
# Minibatch iteration 82/30000: mean batch inertia: 0.589678, ewa inertia: 0.646558
# Minibatch iteration 83/30000: mean batch inertia: 0.538138, ewa inertia: 0.645835
# Minibatch iteration 84/30000: mean batch inertia: 0.519558, ewa inertia: 0.644993
# Minibatch iteration 85/30000: mean batch inertia: 0.526433, ewa inertia: 0.644203
# Minibatch iteration 86/30000: mean batch inertia: 0.577105, ewa inertia: 0.643755
# Minibatch iteration 87/30000: mean batch inertia: 0.617590, ewa inertia: 0.643581
# Minibatch iteration 88/30000: mean batch inertia: 0.552753, ewa inertia: 0.642976
# Minibatch iteration 89/30000: mean batch inertia: 0.547125, ewa inertia: 0.642337
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 90/30000: mean batch inertia: 0.520899, ewa inertia: 0.641527
# Minibatch iteration 91/30000: mean batch inertia: 0.525921, ewa inertia: 0.640756
# Minibatch iteration 92/30000: mean batch inertia: 0.547703, ewa inertia: 0.640136
# Minibatch iteration 93/30000: mean batch inertia: 0.485390, ewa inertia: 0.639104
# Minibatch iteration 94/30000: mean batch inertia: 0.484125, ewa inertia: 0.638071
# Minibatch iteration 95/30000: mean batch inertia: 0.528799, ewa inertia: 0.637343
# Minibatch iteration 96/30000: mean batch inertia: 0.496215, ewa inertia: 0.636402
# Minibatch iteration 97/30000: mean batch inertia: 0.495338, ewa inertia: 0.635462
# Minibatch iteration 98/30000: mean batch inertia: 0.569702, ewa inertia: 0.635023
# Minibatch iteration 99/30000: mean batch inertia: 0.601949, ewa inertia: 0.634803
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 100/30000: mean batch inertia: 0.535536, ewa inertia: 0.634141
# Minibatch iteration 101/30000: mean batch inertia: 0.567808, ewa inertia: 0.633699
# Minibatch iteration 102/30000: mean batch inertia: 0.554562, ewa inertia: 0.633171
# Minibatch iteration 103/30000: mean batch inertia: 0.554966, ewa inertia: 0.632650
# Minibatch iteration 104/30000: mean batch inertia: 0.548016, ewa inertia: 0.632086
# Minibatch iteration 105/30000: mean batch inertia: 0.532095, ewa inertia: 0.631419
# Minibatch iteration 106/30000: mean batch inertia: 0.538608, ewa inertia: 0.630800
# Minibatch iteration 107/30000: mean batch inertia: 0.520479, ewa inertia: 0.630065
# Minibatch iteration 108/30000: mean batch inertia: 0.540788, ewa inertia: 0.629470
# Minibatch iteration 109/30000: mean batch inertia: 0.548566, ewa inertia: 0.628930
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 110/30000: mean batch inertia: 0.521161, ewa inertia: 0.628212
# Minibatch iteration 111/30000: mean batch inertia: 0.545456, ewa inertia: 0.627660
# Minibatch iteration 112/30000: mean batch inertia: 0.538090, ewa inertia: 0.627063
# Minibatch iteration 113/30000: mean batch inertia: 0.481241, ewa inertia: 0.626091
# Minibatch iteration 114/30000: mean batch inertia: 0.530940, ewa inertia: 0.625457
# Minibatch iteration 115/30000: mean batch inertia: 0.451352, ewa inertia: 0.624296
# Minibatch iteration 116/30000: mean batch inertia: 0.532129, ewa inertia: 0.623682
# Minibatch iteration 117/30000: mean batch inertia: 0.475694, ewa inertia: 0.622695
# Minibatch iteration 118/30000: mean batch inertia: 0.507707, ewa inertia: 0.621928
# Minibatch iteration 119/30000: mean batch inertia: 0.503953, ewa inertia: 0.621142
# Minibatch iteration 120/30000: mean batch inertia: 0.518619, ewa inertia: 0.620459
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 121/30000: mean batch inertia: 0.564799, ewa inertia: 0.620087
# Minibatch iteration 122/30000: mean batch inertia: 0.546576, ewa inertia: 0.619597
# Minibatch iteration 123/30000: mean batch inertia: 0.535127, ewa inertia: 0.619034
# Minibatch iteration 124/30000: mean batch inertia: 0.540709, ewa inertia: 0.618512
# Minibatch iteration 125/30000: mean batch inertia: 0.522890, ewa inertia: 0.617875
# Minibatch iteration 126/30000: mean batch inertia: 0.536545, ewa inertia: 0.617333
# Minibatch iteration 127/30000: mean batch inertia: 0.501765, ewa inertia: 0.616562
# Minibatch iteration 128/30000: mean batch inertia: 0.565551, ewa inertia: 0.616222
# Minibatch iteration 129/30000: mean batch inertia: 0.495199, ewa inertia: 0.615415
# Minibatch iteration 130/30000: mean batch inertia: 0.530513, ewa inertia: 0.614849
# Minibatch iteration 131/30000: mean batch inertia: 0.528837, ewa inertia: 0.614276
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 132/30000: mean batch inertia: 0.539669, ewa inertia: 0.613778
# Minibatch iteration 133/30000: mean batch inertia: 0.527181, ewa inertia: 0.613201
# Minibatch iteration 134/30000: mean batch inertia: 0.532150, ewa inertia: 0.612661
# Minibatch iteration 135/30000: mean batch inertia: 0.551615, ewa inertia: 0.612254
# Minibatch iteration 136/30000: mean batch inertia: 0.510131, ewa inertia: 0.611573
# Minibatch iteration 137/30000: mean batch inertia: 0.464052, ewa inertia: 0.610590
# Minibatch iteration 138/30000: mean batch inertia: 0.547227, ewa inertia: 0.610167
# Minibatch iteration 139/30000: mean batch inertia: 0.523188, ewa inertia: 0.609587
# Minibatch iteration 140/30000: mean batch inertia: 0.573563, ewa inertia: 0.609347
# Minibatch iteration 141/30000: mean batch inertia: 0.514689, ewa inertia: 0.608716
# Minibatch iteration 142/30000: mean batch inertia: 0.493432, ewa inertia: 0.607948
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 143/30000: mean batch inertia: 0.558878, ewa inertia: 0.607621
# Minibatch iteration 144/30000: mean batch inertia: 0.534344, ewa inertia: 0.607132
# Minibatch iteration 145/30000: mean batch inertia: 0.539158, ewa inertia: 0.606679
# Minibatch iteration 146/30000: mean batch inertia: 0.515907, ewa inertia: 0.606074
# Minibatch iteration 147/30000: mean batch inertia: 0.516000, ewa inertia: 0.605473
# Minibatch iteration 148/30000: mean batch inertia: 0.532079, ewa inertia: 0.604984
# Minibatch iteration 149/30000: mean batch inertia: 0.558783, ewa inertia: 0.604676
# Minibatch iteration 150/30000: mean batch inertia: 0.563246, ewa inertia: 0.604400
# Minibatch iteration 151/30000: mean batch inertia: 0.543107, ewa inertia: 0.603991
# Minibatch iteration 152/30000: mean batch inertia: 0.530501, ewa inertia: 0.603501
# Minibatch iteration 153/30000: mean batch inertia: 0.508094, ewa inertia: 0.602865
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 154/30000: mean batch inertia: 0.480998, ewa inertia: 0.602053
# Minibatch iteration 155/30000: mean batch inertia: 0.495608, ewa inertia: 0.601343
# Minibatch iteration 156/30000: mean batch inertia: 0.525485, ewa inertia: 0.600838
# Minibatch iteration 157/30000: mean batch inertia: 0.501013, ewa inertia: 0.600172
# Minibatch iteration 158/30000: mean batch inertia: 0.468430, ewa inertia: 0.599294
# Minibatch iteration 159/30000: mean batch inertia: 0.551449, ewa inertia: 0.598975
# Minibatch iteration 160/30000: mean batch inertia: 0.462759, ewa inertia: 0.598067
# Minibatch iteration 161/30000: mean batch inertia: 0.556166, ewa inertia: 0.597787
# Minibatch iteration 162/30000: mean batch inertia: 0.498713, ewa inertia: 0.597127
# Minibatch iteration 163/30000: mean batch inertia: 0.543485, ewa inertia: 0.596769
# Minibatch iteration 164/30000: mean batch inertia: 0.540206, ewa inertia: 0.596392
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 165/30000: mean batch inertia: 0.502417, ewa inertia: 0.595766
# Minibatch iteration 166/30000: mean batch inertia: 0.532384, ewa inertia: 0.595343
# Minibatch iteration 167/30000: mean batch inertia: 0.518446, ewa inertia: 0.594831
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 168/30000: mean batch inertia: 0.557172, ewa inertia: 0.594580
# Minibatch iteration 169/30000: mean batch inertia: 0.537908, ewa inertia: 0.594202
# Minibatch iteration 170/30000: mean batch inertia: 0.570494, ewa inertia: 0.594044
# Minibatch iteration 171/30000: mean batch inertia: 0.575452, ewa inertia: 0.593920
# Minibatch iteration 172/30000: mean batch inertia: 0.555785, ewa inertia: 0.593666
# Minibatch iteration 173/30000: mean batch inertia: 0.563414, ewa inertia: 0.593464
# Minibatch iteration 174/30000: mean batch inertia: 0.441754, ewa inertia: 0.592453
# Minibatch iteration 175/30000: mean batch inertia: 0.517329, ewa inertia: 0.591952
# Minibatch iteration 176/30000: mean batch inertia: 0.530248, ewa inertia: 0.591540
# Minibatch iteration 177/30000: mean batch inertia: 0.523918, ewa inertia: 0.591090
# Minibatch iteration 178/30000: mean batch inertia: 0.528800, ewa inertia: 0.590674
# Minibatch iteration 179/30000: mean batch inertia: 0.545516, ewa inertia: 0.590373
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 180/30000: mean batch inertia: 0.518859, ewa inertia: 0.589897
# Minibatch iteration 181/30000: mean batch inertia: 0.500601, ewa inertia: 0.589301
# Minibatch iteration 182/30000: mean batch inertia: 0.528348, ewa inertia: 0.588895
# Minibatch iteration 183/30000: mean batch inertia: 0.453988, ewa inertia: 0.587996
# Minibatch iteration 184/30000: mean batch inertia: 0.531172, ewa inertia: 0.587617
# Minibatch iteration 185/30000: mean batch inertia: 0.528619, ewa inertia: 0.587224
# Minibatch iteration 186/30000: mean batch inertia: 0.540983, ewa inertia: 0.586915
# Minibatch iteration 187/30000: mean batch inertia: 0.538303, ewa inertia: 0.586591
# Minibatch iteration 188/30000: mean batch inertia: 0.522561, ewa inertia: 0.586164
# Minibatch iteration 189/30000: mean batch inertia: 0.482984, ewa inertia: 0.585476
# Minibatch iteration 190/30000: mean batch inertia: 0.500404, ewa inertia: 0.584909
# Minibatch iteration 191/30000: mean batch inertia: 0.555843, ewa inertia: 0.584716
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 192/30000: mean batch inertia: 0.530798, ewa inertia: 0.584356
# Minibatch iteration 193/30000: mean batch inertia: 0.498852, ewa inertia: 0.583786
# Minibatch iteration 194/30000: mean batch inertia: 0.540626, ewa inertia: 0.583498
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 195/30000: mean batch inertia: 0.526913, ewa inertia: 0.583121
# Minibatch iteration 196/30000: mean batch inertia: 0.544415, ewa inertia: 0.582863
# Minibatch iteration 197/30000: mean batch inertia: 0.479461, ewa inertia: 0.582174
# Minibatch iteration 198/30000: mean batch inertia: 0.486374, ewa inertia: 0.581535
# Minibatch iteration 199/30000: mean batch inertia: 0.513767, ewa inertia: 0.581083
# Minibatch iteration 200/30000: mean batch inertia: 0.544745, ewa inertia: 0.580841
# Minibatch iteration 201/30000: mean batch inertia: 0.505329, ewa inertia: 0.580338
# Minibatch iteration 202/30000: mean batch inertia: 0.574217, ewa inertia: 0.580297
# Minibatch iteration 203/30000: mean batch inertia: 0.540272, ewa inertia: 0.580030
# Minibatch iteration 204/30000: mean batch inertia: 0.493756, ewa inertia: 0.579455
# Minibatch iteration 205/30000: mean batch inertia: 0.509238, ewa inertia: 0.578987
# Minibatch iteration 206/30000: mean batch inertia: 0.514698, ewa inertia: 0.578558
# Minibatch iteration 207/30000: mean batch inertia: 0.479397, ewa inertia: 0.577897
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 208/30000: mean batch inertia: 0.521993, ewa inertia: 0.577525
# Minibatch iteration 209/30000: mean batch inertia: 0.520615, ewa inertia: 0.577145
# Minibatch iteration 210/30000: mean batch inertia: 0.494093, ewa inertia: 0.576592
# Minibatch iteration 211/30000: mean batch inertia: 0.538769, ewa inertia: 0.576339
# Minibatch iteration 212/30000: mean batch inertia: 0.478413, ewa inertia: 0.575687
# Minibatch iteration 213/30000: mean batch inertia: 0.528044, ewa inertia: 0.575369
# Minibatch iteration 214/30000: mean batch inertia: 0.543913, ewa inertia: 0.575159
# Minibatch iteration 215/30000: mean batch inertia: 0.510127, ewa inertia: 0.574726
# Minibatch iteration 216/30000: mean batch inertia: 0.584727, ewa inertia: 0.574792
# Minibatch iteration 217/30000: mean batch inertia: 0.517964, ewa inertia: 0.574414
# Minibatch iteration 218/30000: mean batch inertia: 0.506896, ewa inertia: 0.573963
# Minibatch iteration 219/30000: mean batch inertia: 0.562862, ewa inertia: 0.573889
# Minibatch iteration 220/30000: mean batch inertia: 0.521119, ewa inertia: 0.573538
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 221/30000: mean batch inertia: 0.533707, ewa inertia: 0.573272
# Minibatch iteration 222/30000: mean batch inertia: 0.525372, ewa inertia: 0.572953
# Minibatch iteration 223/30000: mean batch inertia: 0.492020, ewa inertia: 0.572413
# Minibatch iteration 224/30000: mean batch inertia: 0.521205, ewa inertia: 0.572072
# Minibatch iteration 225/30000: mean batch inertia: 0.461675, ewa inertia: 0.571336
# Minibatch iteration 226/30000: mean batch inertia: 0.507535, ewa inertia: 0.570911
# Minibatch iteration 227/30000: mean batch inertia: 0.496682, ewa inertia: 0.570416
# Minibatch iteration 228/30000: mean batch inertia: 0.549181, ewa inertia: 0.570274
# Minibatch iteration 229/30000: mean batch inertia: 0.490368, ewa inertia: 0.569742
# Minibatch iteration 230/30000: mean batch inertia: 0.564232, ewa inertia: 0.569705
# Minibatch iteration 231/30000: mean batch inertia: 0.491844, ewa inertia: 0.569186
# Minibatch iteration 232/30000: mean batch inertia: 0.502894, ewa inertia: 0.568744
# Minibatch iteration 233/30000: mean batch inertia: 0.482482, ewa inertia: 0.568169
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 234/30000: mean batch inertia: 0.554460, ewa inertia: 0.568077
# Minibatch iteration 235/30000: mean batch inertia: 0.522595, ewa inertia: 0.567774
# Minibatch iteration 236/30000: mean batch inertia: 0.520009, ewa inertia: 0.567456
# Minibatch iteration 237/30000: mean batch inertia: 0.570787, ewa inertia: 0.567478
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 238/30000: mean batch inertia: 0.519444, ewa inertia: 0.567158
# Minibatch iteration 239/30000: mean batch inertia: 0.524493, ewa inertia: 0.566873
# Minibatch iteration 240/30000: mean batch inertia: 0.516180, ewa inertia: 0.566535
# Minibatch iteration 241/30000: mean batch inertia: 0.516416, ewa inertia: 0.566201
# Minibatch iteration 242/30000: mean batch inertia: 0.523892, ewa inertia: 0.565919
# Minibatch iteration 243/30000: mean batch inertia: 0.495348, ewa inertia: 0.565449
# Minibatch iteration 244/30000: mean batch inertia: 0.500882, ewa inertia: 0.565018
# Minibatch iteration 245/30000: mean batch inertia: 0.510718, ewa inertia: 0.564656
# Minibatch iteration 246/30000: mean batch inertia: 0.508955, ewa inertia: 0.564285
# Minibatch iteration 247/30000: mean batch inertia: 0.450073, ewa inertia: 0.563524
# Minibatch iteration 248/30000: mean batch inertia: 0.479113, ewa inertia: 0.562961
# Minibatch iteration 249/30000: mean batch inertia: 0.505712, ewa inertia: 0.562579
# Minibatch iteration 250/30000: mean batch inertia: 0.495586, ewa inertia: 0.562133
# Minibatch iteration 251/30000: mean batch inertia: 0.523735, ewa inertia: 0.561877
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 252/30000: mean batch inertia: 0.492829, ewa inertia: 0.561416
# Minibatch iteration 253/30000: mean batch inertia: 0.507586, ewa inertia: 0.561057
# Minibatch iteration 254/30000: mean batch inertia: 0.512395, ewa inertia: 0.560733
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 255/30000: mean batch inertia: 0.502152, ewa inertia: 0.560343
# Minibatch iteration 256/30000: mean batch inertia: 0.495092, ewa inertia: 0.559908
# Minibatch iteration 257/30000: mean batch inertia: 0.512006, ewa inertia: 0.559588
# Minibatch iteration 258/30000: mean batch inertia: 0.511709, ewa inertia: 0.559269
# Minibatch iteration 259/30000: mean batch inertia: 0.546052, ewa inertia: 0.559181
# Minibatch iteration 260/30000: mean batch inertia: 0.510153, ewa inertia: 0.558854
# Minibatch iteration 261/30000: mean batch inertia: 0.469312, ewa inertia: 0.558257
# Minibatch iteration 262/30000: mean batch inertia: 0.535071, ewa inertia: 0.558103
# Minibatch iteration 263/30000: mean batch inertia: 0.553735, ewa inertia: 0.558073
# Minibatch iteration 264/30000: mean batch inertia: 0.507415, ewa inertia: 0.557736
# Minibatch iteration 265/30000: mean batch inertia: 0.555438, ewa inertia: 0.557720
# Minibatch iteration 266/30000: mean batch inertia: 0.537587, ewa inertia: 0.557586
# Minibatch iteration 267/30000: mean batch inertia: 0.487420, ewa inertia: 0.557118
# Minibatch iteration 268/30000: mean batch inertia: 0.509846, ewa inertia: 0.556803
# Minibatch iteration 269/30000: mean batch inertia: 0.492214, ewa inertia: 0.556373
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 270/30000: mean batch inertia: 0.523413, ewa inertia: 0.556153
# Minibatch iteration 271/30000: mean batch inertia: 0.480501, ewa inertia: 0.555649
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 272/30000: mean batch inertia: 0.462784, ewa inertia: 0.555030
# Minibatch iteration 273/30000: mean batch inertia: 0.481102, ewa inertia: 0.554537
# Minibatch iteration 274/30000: mean batch inertia: 0.543189, ewa inertia: 0.554461
# Minibatch iteration 275/30000: mean batch inertia: 0.501128, ewa inertia: 0.554106
# Minibatch iteration 276/30000: mean batch inertia: 0.546105, ewa inertia: 0.554052
# Minibatch iteration 277/30000: mean batch inertia: 0.474195, ewa inertia: 0.553520
# Minibatch iteration 278/30000: mean batch inertia: 0.541223, ewa inertia: 0.553438
# Minibatch iteration 279/30000: mean batch inertia: 0.515527, ewa inertia: 0.553185
# Minibatch iteration 280/30000: mean batch inertia: 0.512005, ewa inertia: 0.552911
# Minibatch iteration 281/30000: mean batch inertia: 0.557710, ewa inertia: 0.552943
# Minibatch iteration 282/30000: mean batch inertia: 0.464258, ewa inertia: 0.552351
# Minibatch iteration 283/30000: mean batch inertia: 0.484622, ewa inertia: 0.551900
# Minibatch iteration 284/30000: mean batch inertia: 0.528952, ewa inertia: 0.551747
# Minibatch iteration 285/30000: mean batch inertia: 0.514412, ewa inertia: 0.551498
# Minibatch iteration 286/30000: mean batch inertia: 0.525749, ewa inertia: 0.551326
# Minibatch iteration 287/30000: mean batch inertia: 0.545989, ewa inertia: 0.551291
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 288/30000: mean batch inertia: 0.560813, ewa inertia: 0.551354
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 289/30000: mean batch inertia: 0.533390, ewa inertia: 0.551235
# Minibatch iteration 290/30000: mean batch inertia: 0.477506, ewa inertia: 0.550743
# Minibatch iteration 291/30000: mean batch inertia: 0.539173, ewa inertia: 0.550666
# Minibatch iteration 292/30000: mean batch inertia: 0.575635, ewa inertia: 0.550832
# Minibatch iteration 293/30000: mean batch inertia: 0.552789, ewa inertia: 0.550845
# Minibatch iteration 294/30000: mean batch inertia: 0.466706, ewa inertia: 0.550284
# Minibatch iteration 295/30000: mean batch inertia: 0.542361, ewa inertia: 0.550232
# Minibatch iteration 296/30000: mean batch inertia: 0.507625, ewa inertia: 0.549948
# Minibatch iteration 297/30000: mean batch inertia: 0.501096, ewa inertia: 0.549622
# Minibatch iteration 298/30000: mean batch inertia: 0.520296, ewa inertia: 0.549426
# Minibatch iteration 299/30000: mean batch inertia: 0.498265, ewa inertia: 0.549085
# Minibatch iteration 300/30000: mean batch inertia: 0.528430, ewa inertia: 0.548948
# Minibatch iteration 301/30000: mean batch inertia: 0.484920, ewa inertia: 0.548521
# Minibatch iteration 302/30000: mean batch inertia: 0.485560, ewa inertia: 0.548101
# Minibatch iteration 303/30000: mean batch inertia: 0.505903, ewa inertia: 0.547820
# Minibatch iteration 304/30000: mean batch inertia: 0.535530, ewa inertia: 0.547738
# Minibatch iteration 305/30000: mean batch inertia: 0.508244, ewa inertia: 0.547475
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 306/30000: mean batch inertia: 0.536383, ewa inertia: 0.547401
# Minibatch iteration 307/30000: mean batch inertia: 0.555150, ewa inertia: 0.547452
# Minibatch iteration 308/30000: mean batch inertia: 0.508655, ewa inertia: 0.547194
# Minibatch iteration 309/30000: mean batch inertia: 0.474615, ewa inertia: 0.546710
# Minibatch iteration 310/30000: mean batch inertia: 0.527283, ewa inertia: 0.546580
# Minibatch iteration 311/30000: mean batch inertia: 0.556408, ewa inertia: 0.546646
# Minibatch iteration 312/30000: mean batch inertia: 0.466494, ewa inertia: 0.546112
# Minibatch iteration 313/30000: mean batch inertia: 0.556130, ewa inertia: 0.546178
# Minibatch iteration 314/30000: mean batch inertia: 0.524270, ewa inertia: 0.546032
# Minibatch iteration 315/30000: mean batch inertia: 0.482994, ewa inertia: 0.545612
# Minibatch iteration 316/30000: mean batch inertia: 0.493800, ewa inertia: 0.545267
# Minibatch iteration 317/30000: mean batch inertia: 0.484396, ewa inertia: 0.544861
# Minibatch iteration 318/30000: mean batch inertia: 0.502068, ewa inertia: 0.544576
# Minibatch iteration 319/30000: mean batch inertia: 0.476676, ewa inertia: 0.544123
# Minibatch iteration 320/30000: mean batch inertia: 0.509565, ewa inertia: 0.543893
# Minibatch iteration 321/30000: mean batch inertia: 0.541648, ewa inertia: 0.543878
# Minibatch iteration 322/30000: mean batch inertia: 0.511745, ewa inertia: 0.543663
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 323/30000: mean batch inertia: 0.544190, ewa inertia: 0.543667
# Minibatch iteration 324/30000: mean batch inertia: 0.545764, ewa inertia: 0.543681
# Minibatch iteration 325/30000: mean batch inertia: 0.475194, ewa inertia: 0.543224
# Minibatch iteration 326/30000: mean batch inertia: 0.494899, ewa inertia: 0.542902
# Minibatch iteration 327/30000: mean batch inertia: 0.459227, ewa inertia: 0.542344
# Minibatch iteration 328/30000: mean batch inertia: 0.517614, ewa inertia: 0.542179
# Minibatch iteration 329/30000: mean batch inertia: 0.544141, ewa inertia: 0.542193
# Minibatch iteration 330/30000: mean batch inertia: 0.565915, ewa inertia: 0.542351
# Minibatch iteration 331/30000: mean batch inertia: 0.485912, ewa inertia: 0.541974
# Minibatch iteration 332/30000: mean batch inertia: 0.503754, ewa inertia: 0.541720
# Minibatch iteration 333/30000: mean batch inertia: 0.448208, ewa inertia: 0.541096
# Minibatch iteration 334/30000: mean batch inertia: 0.497162, ewa inertia: 0.540803
# Minibatch iteration 335/30000: mean batch inertia: 0.491333, ewa inertia: 0.540474
# Minibatch iteration 336/30000: mean batch inertia: 0.538863, ewa inertia: 0.540463
# Minibatch iteration 337/30000: mean batch inertia: 0.481175, ewa inertia: 0.540068
# Minibatch iteration 338/30000: mean batch inertia: 0.484988, ewa inertia: 0.539700
# Minibatch iteration 339/30000: mean batch inertia: 0.521704, ewa inertia: 0.539580
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 340/30000: mean batch inertia: 0.527676, ewa inertia: 0.539501
# Minibatch iteration 341/30000: mean batch inertia: 0.469712, ewa inertia: 0.539036
# Minibatch iteration 342/30000: mean batch inertia: 0.499476, ewa inertia: 0.538772
# Minibatch iteration 343/30000: mean batch inertia: 0.558407, ewa inertia: 0.538903
# Minibatch iteration 344/30000: mean batch inertia: 0.514095, ewa inertia: 0.538738
# Minibatch iteration 345/30000: mean batch inertia: 0.530371, ewa inertia: 0.538682
# Minibatch iteration 346/30000: mean batch inertia: 0.539449, ewa inertia: 0.538687
# Minibatch iteration 347/30000: mean batch inertia: 0.455383, ewa inertia: 0.538132
# Minibatch iteration 348/30000: mean batch inertia: 0.503157, ewa inertia: 0.537898
# Minibatch iteration 349/30000: mean batch inertia: 0.494926, ewa inertia: 0.537612
# Minibatch iteration 350/30000: mean batch inertia: 0.469137, ewa inertia: 0.537156
# Minibatch iteration 351/30000: mean batch inertia: 0.507675, ewa inertia: 0.536959
# Minibatch iteration 352/30000: mean batch inertia: 0.504523, ewa inertia: 0.536743
# Minibatch iteration 353/30000: mean batch inertia: 0.525054, ewa inertia: 0.536665
# Minibatch iteration 354/30000: mean batch inertia: 0.519349, ewa inertia: 0.536549
# Minibatch iteration 355/30000: mean batch inertia: 0.477234, ewa inertia: 0.536154
# Minibatch iteration 356/30000: mean batch inertia: 0.462758, ewa inertia: 0.535665
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 357/30000: mean batch inertia: 0.535474, ewa inertia: 0.535663
# Minibatch iteration 358/30000: mean batch inertia: 0.534822, ewa inertia: 0.535658
# Minibatch iteration 359/30000: mean batch inertia: 0.497916, ewa inertia: 0.535406
# Minibatch iteration 360/30000: mean batch inertia: 0.517759, ewa inertia: 0.535289
# Minibatch iteration 361/30000: mean batch inertia: 0.510400, ewa inertia: 0.535123
# Minibatch iteration 362/30000: mean batch inertia: 0.497170, ewa inertia: 0.534870
# Minibatch iteration 363/30000: mean batch inertia: 0.535281, ewa inertia: 0.534872
# Minibatch iteration 364/30000: mean batch inertia: 0.488311, ewa inertia: 0.534562
# Minibatch iteration 365/30000: mean batch inertia: 0.535975, ewa inertia: 0.534571
# Minibatch iteration 366/30000: mean batch inertia: 0.515266, ewa inertia: 0.534443
# Minibatch iteration 367/30000: mean batch inertia: 0.501729, ewa inertia: 0.534225
# Minibatch iteration 368/30000: mean batch inertia: 0.530331, ewa inertia: 0.534199
# Minibatch iteration 369/30000: mean batch inertia: 0.498141, ewa inertia: 0.533958
# Minibatch iteration 370/30000: mean batch inertia: 0.501934, ewa inertia: 0.533745
# Minibatch iteration 371/30000: mean batch inertia: 0.505606, ewa inertia: 0.533557
# Minibatch iteration 372/30000: mean batch inertia: 0.533667, ewa inertia: 0.533558
# Minibatch iteration 373/30000: mean batch inertia: 0.497881, ewa inertia: 0.533320
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 374/30000: mean batch inertia: 0.535294, ewa inertia: 0.533333
# Minibatch iteration 375/30000: mean batch inertia: 0.508780, ewa inertia: 0.533170
# Minibatch iteration 376/30000: mean batch inertia: 0.467205, ewa inertia: 0.532730
# Minibatch iteration 377/30000: mean batch inertia: 0.454441, ewa inertia: 0.532208
# Minibatch iteration 378/30000: mean batch inertia: 0.447382, ewa inertia: 0.531642
# Minibatch iteration 379/30000: mean batch inertia: 0.460393, ewa inertia: 0.531167
# Minibatch iteration 380/30000: mean batch inertia: 0.463178, ewa inertia: 0.530714
# Minibatch iteration 381/30000: mean batch inertia: 0.526901, ewa inertia: 0.530689
# Minibatch iteration 382/30000: mean batch inertia: 0.552006, ewa inertia: 0.530831
# Minibatch iteration 383/30000: mean batch inertia: 0.487844, ewa inertia: 0.530544
# Minibatch iteration 384/30000: mean batch inertia: 0.471579, ewa inertia: 0.530151
# Minibatch iteration 385/30000: mean batch inertia: 0.509123, ewa inertia: 0.530011
# Minibatch iteration 386/30000: mean batch inertia: 0.475361, ewa inertia: 0.529647
# Minibatch iteration 387/30000: mean batch inertia: 0.522371, ewa inertia: 0.529598
# Minibatch iteration 388/30000: mean batch inertia: 0.534211, ewa inertia: 0.529629
# Minibatch iteration 389/30000: mean batch inertia: 0.530039, ewa inertia: 0.529632
# Minibatch iteration 390/30000: mean batch inertia: 0.563735, ewa inertia: 0.529859
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 391/30000: mean batch inertia: 0.511517, ewa inertia: 0.529737
# Minibatch iteration 392/30000: mean batch inertia: 0.537306, ewa inertia: 0.529787
# Minibatch iteration 393/30000: mean batch inertia: 0.500676, ewa inertia: 0.529593
# Minibatch iteration 394/30000: mean batch inertia: 0.495716, ewa inertia: 0.529367
# Minibatch iteration 395/30000: mean batch inertia: 0.554391, ewa inertia: 0.529534
# Minibatch iteration 396/30000: mean batch inertia: 0.535260, ewa inertia: 0.529572
# Minibatch iteration 397/30000: mean batch inertia: 0.479181, ewa inertia: 0.529236
# Minibatch iteration 398/30000: mean batch inertia: 0.524023, ewa inertia: 0.529202
# Minibatch iteration 399/30000: mean batch inertia: 0.544414, ewa inertia: 0.529303
# Minibatch iteration 400/30000: mean batch inertia: 0.520002, ewa inertia: 0.529241
# Minibatch iteration 401/30000: mean batch inertia: 0.503591, ewa inertia: 0.529070
# Minibatch iteration 402/30000: mean batch inertia: 0.485238, ewa inertia: 0.528778
# Minibatch iteration 403/30000: mean batch inertia: 0.475612, ewa inertia: 0.528423
# Minibatch iteration 404/30000: mean batch inertia: 0.581736, ewa inertia: 0.528779
# Minibatch iteration 405/30000: mean batch inertia: 0.481922, ewa inertia: 0.528466
# Minibatch iteration 406/30000: mean batch inertia: 0.470610, ewa inertia: 0.528081
# Minibatch iteration 407/30000: mean batch inertia: 0.495433, ewa inertia: 0.527863
# Minibatch iteration 408/30000: mean batch inertia: 0.508932, ewa inertia: 0.527737
# Minibatch iteration 409/30000: mean batch inertia: 0.482952, ewa inertia: 0.527438
# Minibatch iteration 410/30000: mean batch inertia: 0.487758, ewa inertia: 0.527174
# Minibatch iteration 411/30000: mean batch inertia: 0.490584, ewa inertia: 0.526930
# Minibatch iteration 412/30000: mean batch inertia: 0.496859, ewa inertia: 0.526729
# Minibatch iteration 413/30000: mean batch inertia: 0.475671, ewa inertia: 0.526389
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 414/30000: mean batch inertia: 0.537638, ewa inertia: 0.526464
# Minibatch iteration 415/30000: mean batch inertia: 0.521259, ewa inertia: 0.526429
# Minibatch iteration 416/30000: mean batch inertia: 0.483903, ewa inertia: 0.526146
# Minibatch iteration 417/30000: mean batch inertia: 0.509087, ewa inertia: 0.526032
# Minibatch iteration 418/30000: mean batch inertia: 0.531396, ewa inertia: 0.526068
# Minibatch iteration 419/30000: mean batch inertia: 0.483554, ewa inertia: 0.525784
# Minibatch iteration 420/30000: mean batch inertia: 0.490223, ewa inertia: 0.525547
# Minibatch iteration 421/30000: mean batch inertia: 0.552906, ewa inertia: 0.525730
# Minibatch iteration 422/30000: mean batch inertia: 0.470200, ewa inertia: 0.525360
# Minibatch iteration 423/30000: mean batch inertia: 0.540150, ewa inertia: 0.525458
# Minibatch iteration 424/30000: mean batch inertia: 0.519044, ewa inertia: 0.525415
# Minibatch iteration 425/30000: mean batch inertia: 0.521651, ewa inertia: 0.525390
# Minibatch iteration 426/30000: mean batch inertia: 0.478154, ewa inertia: 0.525075
# Minibatch iteration 427/30000: mean batch inertia: 0.489367, ewa inertia: 0.524837
# Minibatch iteration 428/30000: mean batch inertia: 0.506757, ewa inertia: 0.524717
# Minibatch iteration 429/30000: mean batch inertia: 0.507069, ewa inertia: 0.524599
# Minibatch iteration 430/30000: mean batch inertia: 0.484389, ewa inertia: 0.524331
# Minibatch iteration 431/30000: mean batch inertia: 0.564650, ewa inertia: 0.524600
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 432/30000: mean batch inertia: 0.514221, ewa inertia: 0.524531
# Minibatch iteration 433/30000: mean batch inertia: 0.488943, ewa inertia: 0.524294
# Minibatch iteration 434/30000: mean batch inertia: 0.508445, ewa inertia: 0.524188
# Minibatch iteration 435/30000: mean batch inertia: 0.522032, ewa inertia: 0.524173
# Minibatch iteration 436/30000: mean batch inertia: 0.521178, ewa inertia: 0.524154
# Minibatch iteration 437/30000: mean batch inertia: 0.534344, ewa inertia: 0.524221
# Minibatch iteration 438/30000: mean batch inertia: 0.511583, ewa inertia: 0.524137
# Minibatch iteration 439/30000: mean batch inertia: 0.483462, ewa inertia: 0.523866
# Minibatch iteration 440/30000: mean batch inertia: 0.553995, ewa inertia: 0.524067
# Minibatch iteration 441/30000: mean batch inertia: 0.518750, ewa inertia: 0.524031
# Minibatch iteration 442/30000: mean batch inertia: 0.484690, ewa inertia: 0.523769
# Minibatch iteration 443/30000: mean batch inertia: 0.480350, ewa inertia: 0.523480
# Minibatch iteration 444/30000: mean batch inertia: 0.495935, ewa inertia: 0.523296
# Minibatch iteration 445/30000: mean batch inertia: 0.522741, ewa inertia: 0.523292
# Minibatch iteration 446/30000: mean batch inertia: 0.461349, ewa inertia: 0.522879
# Minibatch iteration 447/30000: mean batch inertia: 0.509823, ewa inertia: 0.522792
# Minibatch iteration 448/30000: mean batch inertia: 0.555389, ewa inertia: 0.523010
# Minibatch iteration 449/30000: mean batch inertia: 0.489023, ewa inertia: 0.522783
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 450/30000: mean batch inertia: 0.508805, ewa inertia: 0.522690
# Minibatch iteration 451/30000: mean batch inertia: 0.514545, ewa inertia: 0.522636
# Minibatch iteration 452/30000: mean batch inertia: 0.455414, ewa inertia: 0.522188
# Minibatch iteration 453/30000: mean batch inertia: 0.487814, ewa inertia: 0.521958
# Minibatch iteration 454/30000: mean batch inertia: 0.512039, ewa inertia: 0.521892
# Minibatch iteration 455/30000: mean batch inertia: 0.522692, ewa inertia: 0.521898
# Minibatch iteration 456/30000: mean batch inertia: 0.490071, ewa inertia: 0.521685
# Minibatch iteration 457/30000: mean batch inertia: 0.527382, ewa inertia: 0.521723
# Minibatch iteration 458/30000: mean batch inertia: 0.465295, ewa inertia: 0.521347
# Minibatch iteration 459/30000: mean batch inertia: 0.466040, ewa inertia: 0.520979
# Minibatch iteration 460/30000: mean batch inertia: 0.499793, ewa inertia: 0.520837
# Minibatch iteration 461/30000: mean batch inertia: 0.507253, ewa inertia: 0.520747
# Minibatch iteration 462/30000: mean batch inertia: 0.489971, ewa inertia: 0.520542
# Minibatch iteration 463/30000: mean batch inertia: 0.525079, ewa inertia: 0.520572
# Minibatch iteration 464/30000: mean batch inertia: 0.588335, ewa inertia: 0.521024
# Minibatch iteration 465/30000: mean batch inertia: 0.513089, ewa inertia: 0.520971
# Minibatch iteration 466/30000: mean batch inertia: 0.501642, ewa inertia: 0.520842
# Minibatch iteration 467/30000: mean batch inertia: 0.520654, ewa inertia: 0.520841
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 468/30000: mean batch inertia: 0.499231, ewa inertia: 0.520697
# Minibatch iteration 469/30000: mean batch inertia: 0.524768, ewa inertia: 0.520724
# Minibatch iteration 470/30000: mean batch inertia: 0.562354, ewa inertia: 0.521001
# Minibatch iteration 471/30000: mean batch inertia: 0.488338, ewa inertia: 0.520783
# Minibatch iteration 472/30000: mean batch inertia: 0.568458, ewa inertia: 0.521101
# Converged (lack of improvement in inertia) at iteration 472/30000
# Computing label assignment and total inertia
# Computing label assignment and total inertia

# %% [markdown]
# #### Examine some results

# %%
index = 8
sentence_index = np.where(y_hat==index)[0]
for i in sentence_index:
    print('-----------------------------------------------------------------')
    print(sentences[i])
    print('\n')

# %%
index = 33
sentence_index = np.where(y_hat==index)[0]
for i in sentence_index:
    print('-----------------------------------------------------------------')
    print(sentences[i])
    print('\n')
# Out:
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# DECISION
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# JUDGMENT AND SENTENCE
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# Decision
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# Decision
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# DETERMINATION
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# RULING
#
#
# -----------------------------------------------------------------
# RULING

# %%
index = 800
sentence_index = np.where(y_hat==index)[0]
for i in sentence_index:
    print('-----------------------------------------------------------------')
    print(sentences[i])
    print('\n')

# %%
index = 54
sentence_index = np.where(y_hat==index)[0]
for i in sentence_index:
    print('-----------------------------------------------------------------')
    print(sentences[i])
    print('\n')
# Out:
# -----------------------------------------------------------------
# Statement of Offence [a]
#
#
# -----------------------------------------------------------------
# Statement of Offence [a]
#
#
# -----------------------------------------------------------------
# Statement of Offence (a)
#
#
# -----------------------------------------------------------------
# Statement of Offence (a)
#
#
# -----------------------------------------------------------------
# Statement of offence [a]
#
#
# -----------------------------------------------------------------
# (a) the nature of the offence;
#
#
# -----------------------------------------------------------------
# Statement of Offence (a)
#
#
# -----------------------------------------------------------------
# 	◦	Prevalence of offence in community.
#
#
# -----------------------------------------------------------------
# 		(i) attitude to the offence;
#
#
# -----------------------------------------------------------------
# Statement of Offence [a]
#
#
# -----------------------------------------------------------------
# Statement of Offence (a)
#
#
# -----------------------------------------------------------------
# Offence
#
#
# -----------------------------------------------------------------
# Statement of Offence (a)
#
#
# -----------------------------------------------------------------
# (i) attitude of the offence;
#
#
# -----------------------------------------------------------------
# Statement of Offence (a)
#
#
# -----------------------------------------------------------------
# Statement of Offence (a)
#
#
# -----------------------------------------------------------------
# State of Offence (a)
#
#
# -----------------------------------------------------------------
# Statement of Offence (a)
#
#
# -----------------------------------------------------------------
# (a) the nature of the offence;
#
#
# -----------------------------------------------------------------
# 		(i) attitude to the offence;
#
#
# -----------------------------------------------------------------
# Statement of Offence (a)
#
#
# -----------------------------------------------------------------
# Statement of Offence (a)
#
#
# -----------------------------------------------------------------
# Statement of Offence [a]
